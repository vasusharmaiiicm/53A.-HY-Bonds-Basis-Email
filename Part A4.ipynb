# %%
global_update_live = True
email_both = True

# %%
from nbconvert.preprocessors import ExecutePreprocessor
ep = ExecutePreprocessor(timeout=60000)

import asyncio
asyncio.set_event_loop_policy(asyncio.WindowsSelectorEventLoopPolicy())
import pandas as pd
import random
from pydataquery import DataQuery
from matplotlib.colors import LinearSegmentedColormap
from xbbg import blp
import numpy as np
import pytz
import time
from datetime import datetime, timedelta
import statsmodels.api as sm
from ipywidgets import interact, Dropdown, HBox, VBox, Button, Output, Text, widgets
from IPython.display import display, clear_output
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
import re
import scipy.stats as stats
from adjustText import adjust_text
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import sympy as sp
import itertools
import warnings
import openpyxl
import subprocess
import dataframe_image as dfi
import time
import pyautogui
import pygetwindow as gw
import pyodbc
import ast
import json
warnings.filterwarnings("ignore")

# %%
dft = pd.read_excel("DQ_EM_Basis_Data v2.xlsx")
dft.set_index(dft.columns[0],inplace=True)
dft.index.name = None
dft.index = pd.to_datetime(dft.index, format='%Y-%m-%d').date
df_back = dft.copy()

start_date = df_back.index.max()

##################  Change here only

isin_list = ["US105756BX78", "US105756BZ27", "US105756CA66", "US105756CC23", "US105756CG37", "US105756CE88", "US105756CK49", "US105756CF53", "US105756CH10", "US105756BW95", "US105756BY51", "US105756CB40", "US105756CJ75", "US168863DX33", "US168863CF36", "US168863EB04", "US168863DP09", "US168863DN50", "US168863DT21", "US168863DV76", "US168863DZ80", "US168863DS48", "US168863DY16", "US168863CE60", "US168863DL94", "US168863DW59", "XS2327851874", "US168863EA21", "US168863DQ81", "US168863DU93", "US195325CX13", "US195325DL65", "US195325DP79", "US195325DR36", "US195325DS19", "US195325DZ51", "US195325EF88", "US195325EG61", "US195325EL56", "US195325BK01", "US195325BM66", "US195325EA91", "US195325BR53", "US195325CU73", "US195325DQ52", "US195325DT91", "US195325EM30", "US195325DX04", "US91086QBG29", "US91087BAC46", "US91087BAE02", "US91087BAU44", "US91087BAF76", "US91087BAY65", "US91087BAH33", "US91087BAM28", "US91087BAK61", "US91087BAT70", "US91087BAR15", "US91087BAV27", "US91087BAZ31", "US91086QAV05", "US91087BAQ32", "US91086QBB32", "US91086QBE70", "US91086QBF46", "US91087BAB62", "US91087BAD29", "US91087BAG59", "US91087BAL45", "US91087BAS97", "US91087BAX82", "US91087BBA70", "US91087BAN01", "XS2280637039", "US91086QAZ19", "USP90603AN40", "US698299BF03", "US698299BK97", "US698299BX19", "USP90603AP97", "US698299BN37", "US698299BR41", "US698299BT07", "US698299AW45", "US698299BW36", "US698299BY91", "US698299BG85", "US698299BH68", "US698299BB98", "US698299BV52", "US698299BM53", "US698299BL70", "US698299BS24", "US715638DE95", "US715638BU55", "US715638DA73", "US715638DF60", "US715638DP43", "US715638DU38", "US715638EB48", "US715638DS81", "US715638BM30", "US715638DT64", "US715638EC21", "US715638DQ26", "US715638DW93", "US715638DR09", "US836205AT15", "US836205AW44", "US836205AU87", "US836205BA15", "US836205AY00", "US836205BC70", "US836205AS32", "US836205AV60", "US836205AX27", "US836205BB97", "US836205BE37", "US900123DB31", "US900123CJ75", "US900123CK49", "US900123CL22", "USM88269US88", "US900123DF45", "US900123CP36", "US900123CQ19", "US900123DH01", "US900123CT57", "US900123CY43", "US900123DJ66", "US900123DA57", "US900123DC14", "US900123DL13", "US900123DG28", "US900123DD96", "US900123AT75", "US900123DK30", "US900123DN78", "US900123AY60", "US900123BB58", "US900123BG46", "US900123BJ84", "US900123CB40", "US900123CG37", "US900123CM05", "USP3579EBK21", "USP3579EBV85", "USP3579ECB13", "USP3579ECP09", "USP3579ECF27", "USP3579ECR64", "USP3579ECH82", "USP3579ECN50", "USP3579ECU93", "USP3579ECJ49", "USP3579EAY34", "USP3579EBE60", "USP3579EBY25", "USP3579ECE51", "USP3579ECG00", "US71654QDH20", "US71654QBW15", "US71654QCB68", "US71654QDB59", "US71654QCG55", "US71654QCK67", "US71654QCP54", "US71654QDL32", "US71654QDC33", "US71654QDE98", "US71643VAB18", "US71654QDP46", "US706451BG56", "US71654QAZ54", "US71654QBR20", "US71654QCC42", "US71654QCL41", "US71654QDD16", "US71654QDF63", "US71656MAF68", "US71647NAS80", "US71647NAY58", "US71647NBH17", "US71647NBK46", "US71647NBL29", "US71645WAQ42", "US71645WAS08", "US71647NAK54", "US71647NBJ72", "US71647NAN93",
             "XS2214237807", "XS2214239506", "XS2214238441", "XS2214239175", "US040114HX11", "US040114HS26", "US040114HT09", "US040114HU71", "US040114HV54", "US040114HW38", "XS1910826996", "XS1717011982", "XS2384698994", "XS2445169985", "XS1777972511", "XS1910827887", "XS2948511949", "XS1566179039", "XS2384701020", "XS2948512913", "XS1777972941", "XS1717013095", "XS1910828182", "XS2384704800", "XS1843435840", "XS1781710543", "XS2764839945", "XS1843435766", "XS2354781614", "XS1781710626", "XS1318576086", "XS1819680288", "XS2083302419", "XS2446175577", "XS1819680528", "XS2083302500", "XS1790104530", "XS1619155564", "XS2333676133", "XS1790134362", "XS2297220423", "XS1903488572", "XS1558078736", "XS2391394348", "XS1775618439", "XS1504948776", "XS1953057061", "XS1903489463", "XS2297226545", "XS2079842642", "XS2176897754", "XS2391395154", "XS1558078496", "XS1775617464", "XS1953057491", "XS2176899701", "XS2391398174", "USP01012BX31", "USP01012CF16", "XS0146173371", "USP01012AN67", "USP01012AR71", "USP01012CA29", "USP01012CC84", "USP01012CH71", 
             "USP7808BAA54", "USP7808BAB38", "XS0505478684", "XS2079846635", "XS2297221405", 
             "USG2583XAB76", "USL21779AL44", "USL21779AJ97", "USL21779AK60", 
             "XS2322319398", "XS1729875598", "XS2419405274", "XS2322319638", "XS2322321964",
             "USN15516AB83", "USN15516AD40", "USN15516AH53","USN15516AG70","USN15516AJ10","USU1065PAA94",
             "USN15516AE23"
            ]
isin_list += ['XS2965710598','US105756CL22','US105756CM05','US168863EE43','US195325ER27','US195325EQ44','US195325EP60','US195325ES00','US25714PFB94','US25714PFC77','XS2990500766','XS2989586941','XS3010561762','US91087BBB53','US91087BBF67','US91087BBE92','US91087BBC37','US91087BBD10','US715638FD94','US715638FC12','US836205BF02','XS2917537875','US900123DQ00']
isin_list += ["US60367QAC78", "US16955EAC49", "US455780CB07", "US455780BM70", "US455780BY19", "US455780BJ42", "US455780BU96", "US455780BW52", "US455780BR67", "US455780AX45", "US455780AZ92", "US455780AT33", "US455780CV60", "US455780CY00", "US455780CQ75", "US455780CR58", "US455780CW44", "US455780DG84", "US455780CX27", "US455780DJ24", "US455780CN45", "US455780CS32", "US455780DX18", "US455780CT15", "US455780DK96", "US455780CE46", "US455780CU87", "US455780DN36", "US455780DU78", "US455780DR40", "US455780DZ65", "US455780DV51", "US455780DW35", "US455780CJ33", "US455780EA06", "US455780DS23"]
isin_list += ["XS2290957146", "US05675M2G83", "XS2408003064", "US05675M2J23", "XS2058948451", "US05675M2A14", "XS2226916216", "US05675M2D52", "XS1675862012", "US05674RAJ32", "XS2764424813", "US05675M2L78", "XS2611617700", "US05675M2K95", "XS2172965282", "US05675M2C79", "US50064FAS39", "XS2294322818", "US80413TAV17", "XS2109766472", "US80413TAQ22", "XS2159975700", "US80413TAT60", "XS1791939066", "US80413TAH23", "XS2747598444", "US80413TBF57", "XS2577135127", "US80413TBD00", "XS2747599095", "US80413TBG31", "XS2548892020", "US80413TBA60", "XS2974968161", "US80413TBK43", "XS2974969482", "US80413TBL26", "XS2288905370", "US68205LAS25", "XS2234859283", "US68205LAE39", "US718286CK14", "US718286CN52", "US718286CJ41", "US718286CR66", "US718286DC88", "US718286BW60", "US718286CW51", "US718286DG92", "US718286DA23", "US718286CT23", "US718286BD89", "US718286BG11", "US718286BB24", "US718286AY36", "XS2155352664", "US74727PBD24", "XS2822506833", "US74738PTP35", "XS2918565198", "US74738PUJ55", "XS0113419690", "US74727PAE16"]

names_list = ["BRAZIL 6 04/07/26", "BRAZIL 4 5/8 01/13/28", "BRAZIL 4 1/2 05/30/29", "BRAZIL 3 7/8 06/12/30", "BRAZIL 6 1/4 03/18/31", "BRAZIL 3 3/4 09/12/31", "BRAZIL 6 1/8 01/22/32", "BRAZIL 6 10/20/33", "BRAZIL 6 1/8 03/15/34", "BRAZIL 5 01/27/45", "BRAZIL 5 5/8 02/21/47", "BRAZIL 4 3/4 01/14/50", "BRAZIL 7 1/8 05/13/54", "CHILE 2 3/4 01/31/27", "CHILE 3.24 02/06/28", "CHILE 4.85 01/22/29", "CHILE 2.45 01/31/31", "CHILE 2.55 01/27/32", "CHILE 2.55 07/27/33", "CHILE 3 1/2 01/31/34", "CHILE 4.95 01/05/36", "CHILE 3.1 05/07/41", "CHILE 4.34 03/07/42", "CHILE 3.86 06/21/47", "CHILE 3 1/2 01/25/50", "CHILE 4 01/31/52", "CHILE 3 1/2 04/15/53", "CHILE 5.33 01/05/54", "CHILE 3.1 01/22/61", "CHILE 3 1/4 09/21/2071", "COLOM 4 1/2 01/28/26", "COLOM 3 7/8 04/25/27", "COLOM 4 1/2 03/15/29", "COLOM 3 01/30/30", "COLOM 3 1/8 04/15/31", "COLOM 3 1/4 04/22/32", "COLOM 8 04/20/33", "COLOM 7 1/2 02/02/34", "COLOM 8 11/14/35", "COLOM 7 3/8 09/18/37", "COLOM 6 1/8 01/18/41", "COLOM 4 1/8 02/22/42", "COLOM 5 5/8 02/26/44", "COLOM 5 06/15/45", "COLOM 5.2 05/15/49", "COLOM 4 1/8 05/15/51", "COLOM 8 3/4 11/14/53", "COLOM 3 7/8 02/15/61", "MEX 4 1/8 01/21/26", "MEX 4.15 03/28/27", "MEX 3 3/4 01/11/28", "MEX 5.4 02/09/28", "MEX 4 1/2 04/22/29", "MEX 5 05/07/29", "MEX 3 1/4 04/16/30", "MEX 2.659 05/24/31", "MEX 4 3/4 04/27/32", "MEX 4 7/8 05/19/33", "MEX 3 1/2 02/12/34", "MEX 6.35 02/09/35", "MEX 6 05/07/36", "MEX 6.05 01/11/40", "MEX 4.28 08/14/41", "MEX 4 3/4 03/08/44", "MEX 5.55 01/21/45", "MEX 4.6 01/23/46", "MEX 4.35 01/15/47", "MEX 4.6 02/10/48", "MEX 4 1/2 01/31/50", "MEX 5 04/27/51", "MEX 4.4 02/12/52", "MEX 6.338 05/04/53", "MEX 6.4 05/07/54", "MEX 3.771 05/24/61", "MEX 3 3/4 04/19/2071", "MEX 5 3/4 10/12/2110", "PANAMA 3 3/4 04/17/26", "PANAMA 3 7/8 03/17/28", "PANAMA 3.16 01/23/30", "PANAMA 7 1/2 03/01/31", "PANAMA 3.362 06/30/31", "PANAMA 2.252 09/29/32", "PANAMA 3.298 01/19/33", "PANAMA 6.4 02/14/35", "PANAMA 6.7 01/26/36", "PANAMA 6 7/8 01/31/36", "PANAMA 8 03/01/38", "PANAMA 4 1/2 05/15/47", "PANAMA 4 1/2 04/16/50", "PANAMA 4.3 04/29/53", "PANAMA 6.853 03/28/54", "PANAMA 4 1/2 04/01/56", "PANAMA 3.87 07/23/60", "PANAMA 4 1/2 01/19/63", "PERU 2.392 01/23/26", "PERU 4 1/8 08/25/27", "PERU 2.844 06/20/30", "PERU 2.783 01/23/31", "PERU 1.862 12/01/32", "PERU 3 01/15/34", "PERU 5 3/8 02/08/35", "PERU 3.3 03/11/41", "PERU 5 5/8 11/18/50", "PERU 3.55 03/10/51", "PERU 5 7/8 08/08/54", "PERU 2.78 12/01/60", "PERU 3.6 01/15/2072", "PERU 3.23 07/28/2121", "SOAF 4 7/8 04/14/26", "SOAF 4.85 09/27/27", "SOAF 4.3 10/12/28", "SOAF 4.85 09/30/29", "SOAF 5 7/8 06/22/30", "SOAF 5 7/8 04/20/32", "SOAF 5 3/8 07/24/44", "SOAF 5 10/12/46", "SOAF 5.65 09/27/47", "SOAF 5 3/4 09/30/49", "SOAF 7.3 04/20/52", "TURKEY 4 3/4 01/26/26", "TURKEY 4 1/4 04/14/26", "TURKEY 4 7/8 10/09/26", "TURKEY 6 03/25/27", "TURKEY 8.6 09/24/27", "TURKEY 9 7/8 01/15/28", "TURKEY 5 1/8 02/17/28", "TURKEY 6 1/8 10/24/28", "TURKEY 9 3/8 03/14/29", "TURKEY 7 5/8 04/26/29", "TURKEY 5 1/4 03/13/30", "TURKEY 9 1/8 07/13/30", "TURKEY 5.95 01/15/31", "TURKEY 5 7/8 06/26/31", "TURKEY 7 1/8 07/17/32", "TURKEY 9 3/8 01/19/33", "TURKEY 6 1/2 09/20/33", "TURKEY 8 02/14/34", "TURKEY 7 5/8 05/15/34", "TURKEY 6 1/2 01/03/35", "TURKEY 6 7/8 03/17/36", "TURKEY 7 1/4 03/05/38", "TURKEY 6 3/4 05/30/40", "TURKEY 6 01/14/41", "TURKEY 4 7/8 04/16/43", "TURKEY 6 5/8 02/17/45", "TURKEY 5 3/4 05/11/47", "DOMREP 6 7/8 01/29/26", "DOMREP 5.95 01/25/27", "DOMREP 6 07/19/28", "DOMREP 5 1/2 02/22/29", "DOMREP 4 1/2 01/30/30", "DOMREP 7.05 02/03/31", "DOMREP 4 7/8 09/23/32", "DOMREP 6 02/22/33", "DOMREP 6.6 06/01/36", "DOMREP 5.3 01/21/41", "DOMREP 7.45 04/30/44", "DOMREP 6.85 01/27/45", "DOMREP 6 1/2 02/15/48", "DOMREP 6.4 06/05/49", "DOMREP 5 7/8 01/30/60", "PEMEX 6 7/8 10/16/25", "PEMEX 4 1/2 01/23/26", "PEMEX 6 7/8 08/04/26", "PEMEX 6.49 01/23/27", "PEMEX 6 1/2 03/13/27", "PEMEX 5.35 02/12/28", "PEMEX 6 1/2 01/23/29", "PEMEX 8 3/4 06/02/29", "PEMEX 6.84 01/23/30", "PEMEX 5.95 01/28/31", "PEMEX 6.7 02/16/32", "PEMEX 10 02/07/33", "PEMEX 6 5/8 06/15/35", "PEMEX 6 1/2 06/02/41", "PEMEX 6 3/8 01/23/45", "PEMEX 6 3/4 09/21/47", "PEMEX 6.35 02/12/48", "PEMEX 7.69 01/23/50", "PEMEX 6.95 01/28/60", "PEMEX 6 5/8 PERP", "PETBRA 7 3/8 01/17/27", "PETBRA 5.999 01/27/28", "PETBRA 5.6 01/03/31", "PETBRA 6 1/2 07/03/33", "PETBRA 6 01/13/35", "PETBRA 6 7/8 01/20/40", "PETBRA 6 3/4 01/27/41", "PETBRA 7 1/4 03/17/44", "PETBRA 5 1/2 06/10/51", "PETBRA 6.85 06/05/2115",
             "ECUA 6.9 07/31/30", "ECUA 0 07/31/30", "ECUA 5 1/2 07/31/35", "ECUA 5 07/31/40", "ARGENT 1 07/09/29", "ARGENT 0 3/4 07/09/30", "ARGENT 4 1/8 07/09/35", "ARGENT 5 01/09/38", "ARGENT 3 1/2 07/09/41", "ARGENT 4 1/8 07/09/46", "NGERIA 7 5/8 11/21/25", "NGERIA 6 1/2 11/28/27", "NGERIA 6 1/8 09/28/28", "NGERIA 8 3/8 03/24/29", "NGERIA 7.143 02/23/30", "NGERIA 8.747 01/21/31", "NGERIA 9 5/8 06/09/31", "NGERIA 7 7/8 02/16/32", "NGERIA 7 3/8 09/28/33", "NGERIA 10 3/8 12/09/34", "NGERIA 7.696 02/23/38", "NGERIA 7 5/8 11/28/47", "NGERIA 9.248 01/21/49", "NGERIA 8 1/4 09/28/51", "KENINT 7 05/22/27", "KENINT 7 1/4 02/28/28", "KENINT 9 3/4 02/16/31", "KENINT 8 05/22/32", "KENINT 6.3 01/23/34", "KENINT 8 1/4 02/28/48", "ANGOL 9 1/2 11/12/25", "ANGOL 8 1/4 05/09/28", "ANGOL 8 11/26/29", "ANGOL 8 3/4 04/14/32", "ANGOL 9 3/8 05/08/48", "ANGOL 9 1/8 11/26/49", "SENEGL 4 3/4 03/13/28", "SENEGL 6 1/4 05/23/33", "SENEGL 5 3/8 06/08/37", "SENEGL 6 3/4 03/13/48", "EGYPT 3 7/8 02/16/26", "EGYPT 7 1/8 11/10/26", "EGYPT 7 1/2 01/31/27", "EGYPT 5.8 09/30/27", "EGYPT 6.588 02/21/28", "EGYPT 7 11/10/28", "EGYPT 7.6003 03/01/29", "EGYPT 7 5/8 11/10/30", "EGYPT 5 7/8 02/16/31", "EGYPT 7.0529 01/15/32", "EGYPT 7 5/8 05/29/32", "EGYPT 7.3 09/30/33", "EGYPT 8 1/2 01/31/47", "EGYPT 7.903 02/21/48", "EGYPT 8.7002 03/01/49", "EGYPT 8 7/8 05/29/50", "EGYPT 8 3/4 09/30/51", "ELSALV 8 5/8 02/28/29", "ELSALV 9 1/4 04/17/30", "ELSALV 8 1/4 04/10/32", "ELSALV 7.65 06/15/35", "ELSALV 7 5/8 02/01/41", "ELSALV 7.1246 01/20/50", "ELSALV 9 1/2 07/15/52", "ELSALV 9.65 11/21/54", 
             "PETRPE 4 3/4 06/19/32", "PETRPE 5 5/8 06/19/47", "EGYPT 6 7/8 04/30/40", "EGYPT 8.15 11/20/59", "EGYPT 7 1/2 02/16/61", 
             "CSNABZ 6 3/4 01/28/28", "CSNABZ 8 7/8 12/05/30", "CSNABZ 4 5/8 06/10/31", "CSNABZ 5 7/8 04/08/32",
             "PKSTAN 6 04/08/26", "PKSTAN 6 7/8 12/05/27", "PKSTAN 7.95 01/31/29", "PKSTAN 7 3/8 04/08/31", "PKSTAN 8 7/8 04/08/51",
             "BRASKM 4.5 01/10/28", "BRASKM 4.5 01/31/30","BRASKM 8.5 01/12/31","BRASKM 7.25 02/13/33","BRASKM 8 10/15/34","BRASKM 7.125 07/22/41", "BRASKM 5.875 01/31/50",
             ]
names_list += ['ANGOL 10.95 12/27/30', 'BRAZIL 6 5/8 03/15/35', 'BRAZIL 5 1/2 11/06/30', 'CHILE 5.65 01/13/37', 'COLOM 7 3/8 04/25/30', 'COLOM 8 3/8 11/07/54', 'COLOM 7 3/4 11/07/36', 'COLOM 8 1/2 04/25/35', 'DOMREP 6.95 03/15/37', 'DOMREP 7.15 02/24/55', 'EGYPT 9.45 02/04/33', 'EGYPT 8 5/8 02/04/30', 'KENINT 9 1/2 03/05/36', 'MEX 6 05/13/30', 'MEX 6 5/8 01/29/38', 'MEX 5.85 07/02/32', 'MEX 6 7/8 05/13/37', 'MEX 7 3/8 05/13/55', 'PERU 6.2 06/30/55', 'PERU 5 1/2 03/30/36', 'SOAF 7.1 11/19/36', 'SOAF 7.95 11/19/54', 'TURKEY 7 1/4 05/29/32']
names_list += ["CHINA 1 3/4 10/26/31", "CHINA 1.2 10/21/30", "INDON 4 3/4 07/18/47", "INDON 4 5/8 04/15/43", "INDON 5 1/4 01/08/47", "INDON 5 1/4 01/17/42", "INDON 5 1/8 01/15/45", "INDON 5.95 01/08/46", "INDON 6 3/4 01/15/44", "INDON 6 5/8 02/17/37", "INDON 7 3/4 01/17/38", "INDON 8 1/2 10/12/35", "INDON 1.85 03/12/31", "INDON 2.15 07/28/31", "INDON 2.85 02/14/30", "INDON 3 1/2 02/14/50", "INDON 3.05 03/12/51", "INDON 3.2 09/23/61", "INDON 3.35 03/12/2071", "INDON 3.55 03/31/32", "INDON 3.7 10/30/49", "INDON 3.85 10/15/30", "INDON 4 3/4 09/10/34", "INDON 4.2 10/15/50", "INDON 4.3 03/31/52", "INDON 4.35 01/11/48", "INDON 4.45 04/15/70", "INDON 4.65 09/20/32", "INDON 4.7 02/10/34", "INDON 4.85 01/11/33", "INDON 5 1/4 01/15/30", "INDON 5.1 02/10/54", "INDON 5.15 09/10/54", "INDON 5.35 02/11/49", "INDON 5.6 01/15/35", "INDON 5.65 01/11/53"]
names_list += ["BHRAIN 5 1/4 01/25/33", "BHRAIN 5 1/4 01/25/33", "BHRAIN 5 5/8 05/18/34", "BHRAIN 5 5/8 05/18/34", "BHRAIN 5 5/8 09/30/31", "BHRAIN 5 5/8 09/30/31", "BHRAIN 5.45 09/16/32", "BHRAIN 5.45 09/16/32", "BHRAIN 6 3/4 09/20/29", "BHRAIN 6 3/4 09/20/29", "BHRAIN 7 1/2 02/12/36", "BHRAIN 7 1/2 02/12/36", "BHRAIN 7 3/4 04/18/35", "BHRAIN 7 3/4 04/18/35", "BHRAIN 7 3/8 05/14/30", "BHRAIN 7 3/8 05/14/30", "KOREA 1 09/16/30", "KSA 2 1/4 02/02/33", "KSA 2 1/4 02/02/33", "KSA 2 3/4 02/03/32", "KSA 2 3/4 02/03/32", "KSA 3 1/4 10/22/30", "KSA 3 1/4 10/22/30", "KSA 4 1/2 04/17/30", "KSA 4 1/2 04/17/30", "KSA 4 3/4 01/16/30", "KSA 4 3/4 01/16/30", "KSA 4 7/8 07/18/33", "KSA 4 7/8 07/18/33", "KSA 5 01/16/34", "KSA 5 01/16/34", "KSA 5 1/2 10/25/32", "KSA 5 1/2 10/25/32", "KSA 5 3/8 01/13/31", "KSA 5 3/8 01/13/31", "KSA 5 5/8 01/13/35", "KSA 5 5/8 01/13/35", "OMAN 6 1/4 01/25/31", "OMAN 6 1/4 01/25/31", "OMAN 7 3/8 10/28/32", "OMAN 7 3/8 10/28/32", "PHILIP 1.648 06/10/31", "PHILIP 1.95 01/06/32", "PHILIP 2.457 05/05/30", "PHILIP 3.556 09/29/32", "PHILIP 4 3/4 03/05/35", "PHILIP 5 01/13/37", "PHILIP 5 07/17/33", "PHILIP 5 1/2 02/04/35", "PHILIP 5 1/4 05/14/34", "PHILIP 5.609 04/13/33", "PHILIP 6 3/8 01/15/32", "PHILIP 6 3/8 10/23/34", "PHILIP 7 3/4 01/14/31", "PHILIP 9 1/2 02/02/30", "QATAR 3 3/4 04/16/30", "QATAR 3 3/4 04/16/30", "QATAR 4 3/4 05/29/34", "QATAR 4 3/4 05/29/34", "QATAR 4 7/8 02/27/35", "QATAR 4 7/8 02/27/35", "QATAR 9 3/4 06/15/30", "QATAR 9 3/4 06/15/30"]

#Making Manual Adj. for Perp Bond of PEMEX
names_list[names_list.index("PEMEX 6 5/8 PERP")] = "PEMEX 6 5/8 01/01/9999"

#####################################################  Drop some issuers
bonds_dict = dict(zip(names_list, isin_list))
new_bonds_dict = {}

for key, val in bonds_dict.items():
    if not key.split(" ")[0] in ["CSNABZ","CHINA","BRASKM","CHINA","KENINT","PKSTAN","DOMREP"]:
        new_bonds_dict[key] = val

names_list = list(new_bonds_dict.keys())
isin_list = list(new_bonds_dict.values())

#####################################################  Change here only

names_list = [item.split(' ',1)[0] + ' ' + item.rsplit(' ',1)[0].split(' ',1)[1] + '% due ' + item.rsplit('/',1)[-1] for item in names_list]

fields = [          
          ["DB(SAGE,INSTRUMENT,id_isin,", ",StatCdsPESpreadAsk)"],
          ["DB(SAGE,INSTRUMENT,id_isin,", ",StatCdsPESpreadBid)"],
          ["DB(SAGE,INSTRUMENT,id_isin,", ",StatCdsBasis)"],
         ]

field_names = ['PECS Ask', 'PECS Bid','Basis',]

dq_list = []
full_names = []

for i in range(len(isin_list)):
    for j in range(len(fields)):
        dq_list = dq_list + [fields[j][0] + isin_list[i] + fields[j][1]]
        full_names = full_names + [names_list[i] + ' ' + field_names[j]]

labels = dict(zip(full_names, dq_list))

######################################################### Hash this for non-live
# if True:
try:
    if global_update_live:
        cl = 'jbAIMF2Tkp0JO3sc'
        # cl = '0'
    dq = DataQuery(
    client_id=cl,
    client_secret='d7qfzgt55pddjs352sgxosFyI4t2eja07k7opbi6wg9oqjc1OjkdAksn1btmnugeMjchcx2vwTsJupw',
    )
    job = dq.create_job(expressions = list(labels.values()))
    dq.start_date = 'TODAY-5Y'
    job.execute(alert_long_requests='ignore')
    df = job.to_pivot_table()
    df = df.T
    df.index.name = 'Date'
    df.index = pd.to_datetime(df.index, format='%Y%m%d').date
    df.columns.name = None
    
    df1 = pd.DataFrame()
    for key in labels:
        df1[key] = df[labels[key]]
    
    df1 = df1[list(labels.keys())].copy()
    clear_output(wait=False)
    df1.dropna(axis=1, how='all', inplace=True)
    
    df1.columns = df1.columns.str.replace("DQ PECS", "DQ PECS Rich/Cheap")
    df1.columns = df1.columns.str.replace("DQ Z_SPREAD", "DQ Z_SPREAD Rich/Cheap")
    df_back = df1.copy()
    df_back.to_excel("DQ_EM_Basis_Data v2.xlsx")
    
    # else:
    #     df_back = pd.concat([df_back[~df_back.index.isin(df.index)], df])
    #     df_back.to_excel("DQ_Data_v75.xlsx")

except Exception as e:
    print(f"Using old JPM data")

# %%
if global_update_live:
    df_original = pd.read_parquet("Markit CDS.parquet")
    df_original2 = pd.read_parquet("Markit Upfronts.parquet")
    
    to_date = datetime.today().date()
    from_date = df_original["close_date"].iloc[-1].date()
    from_date2 = df_original2["close_date"].iloc[-1].date()
    
    from_date = min(from_date, from_date2)    
    from_date_str = from_date.strftime('%m/%d/%Y')
    to_date_str = to_date.strftime('%m/%d/%Y')
    
    conn_str = (
        f'DRIVER={{SQL Server}};'
        f'SERVER=BC-ODS-P1;'
        f'DATABASE=MarkitDB;'
        f'ApplicationIntent=ReadOnly;'
        f'Trusted_Connection=Yes;'
        f'Authentication=ActiveDirectoryIntegrated;'
    )
    
    conn = pyodbc.connect(conn_str)
    
    query1 = f"""
        DECLARE @FromDate DATE = '{from_date_str}';
        DECLARE @ToDate DATE = '{to_date_str}';
        
        SELECT sc.close_date, r.ticker, c.red, c.tier, c.docclause, c.ccy, sc.tenor, sc.spread
        FROM dbo.RedEntities r
        INNER JOIN dbo.MarkitCurves c ON r.red = c.red
        INNER JOIN dbo.MarkitSpreadCurve sc ON c.curve_id = sc.curve_id
        WHERE sc.close_date >= @FromDate AND sc.close_date <= @ToDate;
    """

    query2 = f""" 
        DECLARE @FromDate DATE = '{from_date_str}';
        DECLARE @ToDate DATE = '{to_date_str}';
        
        Select uf.close_date, r.ticker, c.red, c.tier, c.docclause, c.ccy, uf.coupon, ufc.tenor, ufc.fee, ufc.spread, ufc.calculated_fee, ufc.calculated_spread
        From dbo.RedEntities r
        Inner Join dbo.MarkitCurves c On r.red = c.red
        Inner Join dbo.MarkitUpfronts uf On c.curve_id = uf.curve_id
        Inner Join dbo.MarkitUpfrontFees ufc On uf.curve_id = ufc.curve_id And uf.coupon = ufc.coupon And uf.close_date = ufc.close_date
        Where uf.close_date >= @FromDate And uf.close_date <= @ToDate
     """

    df_new = pd.read_sql(query1, conn)
    df_new2 = pd.read_sql(query2, conn)

    conn.close()

    # df_old = df_original[df_original["close_date"]<pd.to_datetime(from_date)]
    # df_old2 = df_original2[df_original2["close_date"]<pd.to_datetime(from_date)]
    df_original = df_original[df_original["close_date"]<pd.to_datetime(from_date)]
    df_original2 = df_original2[df_original2["close_date"]<pd.to_datetime(from_date)]

    df1 = pd.concat([df_original, df_new])
    df1 = df1.drop_duplicates()
    df1.to_parquet("Markit CDS.parquet")

    df2 = pd.concat([df_original2, df_new2])
    df2 = df2.drop_duplicates()
    df2.to_parquet("Markit Upfronts.parquet")
else:
    df1 = pd.read_parquet("Markit CDS.parquet")
    df2 = pd.read_parquet("Markit Upfronts.parquet")
    print("Using Old Data")

# %%
markit_uf = df2.drop("calculated_spread",axis=1).copy()
markit_par = df1.copy()

markit_uf["fee"] = markit_uf["fee"].fillna(markit_uf["calculated_fee"])
markit_uf["spread"] = markit_uf["fee"]
markit_uf = markit_uf.drop(["calculated_fee","fee"],axis=1)

markit_uf100 = markit_uf[markit_uf["coupon"]==100].drop("coupon", axis=1).reset_index(drop=True).copy()
markit_uf500 = markit_uf[markit_uf["coupon"]==500].drop("coupon", axis=1).reset_index(drop=True).copy()

# %%
f_dict = {}
dt_list = []
last_update = None

def three_curves(df1, update_live, data_type):
    global f_dict
    global dt_list
    global last_update
    
    # active_tickers = list(set(df1[df1["close_date"]==df1["close_date"].iloc[-1]]["ticker"]))
    # df1 = df1[df1["ticker"].isin(active_tickers)].reset_index(drop=True).copy()
    
    markit_cds = list(set(df1["red"]))
    markit_df1 = df1.copy()
    
    res_codes = { "Full Restructuring": "CR14", "Modified Restructuring": "MR14",
              "Modified-Modified Restructurin": "MM14", "No Restructuring": "XR14"}
    
    excel_df = None
    all_dq = None
    all_temp_cds = None
    
    for rating_col in["IG","HY","EUR_IG","EUR_HY","SNRFIN","SUBFIN","Extras"]:
        dq = pd.read_excel("New CDX Members.xlsx", sheet_name=rating_col)
        dq["Restructuring"] = dq["Restructuring"].apply(lambda x: res_codes[x])
        dq = dq[dq["Actual RED Code"].isin(markit_cds)].reset_index(drop=True).copy()
        dq.rename(columns={"Actual RED Code": "red"}, inplace=True)
        
        if not "Family" in dq.columns:
            dq["Family"] = [rating_col]*len(dq)
            
        if not "tier" in dq.columns:
            dq["tier"] = "SNRFOR" if rating_col != "SUBFIN" else "SUBLT2"
        
        dq["ccy"] = dq["Family"].apply(lambda x: "USD" if x in ["IG","HY"] else "EUR")
        dq = dq.drop(["5Y CDS Ticker","ISIN","RED Code","Company Name","Corp Ticker"],axis=1)
        
        all_dq = pd.concat([all_dq, dq]).drop_duplicates(keep="first").reset_index(drop=True).copy()
    
    unique_all_dq = all_dq.drop("Family",axis=1).drop_duplicates().reset_index(drop=True).copy()
    unique_all_dq.columns = unique_all_dq.columns.str.replace("Restructuring","docclause")
    
    cds_df = pd.merge(left=markit_df1, right = unique_all_dq, on=["red","docclause","tier","ccy"], how="inner")
    cds_df["close_date"] = pd.to_datetime(cds_df["close_date"])
    cds_df = cds_df[cds_df["tenor"]!="Spot"]
    cds_df["tenor"] = cds_df["tenor"].apply(lambda x: eval(x.replace("y","*1").replace("m","*(1/12)")))
    
    cds_df["ticker_red_tier_ccy_docclause"] = (cds_df["ticker"].astype(str) + "_" + cds_df["red"].astype(str) +\
         "_" + cds_df["tier"].astype(str) + "_" + cds_df["ccy"].astype(str) + "_" + cds_df["docclause"].astype(str))
    cds_df = cds_df.drop(["ticker","red","tier","ccy","docclause"],axis=1)
    
    ########################### Only for HY quoted spread df
    if "fee" in cds_df.columns:
        cds_df = cds_df[cds_df["coupon"]==100].drop(["coupon"], axis=1).copy()
        cds_df = cds_df[~pd.isna(cds_df["fee"]) | ~pd.isna(cds_df["calculated_fee"])].reset_index(drop=True).copy()
    
    ########################### Creating map for family
    f = all_dq.drop_duplicates().reset_index(drop=True).copy()
    f1 = f["Issuer Equity"].astype(str) + "_" + f["red"].astype(str) + "_" +\
    f["tier"].astype(str) + "_" + f["ccy"].astype(str)  + "_" + f["Restructuring"].astype(str)
    f2 = f["Family"]
    f_dict = dict(zip(f1,f2))
    
    
    ############################################################################################################## NEW BLOCK
    
    issuers = list(sorted(set(cds_df["ticker_red_tier_ccy_docclause"])))
    last_dt = max(cds_df["close_date"])
    
    all_curves = None
    
    try:
        if not update_live:
            all_curves = pd.read_excel("All CDS Curves Par.xlsx/") ############## made to fail
        for issuer in issuers:
            df = cds_df[cds_df["ticker_red_tier_ccy_docclause"]==issuer]
            df = pd.pivot_table(df, values="spread", index="close_date", columns ="tenor")
            
            if not last_dt in df.index:
                df.loc[last_dt] = [np.nan] * len(df.columns)
            df = df.sort_index().ffill().copy()
            df[f"{issuer}_curve"] = [np.nan] * len(df)
        
            for idx in df.index:
                curve = df.loc[[idx],:].dropna(axis=1)
                curve = curve.iloc[:,:-1].copy()
                x = list((curve.columns))
                x2 = [item**2 for item in x]
                X = np.column_stack([x, x2])
                Y = list(curve.iloc[0])
        
                if len(X) > 2:
                    model = sm.OLS(Y, sm.add_constant(X)).fit()
                    df.loc[idx,f"{issuer}_curve"] = str([model.params[0], model.params[1], model.params[2]])
                    
                    # x_pred = list(np.linspace(min(x), max(x),100))
                    # x_pred2 = [item**2 for item in x_pred]
                    # X_pred = np.column_stack([x_pred, x_pred2])
                    # y_pred = model.predict(sm.add_constant(X_pred))
                    # plt.plot(x, Y)
                    # plt.plot(x_pred, y_pred)
                    # title = f"{issuer} on {str(idx.date())}"
                    # plt.title(title)
                    # # plt.savefig(f"Curve Plots v2/{title}.png")
                    # plt.show()
                    # plt.close()
                    
                else:
                    df.loc[idx,f"{issuer}_curve"] = str([np.nan, np.nan, np.nan])
        
            all_curves = pd.concat([all_curves,df.iloc[:,[-1]]],axis=1)
        all_curves.to_excel(f"All CDS Curves_{data_type}.xlsx")
    except:
        all_curves = pd.read_excel(f"All CDS Curves_{data_type}.xlsx",index_col=0, parse_dates=True)
    
    all_curves1 = all_curves.copy()
    all_curves = all_curves.T.copy()
    all_curves.index.name = "ticker_red_tier_ccy_docclause"
    all_curves.columns = [f'CDS_{item.date()}' for item in all_curves.columns]
    all_curves = all_curves.reset_index(drop=False).copy()
    all_temp_cds = all_curves.copy()
    all_temp_cds["Temp"] = (all_temp_cds["ticker_red_tier_ccy_docclause"].astype(str).\
        str.split("_", n=1).str[1].str.replace("_curve", "", regex=False))
    ############################################################################################################## NEW BLOCK
    
    unique_all_dq["Issuer Equity_red_tier_ccy_docclause"] = (unique_all_dq["Issuer Equity"].astype(str) + "_" + unique_all_dq["red"].astype(str) +\
         "_" + unique_all_dq["tier"].astype(str) + "_" + unique_all_dq["ccy"].astype(str) + "_" + unique_all_dq["docclause"].astype(str))
    unique_all_dq = unique_all_dq.drop(["Issuer Equity","red","tier","ccy","docclause"],axis=1)
    unique_all_dq["Temp"] = unique_all_dq["Issuer Equity_red_tier_ccy_docclause"].astype(str).str.split("_", n=1).str[1]
    
    df2 = pd.merge(left=unique_all_dq, right=all_temp_cds, on="Temp", how="inner").drop(["Temp","ticker_red_tier_ccy_docclause"], axis=1)
    
    ############################################################################################################## NEW BLOCK
    
    markit_to_bbg_tier_map = {"SNRFOR": "Sr Unsecured", "SUBLT2": "Subordinated"}
    
    l1 = [item.split("_")[0] for item in df2["Issuer Equity_red_tier_ccy_docclause"]]
    l2 = [markit_to_bbg_tier_map[item.split("_")[2]] for item in df2["Issuer Equity_red_tier_ccy_docclause"]]
    l3 = [item.split("_")[3] for item in df2["Issuer Equity_red_tier_ccy_docclause"]]
    l4 = [item.split(" ")[0] for item in df2["Bond Name"]]
    bbg_bonds_dict = {}
    
    for i in range(len(l1)):
        bbg_bonds_dict[f"{l1[i]} Equity_{l2[i]}_{l3[i]}"] = l4[i]
        
    ############################################################################################################## NEW BLOCK
    # ##########################################################################This Data was copied to All Bonds sheet
    # bql_list = []
    
    # fl = [f"""=BQL("filter(bonds(['""",
    #       f"""']), payment_rank=='""",
    #       f"""' AND crncy=='""",
    #       f"""')", "id_isin, id_cusip, name, maturity, amt_outstanding")"""]
    
    # for item, key in bbg_bonds_dict.items():
    #     bql_list += [fl[0] + item.split("_")[0] + fl[1] + item.split("_")[1] + fl[2] + item.split("_")[2] + fl[3]]
    
        
    # bql_list = [item.replace("\\", "") for item in bql_list]
    
    # workbook = openpyxl.load_workbook(r"J:\\HY Basis Data.xlsx")
    # sheet = workbook.active
    
    # for row in sheet.iter_rows():
    #     for cell in row:
    #         cell.value = None
    
    # start_col = 1
    # for item in bql_list:
    #     cell = sheet.cell(row=2, column=start_col)
    #     cell.value = item
    #     start_col += 6
    # workbook.save(r"J:\\HY Basis Data.xlsx")
    
    # file_path = r"J:\\HY Basis Data.xlsx"
    # window_title = "HY Basis Data - Excel"
    
    # subprocess.Popen(['start', 'excel', file_path], shell=True)
    # time.sleep(5)
    
    # excel_windows = [window for window in gw.getWindowsWithTitle('Excel')]
    
    # for window in excel_windows:
    #     if window_title in window.title:
    #         # time.sleep(0.5)
    #         window.activate()
    #         break
    
    # time.sleep(45)
    # pyautogui.hotkey('ctrl', 's')
    # time.sleep(1)
    # # pyautogui.hotkey('alt', 'f4')
    
    # time.sleep(1.5)
    
    ############################################################################################################## NEW BLOCK
    
    bonds_map = []
    markit_to_bbg_tier_map_reverse = dict(zip(list(markit_to_bbg_tier_map.values()), list(markit_to_bbg_tier_map.keys())))
    
    for i in range(len(l1)):
        bonds_map += [f"{l1[i]}_{markit_to_bbg_tier_map_reverse[l2[i]]}_{l3[i]}"]
        
    ############################################################################################################## NEW BLOCK
    # df = pd.read_excel("All Bonds.xlsx", sheet_name="All Bonds")
    df = pd.read_excel("All Bonds.xlsx", sheet_name="New All Bonds")
    l5 = [item.split("_")[0].replace(" Equity","") + "_" + markit_to_bbg_tier_map_reverse[item.split("_")[1]] +\
          "_" + item.split("_")[2] for item in list(bbg_bonds_dict.keys())]
    l6 = list(bbg_bonds_dict.values())
    
    all_df = None
    
    for i in range(len(df.columns))[::6]:
        x = df.iloc[:,i:i+6].dropna().copy()
        # try:
        if len(x) > 0:
            x.columns = ['ID','ISIN', "CUSIP", 'Name', 'Maturity','Amt']
            x["Issuer Equity_tier_ccy"] = [l5[int(i/6)]] * len(x)
            x["Bond Name"] = [l6[int(i/6)]] * len(x)
            x["Check Col"] = x.apply(lambda row: row["Name"].split(" ")[0]==row["Bond Name"],axis=1)
            x = x[x["Check Col"]].drop(["Check Col","Bond Name"],axis=1)
            all_df = pd.concat([all_df, x])
        # except:
        #     hello = 1
    
    all_df['Time'] = round(((pd.to_datetime(all_df['Maturity'])-datetime.now()).dt.days/365),2)
    all_df = all_df[all_df["Time"]>=0]
    all_df = all_df[(all_df['Time']>=4) & (all_df['Time']<=10)]
    all_df = all_df[all_df['Amt']>=300*10**6]
    all_df = all_df.reset_index(drop=True)
    excel_df = pd.concat([excel_df, all_df])
    all_df = excel_df.copy()
    
    all_df = all_df.drop_duplicates(keep="first").reset_index(drop=True).copy()
    
    ########################################################################################### 144A and REGS
    
    blist = [f'/isin/{item}@BGN' for item in list(all_df["ISIN"])]
    if update_live and data_type=="Par":
        blist = blp.bdp(tickers=blist, flds=["144A_FLAG","IS_REG_S"])
        blist.to_parquet("BBG 144A.parquet")
    blist = pd.read_parquet("BBG 144A.parquet")
    blist.index = [item.rsplit("/",1)[1].split("@")[0] for item in blist.index]
    
    blist.columns = ["144A","REGS"]
    blist.index.name = "ISIN"
    blist = blist.reset_index()
    blist["REGS_144A"] = blist.apply(lambda row: f'{row["REGS"]}_{row["144A"]}',axis=1)
    order = ["N_N", "Y_N", "Y_Y", "N_Y"]
    
    all_df = pd.merge(left=all_df, right=blist, on="ISIN", how="outer")
    all_df = all_df[[item for item in all_df.columns if not item in ["144A","REGS"]]]
    
    all_df["REGS_144A"] = pd.Categorical(all_df["REGS_144A"], categories=order, ordered=True)
    all_df = all_df.sort_values(by="REGS_144A")
    all_df = all_df[~all_df["Name"].duplicated(keep='first')].drop(["REGS_144A","Time"],axis=1).reset_index(drop=True).copy()
    
    ############################################################################################################## NEW BLOCK
    
    t = [f"/isin/{item}@BGN" for item in list(all_df["ISIN"])]
    if update_live and data_type=="Par":
        bbg = blp.bdh(tickers=t, flds="BLOOMBERG_MID_G_SPREAD", start_date=datetime.now()-timedelta(days=365*5))
        bbg.to_parquet("BBG G_Sprds.parquet")
    bbg = pd.read_parquet("BBG G_Sprds.parquet")
    
    bbg1 = bbg.copy()
    new = []
    for item in bbg1.columns:
        new += ["BBG_" + item[0].replace("/isin/","").replace("@BGN","")]
    bbg1.columns = new
    bbg1.index = pd.to_datetime(bbg1.index)
    
    ############################################################ choose bbg or dq sprds
    
    bbg1.columns = [item.split("_")[1] for item in bbg1.columns]
    bbg1.index = [f"Sprd_{str(item.date())}" for item in bbg1.index]
    bbg1 = bbg1.T.copy()
    bbg1.index.name = "ISIN"
    bbg1 = bbg1.reset_index(drop=False).copy()
    
    ############################################################################################################## NEW BLOCK
    
    df2a = df2.drop(["Primary ISIN","Bond Name"],axis=1).copy()
    df2a["Issuer Equity_tier_ccy"] = [item.split("_")[0] + "_" + item.split("_")[2] +\
                   "_" + item.split("_")[3] for item in df2a["Issuer Equity_red_tier_ccy_docclause"]]
    # df2a = df2a.replace(np.nan,"[np.nan, np.nan, np.nan]")
    df3 = pd.merge(left=all_df, right=df2a, on="Issuer Equity_tier_ccy",\
                   how="inner").drop(["ID","Amt","Issuer Equity_tier_ccy"],axis=1).copy()
    
    for dt in pd.to_datetime(bbg.index):
        df3[f'Mat_Time_{dt.date()}'] = [((pd.to_datetime(item) - dt).days/365) for item in df3["Maturity"]]
    
    df4A = df3.copy()
    dt_list = [item.replace("CDS_","") for item in df4A.columns if item.startswith("CDS_")]
    
    def safe_literal_eval(x):
        try:
            return ast.literal_eval(x) if isinstance(x, str) else [np.nan, np.nan, np.nan]
        except (ValueError, SyntaxError):
            return [np.nan, np.nan, np.nan]
    
    for dt in dt_list:
        if f"Mat_Time_{dt}" in df4A.columns and f"CDS_{dt}" in df4A.columns:
            cds_values = df4A[f'CDS_{dt}'].apply(safe_literal_eval)
            mat_time = df4A[f'Mat_Time_{dt}']
    
            df4A[f'Mat_Matched_CDS_{dt}'] = (
                cds_values.apply(lambda x: x[0]) +
                mat_time * cds_values.apply(lambda x: x[1]) +
                mat_time**2 * cds_values.apply(lambda x: x[2]))
    
    df4 = df4A[["ISIN","CUSIP","Name","Maturity","Issuer Equity_red_tier_ccy_docclause"] +\
        [col for col in df4A.columns if col.startswith("Mat_Matched_CDS")]].copy()
    
    ############################################################################################################## NEW BLOCK
    
    #################################################### Duration Data
    
    dq_bonds = ['US50077LBF22','US49456BAG68','US49456BAR24','US49456BAV36','US49456BAX91','US500255AX28','US50077LAL09','US50077LAV80','US50077LBN55','US526057CY87','US530715AJ01','US501044DV05','US48666KAY55','US48666KAZ21','US48666KBA60','US620076BT59','US626717AP72','US63938CAN83','US63938CAP32','US63938CAQ15','US651229BD74','US549271AF19','US55262CAJ99','US552676AT59','US552676AU23','US552953CJ87','US552953CK50','US55342UAM62','US55616XAM92','US58013MFQ24','US382550BJ95','US382550BK68','US382550BR12','US382550BS94','US404119CA57','US404119CC14','US404119CK30','US404119CQ00','US404119CT49','US337932AL12','US337932AP26','US345370CA64','US345370CX67','US345370DA55','US345370DB39','US35671DBJ37','US35671DCD57','US35671DCF06','US35671DCH61','US36186CBY84','US36962GXZ26','US370334CL64','US370334CT90','US37045VAH33','US37045VAY65','US37045VAZ31','US404119DB22','US404121AK12','US458140BR09','US651229BE57','US44107TBC99','US40434LAN55','US42307TAG31','US432833AF84','US437076CB65','US44106MAY84','US44106MBB72','US44107TAY29','US44107TAZ93','US651229BF23','US89352HBA68','US893830AF64','US902494AZ66','US911363AM11','US911365BL76','US911365BP80','US91324PEJ75','US911365BN33','US88947EAU47','US85172FAR01','US87264ABF12','US87264ABT16','US87264ABW45','US87264ABX28','US87264ACB98','US87264ACQ67','US87264ACV52','US87264ADT97','US87901JAH86','US88033GAV23','US88167AAR23','US88167AAS06','US88167AAT88','US962166BR41','US963320AY28','US963320AZ92','US963320BA33','US963320BC98','US963320BD71','US963320BE54','US969457BB59','US969457BM15','US969457BZ28','US969457CJ76','US988498AN16','US988498AP63','US988498AR20','XS0161100515','US931142FC22','US92343VEU44','US92343VFX73','US92343VGN82','US92343VGY48','US92343VGZ13','US925524AH30','US925524AV24','US92556HAB33','US92556HAD98','US680665AK27','US682691AA80','US682691AE03','US682691AF77','US682691AG50','US682691AJ99','US682691AK62','US682691AL46','US68389XBV64','US68389XCE31','US68389XCH61','US68389XCJ28','US69047QAC69','US674599EL59','US674599EK76','US65339KCU25','US65339KDJ60','US65339KDK34','US65339KDL17',
    'US674599DD43','US674599DE26','US674599EA94','US674599ED34','US674599EF81','US698900AG20','US75513ECR09','US78355HLC15','US78442FAZ18','US81761LAE20','US828807DT11','US716973AD41','US716973AE24','US717081EW90','US745867AM30','US745867AP60','US745867AT82','US74834LBC37','US30212PBH73','US1248EPCN14','US012873AK13','US012873AH83','US11135FAS02','US11135FBD24','US136385AE19','US134429BJ73','US126650DJ69','US00206RMM15','US126650DU15','US126650ED80','US031162DQ06','US026874DC84','US02406PBB58','US023551AM66','US023551AJ38','US097023CN34','US097023CP81','US097023CY98','US097023DC69','US097023DR39','US097023CJ22','US097023DS12','US023135AP19','US097023AU94','US023551AF16','US058498AW66','US058498AX40','US058498BA38','US07556QBT13','US08652BAB53','US071813BY49','US254709AS70','US244199BJ37','US247361ZT81','US251799AA02','US25179MBF95','US25179SAD27','US247361A329','US23331ABT51','US29273VAU44','US29273VBA70','US29278NAQ60','US30161NAX93','US30212PAR64','US29273VAT70','US29273RBE80','US28368EAD85','US28368EAE68','US292480AM22','US29273VAQ32','US292505AD65','US20030NEE76','US20030NDG34','US20030NBH35','US15089QAZ72','US15089QBA13','US15089QAY08','US00206RCP55','US15089QAP90','US00130HCG83','US15089QAX25','US205887AX04','XS2774392638','XS2655993033','XS3037720227','XS3023963534','XS3126635039','XS3106096178','XS3105513769','XS3091660194','XS2872799734','XS2870878456','XS2864439158','XS2811097075','XS2802883731','XS2826718087','XS2929387996','XS2922654418','XS2914769299','XS2904791774','XS2385393587','XS2116386132','XS2432162654','XS2247549731','XS2189766970','XS2300293003','XS2290544068','XS2056491587','XS2488809612','XS2010039894','FR001400WJR8','FR001400PAJ8','DE000A383HC1','CH0494734418','CH0591979627','DE000A4DFLQ6','US46284VAQ41','US501797AW48','US513272AD65','US513272AE49','US53219LAX73','US46284VAN10','US55617LAR33','US55617LAS16','US62482BAB80','US46284VAL53','US44332PAJ03','US46284VAF85','US37441QAA94','US428040DB25','US431318AV64','US431318AY04','US431318AZ78','US431318BC74','US431318BE31','US431318BG88','US432833AL52','US432833AN19','US432833AQ40','US432833AR23','US432833AS06','US44332PAG63','US62886HBP55','US46284VAJ08','US62886HBR12','US629377CS98','US629377CR16','US780153BV38','US780153BW11','US81211KAK60','US812127AB45','US812127AC28','US82967NBG25','US82967NBM92','US853496AG21','US853496AH04','US893830BZ10','US911365BR47','US92840VAP76','US92840VAR33','US947075AU14','US988498AL59','US780153BU54','US75606DAQ43','US737446AV69','US629377CW01','US629377CX83','US62957HAP01','US62957HAQ83','US63861CAF68','US64110LAU08','US64110LAV80','US677347CH71','US680665AN65','US68622FAB76','US68622TAB70','US737446AP91','US737446AQ74','US737446AR57','US737446AX26','US364760AQ18','US11135FBF71','US11135FBH38','US11135FBK66''US11135FBL40','US11135FBT75','US1248EPCD32','US1248EPCE15','US1248EPCK74','US1248EPCL57','US1248EPCP61','US1248EPCQ45''US1248EPCS01','US1248EPCT83','US126307BA42','US126307BB25','US103304BV23','US126307BD80','US097751CD18','US097751CB51','US00130HCC79','US01883LAD55','US01883LAH69','US03743QAQ10','US04433LAA08','US05368VAA44','US05368VAB27','US053773BH95','US053773BJ51','US053773BK25','US071734AJ60','US071734AL17','US097751AL51','US097751CA78','US097751CC35','US126307BF39','US126307BH94','US126307BK24','US224044CS42','US226373AT56','US23918KAS78','US23918KAT51','US23918KAW80','US23918KAY47','US185899AS01','US185899AR28','US12769GAA85','US12769GAD25','US131347CQ78','US143658BX94','US143658BY77','US364760AP35','US143658BZ43','US17888HAB96','US17888HAC79','US17888HAD52','US185899AL57','US185899AN14','US185899AP61','US185899AQ45','US143658CA82']
    
    dq_bonds = list(df4["ISIN"])
    all_labels = dict(zip(df4["ISIN"],[f"DB(CREDIT,HY,BOND,{item},MDUR)" for item in df4["CUSIP"]]))
    
    labels = {}
    for item in dq_bonds:
        labels[f"{item}_Dur"] = all_labels[item]
    
    try:
        if not update_live or data_type != "Par":
            df1 = pd.read_excel("DQ HY Duration Data.xlsx/",index_col=0, parse_dates=True)
        dq = DataQuery(
            client_id='jbAIMF2Tkp0JO3sc',
            client_secret='d7qfzgt55pddjs352sgxosFyI4t2eja07k7opbi6wg9oqjc1OjkdAksn1btmnugeMjchcx2vwTsJupw',
            # calendar = 'CAL_USBANK',
        )
        
        job = dq.create_job(expressions = list(labels.values()))
        dq.start_date = str((datetime.now()-timedelta(days=5*365)).date())
        job.execute(alert_long_requests='ignore')
        df = job.to_pivot_table()
        df = df.T
        df.index.name = 'Date'
        df.index = pd.to_datetime(df.index, format='%Y%m%d').date
        df.columns.name = None
        
        df1 = pd.DataFrame()
        for key in labels:
            df1[key] = df[labels[key]]
        
        df1 = df1[list(labels.keys())].copy()
        clear_output(wait=False)
        df1.dropna(axis=1, how='all', inplace=True)
        df1.to_excel("DQ HY Duration Data.xlsx")
    except:
        df1 = pd.read_excel("DQ HY Duration Data.xlsx",index_col=0, parse_dates=True)
    
    ############################################################################################################## NEW BLOCK
    
    df1 = pd.read_excel("DQ HY Duration Data.xlsx",index_col=0, parse_dates=True)
    df1a = df1.copy()
    df1a = df1a.T
    df1a.index = df1a.index.str.replace("_Dur","")
    df1a.columns = ["Dur_" + str(item.date()) for item in df1a.columns]
    df1a.index.name="ISIN"
    df1a = df1a.reset_index()
    
    df4B = pd.merge(left=df4, right=df1a, on="ISIN", how="outer")
    
    ####################################################################
    
    t = [f"/isin/{item}@BGN" for item in list(all_df["ISIN"])]
    if update_live and data_type == "Par" :
        px = blp.bdh(tickers=t, flds="PX_LAST", start_date=datetime.now()-timedelta(days=365*7))
        px.to_parquet("BBG PX.parquet")
    px = pd.read_parquet("BBG PX.parquet")
    
    new = []
    for item in px.columns:
        new += [item[0].replace("/isin/","").replace("@BGN","")]
    px.columns = new
    px = px.T
    px.columns = ["Price_" + str(item) for item in px.columns]
    px.index.name= "ISIN"
    px = px.reset_index()
    
    ####################################################
    df5a = pd.merge(left=df4B, right=bbg1, on="ISIN", how="inner")
    last_update = max(dt_list)
    for dt in dt_list:
        try:
            df5a[f"Basis_{dt}"] = df5a[f"Mat_Matched_CDS_{dt}"] - df5a[f"Sprd_{dt}"]
        except:
            hello = 1
    
    df5a = pd.merge(left=df5a, right=px, on="ISIN", how="inner")

    return df5a.copy()
    ############################################################################################################## NEW BLOCK

# %%
par = three_curves(markit_par, global_update_live, "Par")
uf100 = three_curves(markit_uf100, global_update_live, "100")
uf100 = uf100[["ISIN"]+[col for col in uf100.columns if col.startswith("Mat_Matched_CDS")]]
uf100.columns = uf100.columns.str.replace("CDS","UF100")

uf500 = three_curves(markit_uf500, global_update_live, "500")
uf500 = uf500[["ISIN"]+[col for col in uf500.columns if col.startswith("Mat_Matched_CDS")]]
uf500.columns = uf500.columns.str.replace("CDS","UF500")
uf = pd.merge(left = uf100, right = uf500, on="ISIN", how="outer")
# Out:
# 2025-10-18 09:27:33.396670+0000 UTC [INFO] pydataquery: DataQuery initialized with client_id='jbAIMF2Tkp0JO3sc'
# 2025-10-18 09:27:33.412306+0000 UTC [INFO] pydataquery: Set preferred_timezone='UTC'. current_time='2025-10-18 09:27:33.412306+0000 UTC'
# 2025-10-18 09:27:33.412306+0000 UTC [INFO] pydataquery: DataQuery default attribute `start_date` set to '2020-10-19'
# 2025-10-18 09:27:33.412306+0000 UTC [WARNING] pydataquery: Potential long process time due to date range exceeding two years: 5.0 years.
# 2025-10-18 09:27:33.412306+0000 UTC [INFO] pydataquery: DataQuery default attribute `start_date` set to '2020-10-19' (client_id='jbAIMF2Tkp0JO3sc')
# 2025-10-18 09:27:33.412306+0000 UTC [INFO] pydataquery: Execution started
# 2025-10-18 09:27:33.412306+0000 UTC [INFO] pydataquery: Prepared 228 API requests for 1,518 expressions of 4 year(s) 364 day(s): start_date=20201019, end_date=20251017
# 2025-10-18 09:27:33.412306+0000 UTC [INFO] pydataquery: Sending 1/228 API request
# 2025-10-18 09:27:33.412306+0000 UTC [INFO] pydataquery: Generating a new OAuth access token for client_id=jbAIMF2Tkp0JO3sc
# 2025-10-18 09:27:34.029498+0000 UTC [INFO] pydataquery: Generated an OAuth access token for client_id=jbAIMF2Tkp0JO3sc in 0.60 seconds. The token expires_at=2025-10-18 11:27:33+0000 UTC
# 2025-10-18 09:27:38.397225+0000 UTC [INFO] pydataquery: Received API response in 3.90367 seconds with response code 200
# 2025-10-18 09:27:38.404824+0000 UTC [INFO] pydataquery: Sending 2/228 API request
# 2025-10-18 09:27:42.700976+0000 UTC [INFO] pydataquery: Received API response in 3.891159 seconds with response code 200
# 2025-10-18 09:27:42.707484+0000 UTC [INFO] pydataquery: Sending 3/228 API request
# 2025-10-18 09:27:47.389118+0000 UTC [INFO] pydataquery: Received API response in 4.414838 seconds with response code 200
# 2025-10-18 09:27:47.404770+0000 UTC [INFO] pydataquery: Sending 4/228 API request
# 2025-10-18 09:27:51.898501+0000 UTC [INFO] pydataquery: Received API response in 4.160286 seconds with response code 200
# 2025-10-18 09:27:51.914570+0000 UTC [INFO] pydataquery: Sending 5/228 API request
# 2025-10-18 09:27:56.667632+0000 UTC [INFO] pydataquery: Received API response in 4.417574 seconds with response code 200
# 2025-10-18 09:27:56.667632+0000 UTC [INFO] pydataquery: Sending 6/228 API request
# 2025-10-18 09:28:00.102658+0000 UTC [INFO] pydataquery: Received API response in 3.326115 seconds with response code 200
# 2025-10-18 09:28:00.102658+0000 UTC [INFO] pydataquery: Sending 7/228 API request
# 2025-10-18 09:28:04.368089+0000 UTC [INFO] pydataquery: Received API response in 4.076395 seconds with response code 200
# 2025-10-18 09:28:04.378678+0000 UTC [INFO] pydataquery: Sending 8/228 API request
# 2025-10-18 09:28:08.608750+0000 UTC [INFO] pydataquery: Received API response in 4.044454 seconds with response code 200
# 2025-10-18 09:28:08.624382+0000 UTC [INFO] pydataquery: Sending 9/228 API request
# 2025-10-18 09:28:12.773247+0000 UTC [INFO] pydataquery: Received API response in 4.027487 seconds with response code 200
# 2025-10-18 09:28:12.777769+0000 UTC [INFO] pydataquery: Sending 10/228 API request
# 2025-10-18 09:28:13.658566+0000 UTC [INFO] pydataquery: Received API response in 0.799898 seconds with response code 200
# 2025-10-18 09:28:13.664078+0000 UTC [INFO] pydataquery: Sending 11/228 API request
# 2025-10-18 09:28:16.156152+0000 UTC [INFO] pydataquery: Received API response in 2.297892 seconds with response code 200
# 2025-10-18 09:28:16.156152+0000 UTC [INFO] pydataquery: Sending 12/228 API request
# 2025-10-18 09:28:16.971837+0000 UTC [INFO] pydataquery: Received API response in 0.801574 seconds with response code 200
# 2025-10-18 09:28:16.978394+0000 UTC [INFO] pydataquery: Sending 13/228 API request
# 2025-10-18 09:28:19.185484+0000 UTC [INFO] pydataquery: Received API response in 2.038145 seconds with response code 200
# 2025-10-18 09:28:19.191067+0000 UTC [INFO] pydataquery: Sending 14/228 API request
# 2025-10-18 09:28:21.483667+0000 UTC [INFO] pydataquery: Received API response in 2.002203 seconds with response code 200
# 2025-10-18 09:28:21.500294+0000 UTC [INFO] pydataquery: Sending 15/228 API request
# 2025-10-18 09:28:25.373820+0000 UTC [INFO] pydataquery: Received API response in 3.692383 seconds with response code 200
# 2025-10-18 09:28:25.388853+0000 UTC [INFO] pydataquery: Sending 16/228 API request
# 2025-10-18 09:28:29.084412+0000 UTC [INFO] pydataquery: Received API response in 3.397788 seconds with response code 200
# 2025-10-18 09:28:29.084412+0000 UTC [INFO] pydataquery: Sending 17/228 API request
# 2025-10-18 09:28:32.171676+0000 UTC [INFO] pydataquery: Received API response in 2.781943 seconds with response code 200
# 2025-10-18 09:28:32.171676+0000 UTC [INFO] pydataquery: Sending 18/228 API request
# 2025-10-18 09:28:36.227743+0000 UTC [INFO] pydataquery: Received API response in 3.875927 seconds with response code 200
# 2025-10-18 09:28:36.238751+0000 UTC [INFO] pydataquery: Sending 19/228 API request
# 2025-10-18 09:28:41.993908+0000 UTC [INFO] pydataquery: Received API response in 5.410259 seconds with response code 200
# 2025-10-18 09:28:42.009621+0000 UTC [INFO] pydataquery: Sending 20/228 API request
# 2025-10-18 09:28:44.860840+0000 UTC [INFO] pydataquery: Received API response in 2.445108 seconds with response code 200
# 2025-10-18 09:28:44.860840+0000 UTC [INFO] pydataquery: Sending 21/228 API request
# 2025-10-18 09:28:46.983646+0000 UTC [INFO] pydataquery: Received API response in 1.848444 seconds with response code 200
# 2025-10-18 09:28:46.989240+0000 UTC [INFO] pydataquery: Sending 22/228 API request
# 2025-10-18 09:28:49.217643+0000 UTC [INFO] pydataquery: Received API response in 1.894344 seconds with response code 200
# 2025-10-18 09:28:49.217643+0000 UTC [INFO] pydataquery: Sending 23/228 API request
# 2025-10-18 09:28:54.725003+0000 UTC [INFO] pydataquery: Received API response in 5.161302 seconds with response code 200
# 2025-10-18 09:28:54.725003+0000 UTC [INFO] pydataquery: Sending 24/228 API request
# 2025-10-18 09:28:59.532096+0000 UTC [INFO] pydataquery: Received API response in 4.598388 seconds with response code 200
# 2025-10-18 09:28:59.539603+0000 UTC [INFO] pydataquery: Sending 25/228 API request
# 2025-10-18 09:29:01.786829+0000 UTC [INFO] pydataquery: Received API response in 1.908126 seconds with response code 200
# 2025-10-18 09:29:01.786829+0000 UTC [INFO] pydataquery: Sending 26/228 API request
# 2025-10-18 09:29:05.284769+0000 UTC [INFO] pydataquery: Received API response in 3.16215 seconds with response code 200
# 2025-10-18 09:29:05.284769+0000 UTC [INFO] pydataquery: Sending 27/228 API request
# 2025-10-18 09:29:07.106361+0000 UTC [INFO] pydataquery: Received API response in 1.6151 seconds with response code 200
# 2025-10-18 09:29:07.122422+0000 UTC [INFO] pydataquery: Sending 28/228 API request
# 2025-10-18 09:29:10.963053+0000 UTC [INFO] pydataquery: Received API response in 3.372179 seconds with response code 200
# 2025-10-18 09:29:10.963053+0000 UTC [INFO] pydataquery: Sending 29/228 API request
# 2025-10-18 09:29:18.113918+0000 UTC [INFO] pydataquery: Received API response in 6.677521 seconds with response code 200
# 2025-10-18 09:29:18.123926+0000 UTC [INFO] pydataquery: Sending 30/228 API request
# 2025-10-18 09:29:22.992476+0000 UTC [INFO] pydataquery: Received API response in 4.634249 seconds with response code 200
# 2025-10-18 09:29:23.002490+0000 UTC [INFO] pydataquery: Sending 31/228 API request
# 2025-10-18 09:29:29.071320+0000 UTC [INFO] pydataquery: Received API response in 5.658747 seconds with response code 200
# 2025-10-18 09:29:29.071320+0000 UTC [INFO] pydataquery: Sending 32/228 API request
# 2025-10-18 09:29:32.568856+0000 UTC [INFO] pydataquery: Received API response in 3.141356 seconds with response code 200
# 2025-10-18 09:29:32.584265+0000 UTC [INFO] pydataquery: Sending 33/228 API request
# 2025-10-18 09:29:37.965430+0000 UTC [INFO] pydataquery: Received API response in 5.143968 seconds with response code 200
# 2025-10-18 09:29:37.975448+0000 UTC [INFO] pydataquery: Sending 34/228 API request
# 2025-10-18 09:29:43.068831+0000 UTC [INFO] pydataquery: Received API response in 4.7998 seconds with response code 200
# 2025-10-18 09:29:43.083927+0000 UTC [INFO] pydataquery: Sending 35/228 API request
# 2025-10-18 09:29:48.082911+0000 UTC [INFO] pydataquery: Received API response in 4.701321 seconds with response code 200
# 2025-10-18 09:29:48.082911+0000 UTC [INFO] pydataquery: Sending 36/228 API request
# 2025-10-18 09:29:49.270368+0000 UTC [INFO] pydataquery: Received API response in 1.115006 seconds with response code 200
# 2025-10-18 09:29:49.270368+0000 UTC [INFO] pydataquery: Sending 37/228 API request
# 2025-10-18 09:29:55.525725+0000 UTC [INFO] pydataquery: Received API response in 5.905591 seconds with response code 200
# 2025-10-18 09:29:55.541350+0000 UTC [INFO] pydataquery: Sending 38/228 API request
# 2025-10-18 09:30:01.475492+0000 UTC [INFO] pydataquery: Received API response in 5.642023 seconds with response code 200
# 2025-10-18 09:30:01.475492+0000 UTC [INFO] pydataquery: Sending 39/228 API request
# 2025-10-18 09:30:06.380599+0000 UTC [INFO] pydataquery: Received API response in 4.78408 seconds with response code 200
# 2025-10-18 09:30:06.396219+0000 UTC [INFO] pydataquery: Sending 40/228 API request
# 2025-10-18 09:30:11.650999+0000 UTC [INFO] pydataquery: Received API response in 5.045418 seconds with response code 200
# 2025-10-18 09:30:11.666641+0000 UTC [INFO] pydataquery: Sending 41/228 API request
# 2025-10-18 09:30:16.190910+0000 UTC [INFO] pydataquery: Received API response in 4.124447 seconds with response code 200
# 2025-10-18 09:30:16.206608+0000 UTC [INFO] pydataquery: Sending 42/228 API request
# 2025-10-18 09:30:18.945103+0000 UTC [INFO] pydataquery: Received API response in 2.5439 seconds with response code 200
# 2025-10-18 09:30:18.961302+0000 UTC [INFO] pydataquery: Sending 43/228 API request
# 2025-10-18 09:30:25.694474+0000 UTC [INFO] pydataquery: Received API response in 6.3298 seconds with response code 200
# 2025-10-18 09:30:25.699569+0000 UTC [INFO] pydataquery: Sending 44/228 API request
# 2025-10-18 09:30:30.269346+0000 UTC [INFO] pydataquery: Received API response in 4.171132 seconds with response code 200
# 2025-10-18 09:30:30.269346+0000 UTC [INFO] pydataquery: Sending 45/228 API request
# 2025-10-18 09:30:35.841511+0000 UTC [INFO] pydataquery: Received API response in 5.297668 seconds with response code 200
# 2025-10-18 09:30:35.841511+0000 UTC [INFO] pydataquery: Sending 46/228 API request
# 2025-10-18 09:30:40.521228+0000 UTC [INFO] pydataquery: Received API response in 4.33925 seconds with response code 200
# 2025-10-18 09:30:40.534290+0000 UTC [INFO] pydataquery: Sending 47/228 API request
# 2025-10-18 09:30:45.124187+0000 UTC [INFO] pydataquery: Received API response in 4.258219 seconds with response code 200
# 2025-10-18 09:30:45.136781+0000 UTC [INFO] pydataquery: Sending 48/228 API request
# 2025-10-18 09:30:49.394704+0000 UTC [INFO] pydataquery: Received API response in 4.060425 seconds with response code 200
# 2025-10-18 09:30:49.400218+0000 UTC [INFO] pydataquery: Sending 49/228 API request
# 2025-10-18 09:30:55.829555+0000 UTC [INFO] pydataquery: Received API response in 6.024327 seconds with response code 200
# 2025-10-18 09:30:55.829555+0000 UTC [INFO] pydataquery: Sending 50/228 API request
# 2025-10-18 09:31:01.013032+0000 UTC [INFO] pydataquery: Received API response in 4.773714 seconds with response code 200
# 2025-10-18 09:31:01.022128+0000 UTC [INFO] pydataquery: Sending 51/228 API request
# 2025-10-18 09:31:04.220988+0000 UTC [INFO] pydataquery: Received API response in 3.053964 seconds with response code 200
# 2025-10-18 09:31:04.236884+0000 UTC [INFO] pydataquery: Sending 52/228 API request
# 2025-10-18 09:31:17.145309+0000 UTC [INFO] pydataquery: Received API response in 12.828952 seconds with response code 200
# 2025-10-18 09:31:17.145309+0000 UTC [INFO] pydataquery: Sending 53/228 API request
# 2025-10-18 09:31:19.626409+0000 UTC [INFO] pydataquery: Received API response in 2.298024 seconds with response code 200
# 2025-10-18 09:31:19.637432+0000 UTC [INFO] pydataquery: Sending 54/228 API request
# 2025-10-18 09:31:21.781891+0000 UTC [INFO] pydataquery: Received API response in 2.027553 seconds with response code 200
# 2025-10-18 09:31:21.781891+0000 UTC [INFO] pydataquery: Sending 55/228 API request
# 2025-10-18 09:31:25.430019+0000 UTC [INFO] pydataquery: Received API response in 3.382885 seconds with response code 200
# 2025-10-18 09:31:25.445660+0000 UTC [INFO] pydataquery: Sending 56/228 API request
# 2025-10-18 09:31:28.976692+0000 UTC [INFO] pydataquery: Received API response in 3.299783 seconds with response code 200
# 2025-10-18 09:31:28.976692+0000 UTC [INFO] pydataquery: Sending 57/228 API request
# 2025-10-18 09:31:31.131925+0000 UTC [INFO] pydataquery: Received API response in 2.017765 seconds with response code 200
# 2025-10-18 09:31:31.131925+0000 UTC [INFO] pydataquery: Sending 58/228 API request
# 2025-10-18 09:31:33.381375+0000 UTC [INFO] pydataquery: Received API response in 2.030375 seconds with response code 200
# 2025-10-18 09:31:33.381375+0000 UTC [INFO] pydataquery: Sending 59/228 API request
# 2025-10-18 09:31:35.105117+0000 UTC [INFO] pydataquery: Received API response in 1.525358 seconds with response code 200
# 2025-10-18 09:31:35.105117+0000 UTC [INFO] pydataquery: Sending 60/228 API request
# 2025-10-18 09:31:36.528512+0000 UTC [INFO] pydataquery: Received API response in 1.308901 seconds with response code 200
# 2025-10-18 09:31:36.544119+0000 UTC [INFO] pydataquery: Sending 61/228 API request
# 2025-10-18 09:31:39.298626+0000 UTC [INFO] pydataquery: Received API response in 2.534876 seconds with response code 200
# 2025-10-18 09:31:39.298626+0000 UTC [INFO] pydataquery: Sending 62/228 API request
# 2025-10-18 09:31:42.059041+0000 UTC [INFO] pydataquery: Received API response in 2.55674 seconds with response code 200
# 2025-10-18 09:31:42.070487+0000 UTC [INFO] pydataquery: Sending 63/228 API request
# 2025-10-18 09:31:43.669660+0000 UTC [INFO] pydataquery: Received API response in 1.510112 seconds with response code 200
# 2025-10-18 09:31:43.685007+0000 UTC [INFO] pydataquery: Sending 64/228 API request
# 2025-10-18 09:31:47.626101+0000 UTC [INFO] pydataquery: Received API response in 3.515317 seconds with response code 200
# 2025-10-18 09:31:47.626101+0000 UTC [INFO] pydataquery: Sending 65/228 API request
# 2025-10-18 09:31:54.685476+0000 UTC [INFO] pydataquery: Received API response in 6.993337 seconds with response code 200
# 2025-10-18 09:31:54.691104+0000 UTC [INFO] pydataquery: Sending 66/228 API request
# 2025-10-18 09:32:11.169707+0000 UTC [INFO] pydataquery: Received API response in 16.486102 seconds with response code 200
# 2025-10-18 09:32:11.185806+0000 UTC [INFO] pydataquery: Sending 67/228 API request
# 2025-10-18 09:32:23.262273+0000 UTC [INFO] pydataquery: Received API response in 12.079504 seconds with response code 200
# 2025-10-18 09:32:23.272279+0000 UTC [INFO] pydataquery: Sending 68/228 API request
# 2025-10-18 09:32:31.615640+0000 UTC [INFO] pydataquery: Received API response in 8.341635 seconds with response code 200
# 2025-10-18 09:32:31.615640+0000 UTC [INFO] pydataquery: Sending 69/228 API request
# 2025-10-18 09:32:42.212038+0000 UTC [INFO] pydataquery: Received API response in 10.59178 seconds with response code 200
# 2025-10-18 09:32:42.222842+0000 UTC [INFO] pydataquery: Sending 70/228 API request
# 2025-10-18 09:32:50.626656+0000 UTC [INFO] pydataquery: Received API response in 8.399764 seconds with response code 200
# 2025-10-18 09:32:50.626656+0000 UTC [INFO] pydataquery: Sending 71/228 API request
# 2025-10-18 09:32:58.965230+0000 UTC [INFO] pydataquery: Received API response in 8.34324 seconds with response code 200
# 2025-10-18 09:32:58.981432+0000 UTC [INFO] pydataquery: Sending 72/228 API request
# 2025-10-18 09:33:07.309914+0000 UTC [INFO] pydataquery: Received API response in 8.330846 seconds with response code 200
# 2025-10-18 09:33:07.309914+0000 UTC [INFO] pydataquery: Sending 73/228 API request
# 2025-10-18 09:33:15.731493+0000 UTC [INFO] pydataquery: Received API response in 8.404859 seconds with response code 200
# 2025-10-18 09:33:15.731493+0000 UTC [INFO] pydataquery: Sending 74/228 API request
# 2025-10-18 09:33:24.093610+0000 UTC [INFO] pydataquery: Received API response in 8.355893 seconds with response code 200
# 2025-10-18 09:33:24.093610+0000 UTC [INFO] pydataquery: Sending 75/228 API request
# 2025-10-18 09:33:48.737732+0000 UTC [INFO] pydataquery: Received API response in 24.368137 seconds with response code 200
# 2025-10-18 09:33:48.737732+0000 UTC [INFO] pydataquery: Sending 76/228 API request
# 2025-10-18 09:33:53.741589+0000 UTC [INFO] pydataquery: Received API response in 4.827621 seconds with response code 200
# 2025-10-18 09:33:53.741589+0000 UTC [INFO] pydataquery: Sending 77/228 API request
# 2025-10-18 09:33:58.976618+0000 UTC [INFO] pydataquery: Received API response in 4.892078 seconds with response code 200
# 2025-10-18 09:33:58.976618+0000 UTC [INFO] pydataquery: Sending 78/228 API request
# 2025-10-18 09:34:03.807814+0000 UTC [INFO] pydataquery: Received API response in 4.627654 seconds with response code 200
# 2025-10-18 09:34:03.817831+0000 UTC [INFO] pydataquery: Sending 79/228 API request
# 2025-10-18 09:34:17.366420+0000 UTC [INFO] pydataquery: Received API response in 13.150195 seconds with response code 200
# 2025-10-18 09:34:17.366420+0000 UTC [INFO] pydataquery: Sending 80/228 API request
# 2025-10-18 09:34:23.345153+0000 UTC [INFO] pydataquery: Received API response in 5.632755 seconds with response code 200
# 2025-10-18 09:34:23.350664+0000 UTC [INFO] pydataquery: Sending 81/228 API request
# 2025-10-18 09:34:28.674062+0000 UTC [INFO] pydataquery: Received API response in 5.126626 seconds with response code 200
# 2025-10-18 09:34:28.674062+0000 UTC [INFO] pydataquery: Sending 82/228 API request
# 2025-10-18 09:34:48.156569+0000 UTC [INFO] pydataquery: Received API response in 19.141775 seconds with response code 200
# 2025-10-18 09:34:48.161260+0000 UTC [INFO] pydataquery: Sending 83/228 API request
# 2025-10-18 09:34:53.149725+0000 UTC [INFO] pydataquery: Received API response in 4.704393 seconds with response code 200
# 2025-10-18 09:34:53.181707+0000 UTC [INFO] pydataquery: Sending 84/228 API request
# 2025-10-18 09:34:57.753467+0000 UTC [INFO] pydataquery: Received API response in 4.385482 seconds with response code 200
# 2025-10-18 09:34:57.753467+0000 UTC [INFO] pydataquery: Sending 85/228 API request
# 2025-10-18 09:35:02.704769+0000 UTC [INFO] pydataquery: Received API response in 4.65992 seconds with response code 200
# 2025-10-18 09:35:02.716861+0000 UTC [INFO] pydataquery: Sending 86/228 API request
# 2025-10-18 09:35:07.778935+0000 UTC [INFO] pydataquery: Received API response in 4.76031 seconds with response code 200
# 2025-10-18 09:35:07.789038+0000 UTC [INFO] pydataquery: Sending 87/228 API request
# 2025-10-18 09:35:12.349478+0000 UTC [INFO] pydataquery: Received API response in 4.388339 seconds with response code 200
# 2025-10-18 09:35:12.349478+0000 UTC [INFO] pydataquery: Sending 88/228 API request
# 2025-10-18 09:35:17.667886+0000 UTC [INFO] pydataquery: Received API response in 5.005745 seconds with response code 200
# 2025-10-18 09:35:17.667886+0000 UTC [INFO] pydataquery: Sending 89/228 API request
# 2025-10-18 09:35:19.777606+0000 UTC [INFO] pydataquery: Received API response in 1.80885 seconds with response code 200
# 2025-10-18 09:35:19.793303+0000 UTC [INFO] pydataquery: Sending 90/228 API request
# 2025-10-18 09:35:33.167756+0000 UTC [INFO] pydataquery: Received API response in 13.196712 seconds with response code 200
# 2025-10-18 09:35:33.171276+0000 UTC [INFO] pydataquery: Sending 91/228 API request
# 2025-10-18 09:35:38.594576+0000 UTC [INFO] pydataquery: Received API response in 5.12499 seconds with response code 200
# 2025-10-18 09:35:38.604159+0000 UTC [INFO] pydataquery: Sending 92/228 API request
# 2025-10-18 09:35:43.965327+0000 UTC [INFO] pydataquery: Received API response in 5.070342 seconds with response code 200
# 2025-10-18 09:35:43.965327+0000 UTC [INFO] pydataquery: Sending 93/228 API request
# 2025-10-18 09:35:48.967240+0000 UTC [INFO] pydataquery: Received API response in 4.807588 seconds with response code 200
# 2025-10-18 09:35:48.967240+0000 UTC [INFO] pydataquery: Sending 94/228 API request
# 2025-10-18 09:35:52.281191+0000 UTC [INFO] pydataquery: Received API response in 2.954296 seconds with response code 200
# 2025-10-18 09:35:52.281191+0000 UTC [INFO] pydataquery: Sending 95/228 API request
# 2025-10-18 09:35:57.855806+0000 UTC [INFO] pydataquery: Received API response in 5.211378 seconds with response code 200
# 2025-10-18 09:35:57.870055+0000 UTC [INFO] pydataquery: Sending 96/228 API request
# 2025-10-18 09:36:02.760760+0000 UTC [INFO] pydataquery: Received API response in 4.664874 seconds with response code 200
# 2025-10-18 09:36:02.760760+0000 UTC [INFO] pydataquery: Sending 97/228 API request
# 2025-10-18 09:36:07.754358+0000 UTC [INFO] pydataquery: Received API response in 4.699547 seconds with response code 200
# 2025-10-18 09:36:07.754358+0000 UTC [INFO] pydataquery: Sending 98/228 API request
# 2025-10-18 09:36:14.622499+0000 UTC [INFO] pydataquery: Received API response in 6.563019 seconds with response code 200
# 2025-10-18 09:36:14.637010+0000 UTC [INFO] pydataquery: Sending 99/228 API request
# 2025-10-18 09:36:16.235960+0000 UTC [INFO] pydataquery: Received API response in 1.364096 seconds with response code 200
# 2025-10-18 09:36:16.235960+0000 UTC [INFO] pydataquery: Sending 100/228 API request
# 2025-10-18 09:36:18.086498+0000 UTC [INFO] pydataquery: Received API response in 1.608118 seconds with response code 200
# 2025-10-18 09:36:18.086498+0000 UTC [INFO] pydataquery: Sending 101/228 API request
# 2025-10-18 09:36:27.781931+0000 UTC [INFO] pydataquery: Received API response in 9.397919 seconds with response code 200
# 2025-10-18 09:36:27.781931+0000 UTC [INFO] pydataquery: Sending 102/228 API request
# 2025-10-18 09:36:29.436450+0000 UTC [INFO] pydataquery: Received API response in 1.570891 seconds with response code 200
# 2025-10-18 09:36:29.436450+0000 UTC [INFO] pydataquery: Sending 103/228 API request
# 2025-10-18 09:36:34.172741+0000 UTC [INFO] pydataquery: Received API response in 4.545545 seconds with response code 200
# 2025-10-18 09:36:34.172741+0000 UTC [INFO] pydataquery: Sending 104/228 API request
# 2025-10-18 09:36:38.896122+0000 UTC [INFO] pydataquery: Received API response in 4.528388 seconds with response code 200
# 2025-10-18 09:36:38.901221+0000 UTC [INFO] pydataquery: Sending 105/228 API request
# 2025-10-18 09:36:43.275822+0000 UTC [INFO] pydataquery: Received API response in 4.293911 seconds with response code 200
# 2025-10-18 09:36:43.288914+0000 UTC [INFO] pydataquery: Sending 106/228 API request
# 2025-10-18 09:36:48.031316+0000 UTC [INFO] pydataquery: Received API response in 4.559258 seconds with response code 200
# 2025-10-18 09:36:48.046987+0000 UTC [INFO] pydataquery: Sending 107/228 API request
# 2025-10-18 09:36:49.993462+0000 UTC [INFO] pydataquery: Received API response in 1.770765 seconds with response code 200
# 2025-10-18 09:36:50.004387+0000 UTC [INFO] pydataquery: Sending 108/228 API request
# 2025-10-18 09:36:51.900984+0000 UTC [INFO] pydataquery: Received API response in 1.711109 seconds with response code 200
# 2025-10-18 09:36:51.905041+0000 UTC [INFO] pydataquery: Sending 109/228 API request
# 2025-10-18 09:36:56.898046+0000 UTC [INFO] pydataquery: Received API response in 4.700125 seconds with response code 200
# 2025-10-18 09:36:56.913363+0000 UTC [INFO] pydataquery: Sending 110/228 API request
# 2025-10-18 09:37:01.969965+0000 UTC [INFO] pydataquery: Received API response in 4.765049 seconds with response code 200
# 2025-10-18 09:37:01.977472+0000 UTC [INFO] pydataquery: Sending 111/228 API request
# 2025-10-18 09:37:06.603652+0000 UTC [INFO] pydataquery: Received API response in 4.523837 seconds with response code 200
# 2025-10-18 09:37:06.603652+0000 UTC [INFO] pydataquery: Sending 112/228 API request
# 2025-10-18 09:37:09.087040+0000 UTC [INFO] pydataquery: Received API response in 2.274259 seconds with response code 200
# 2025-10-18 09:37:09.102756+0000 UTC [INFO] pydataquery: Sending 113/228 API request
# 2025-10-18 09:37:13.530831+0000 UTC [INFO] pydataquery: Received API response in 4.267938 seconds with response code 200
# 2025-10-18 09:37:13.546467+0000 UTC [INFO] pydataquery: Sending 114/228 API request
# 2025-10-18 09:37:15.457483+0000 UTC [INFO] pydataquery: Received API response in 1.798032 seconds with response code 200
# 2025-10-18 09:37:15.467081+0000 UTC [INFO] pydataquery: Sending 115/228 API request
# 2025-10-18 09:37:18.229237+0000 UTC [INFO] pydataquery: Received API response in 2.566314 seconds with response code 200
# 2025-10-18 09:37:18.229237+0000 UTC [INFO] pydataquery: Sending 116/228 API request
# 2025-10-18 09:37:21.178977+0000 UTC [INFO] pydataquery: Received API response in 2.768334 seconds with response code 200
# 2025-10-18 09:37:21.178977+0000 UTC [INFO] pydataquery: Sending 117/228 API request
# 2025-10-18 09:37:25.317326+0000 UTC [INFO] pydataquery: Received API response in 4.045323 seconds with response code 200
# 2025-10-18 09:37:25.332957+0000 UTC [INFO] pydataquery: Sending 118/228 API request
# 2025-10-18 09:37:27.806033+0000 UTC [INFO] pydataquery: Received API response in 2.279958 seconds with response code 200
# 2025-10-18 09:37:27.819271+0000 UTC [INFO] pydataquery: Sending 119/228 API request
# 2025-10-18 09:37:32.787683+0000 UTC [INFO] pydataquery: Received API response in 4.795031 seconds with response code 200
# 2025-10-18 09:37:32.797777+0000 UTC [INFO] pydataquery: Sending 120/228 API request
# 2025-10-18 09:37:34.463282+0000 UTC [INFO] pydataquery: Received API response in 1.51131 seconds with response code 200
# 2025-10-18 09:37:34.479005+0000 UTC [INFO] pydataquery: Sending 121/228 API request
# 2025-10-18 09:37:37.076190+0000 UTC [INFO] pydataquery: Received API response in 2.194866 seconds with response code 200
# 2025-10-18 09:37:37.076190+0000 UTC [INFO] pydataquery: Sending 122/228 API request
# 2025-10-18 09:37:40.364786+0000 UTC [INFO] pydataquery: Received API response in 2.886458 seconds with response code 200
# 2025-10-18 09:37:40.364786+0000 UTC [INFO] pydataquery: Sending 123/228 API request
# 2025-10-18 09:37:43.756471+0000 UTC [INFO] pydataquery: Received API response in 3.110555 seconds with response code 200
# 2025-10-18 09:37:43.756471+0000 UTC [INFO] pydataquery: Sending 124/228 API request
# 2025-10-18 09:37:49.027643+0000 UTC [INFO] pydataquery: Received API response in 4.868457 seconds with response code 200
# 2025-10-18 09:37:49.035344+0000 UTC [INFO] pydataquery: Sending 125/228 API request
# 2025-10-18 09:37:51.472409+0000 UTC [INFO] pydataquery: Received API response in 2.108914 seconds with response code 200
# 2025-10-18 09:37:51.481428+0000 UTC [INFO] pydataquery: Sending 126/228 API request
# 2025-10-18 09:37:54.271721+0000 UTC [INFO] pydataquery: Received API response in 2.656684 seconds with response code 200
# 2025-10-18 09:37:54.271721+0000 UTC [INFO] pydataquery: Sending 127/228 API request
# 2025-10-18 09:37:57.233415+0000 UTC [INFO] pydataquery: Received API response in 2.621477 seconds with response code 200
# 2025-10-18 09:37:57.249041+0000 UTC [INFO] pydataquery: Sending 128/228 API request
# 2025-10-18 09:38:01.689276+0000 UTC [INFO] pydataquery: Received API response in 4.274131 seconds with response code 200
# 2025-10-18 09:38:01.689276+0000 UTC [INFO] pydataquery: Sending 129/228 API request
# 2025-10-18 09:38:03.825334+0000 UTC [INFO] pydataquery: Received API response in 2.019056 seconds with response code 200
# 2025-10-18 09:38:03.840975+0000 UTC [INFO] pydataquery: Sending 130/228 API request
# 2025-10-18 09:38:06.072768+0000 UTC [INFO] pydataquery: Received API response in 2.050623 seconds with response code 200
# 2025-10-18 09:38:06.088394+0000 UTC [INFO] pydataquery: Sending 131/228 API request
# 2025-10-18 09:38:10.583256+0000 UTC [INFO] pydataquery: Received API response in 4.298304 seconds with response code 200
# 2025-10-18 09:38:10.583256+0000 UTC [INFO] pydataquery: Sending 132/228 API request
# 2025-10-18 09:38:12.512546+0000 UTC [INFO] pydataquery: Received API response in 1.742038 seconds with response code 200
# 2025-10-18 09:38:13.048848+0000 UTC [INFO] pydataquery: Sending 133/228 API request
# 2025-10-18 09:38:19.013624+0000 UTC [INFO] pydataquery: Received API response in 5.662273 seconds with response code 200
# 2025-10-18 09:38:19.013624+0000 UTC [INFO] pydataquery: Sending 134/228 API request
# 2025-10-18 09:38:23.786422+0000 UTC [INFO] pydataquery: Received API response in 4.423014 seconds with response code 200
# 2025-10-18 09:38:23.786422+0000 UTC [INFO] pydataquery: Sending 135/228 API request
# 2025-10-18 09:38:25.581534+0000 UTC [INFO] pydataquery: Received API response in 1.588117 seconds with response code 200
# 2025-10-18 09:38:25.581534+0000 UTC [INFO] pydataquery: Sending 136/228 API request
# 2025-10-18 09:38:30.310465+0000 UTC [INFO] pydataquery: Received API response in 4.388634 seconds with response code 200
# 2025-10-18 09:38:30.310465+0000 UTC [INFO] pydataquery: Sending 137/228 API request
# 2025-10-18 09:38:32.846248+0000 UTC [INFO] pydataquery: Received API response in 2.208367 seconds with response code 200
# 2025-10-18 09:38:32.846248+0000 UTC [INFO] pydataquery: Sending 138/228 API request
# 2025-10-18 09:38:35.014913+0000 UTC [INFO] pydataquery: Received API response in 1.962431 seconds with response code 200
# 2025-10-18 09:38:35.014913+0000 UTC [INFO] pydataquery: Sending 139/228 API request
# 2025-10-18 09:38:40.445563+0000 UTC [INFO] pydataquery: Received API response in 5.085537 seconds with response code 200
# 2025-10-18 09:38:40.461268+0000 UTC [INFO] pydataquery: Sending 140/228 API request
# 2025-10-18 09:38:43.749564+0000 UTC [INFO] pydataquery: Received API response in 3.002905 seconds with response code 200
# 2025-10-18 09:38:43.765219+0000 UTC [INFO] pydataquery: Sending 141/228 API request
# 2025-10-18 09:38:45.315034+0000 UTC [INFO] pydataquery: Received API response in 1.369979 seconds with response code 200
# 2025-10-18 09:38:45.315034+0000 UTC [INFO] pydataquery: Sending 142/228 API request
# 2025-10-18 09:38:50.566890+0000 UTC [INFO] pydataquery: Received API response in 4.95389 seconds with response code 200
# 2025-10-18 09:38:50.572402+0000 UTC [INFO] pydataquery: Sending 143/228 API request
# 2025-10-18 09:38:55.935321+0000 UTC [INFO] pydataquery: Received API response in 5.069319 seconds with response code 200
# 2025-10-18 09:38:55.935321+0000 UTC [INFO] pydataquery: Sending 144/228 API request
# 2025-10-18 09:38:57.758121+0000 UTC [INFO] pydataquery: Received API response in 1.630878 seconds with response code 200
# 2025-10-18 09:38:57.758121+0000 UTC [INFO] pydataquery: Sending 145/228 API request
# 2025-10-18 09:39:02.811386+0000 UTC [INFO] pydataquery: Received API response in 4.821479 seconds with response code 200
# 2025-10-18 09:39:02.827121+0000 UTC [INFO] pydataquery: Sending 146/228 API request
# 2025-10-18 09:39:08.125104+0000 UTC [INFO] pydataquery: Received API response in 5.001673 seconds with response code 200
# 2025-10-18 09:39:08.125104+0000 UTC [INFO] pydataquery: Sending 147/228 API request
# 2025-10-18 09:39:11.062383+0000 UTC [INFO] pydataquery: Received API response in 2.744557 seconds with response code 200
# 2025-10-18 09:39:11.067489+0000 UTC [INFO] pydataquery: Sending 148/228 API request
# 2025-10-18 09:39:13.270557+0000 UTC [INFO] pydataquery: Received API response in 1.910913 seconds with response code 200
# 2025-10-18 09:39:13.270557+0000 UTC [INFO] pydataquery: Sending 149/228 API request
# 2025-10-18 09:39:18.497924+0000 UTC [INFO] pydataquery: Received API response in 4.926461 seconds with response code 200
# 2025-10-18 09:39:18.499983+0000 UTC [INFO] pydataquery: Sending 150/228 API request
# 2025-10-18 09:39:23.378653+0000 UTC [INFO] pydataquery: Received API response in 4.693604 seconds with response code 200
# 2025-10-18 09:39:23.378653+0000 UTC [INFO] pydataquery: Sending 151/228 API request
# 2025-10-18 09:39:26.758977+0000 UTC [INFO] pydataquery: Received API response in 3.207291 seconds with response code 200
# 2025-10-18 09:39:26.765583+0000 UTC [INFO] pydataquery: Sending 152/228 API request
# 2025-10-18 09:39:31.887880+0000 UTC [INFO] pydataquery: Received API response in 4.939899 seconds with response code 200
# 2025-10-18 09:39:31.888589+0000 UTC [INFO] pydataquery: Sending 153/228 API request
# 2025-10-18 09:39:33.934083+0000 UTC [INFO] pydataquery: Received API response in 1.967467 seconds with response code 200
# 2025-10-18 09:39:33.934083+0000 UTC [INFO] pydataquery: Sending 154/228 API request
# 2025-10-18 09:39:39.045792+0000 UTC [INFO] pydataquery: Received API response in 4.950473 seconds with response code 200
# 2025-10-18 09:39:39.062966+0000 UTC [INFO] pydataquery: Sending 155/228 API request
# 2025-10-18 09:39:41.404389+0000 UTC [INFO] pydataquery: Received API response in 2.148089 seconds with response code 200
# 2025-10-18 09:39:41.420650+0000 UTC [INFO] pydataquery: Sending 156/228 API request
# 2025-10-18 09:39:46.228591+0000 UTC [INFO] pydataquery: Received API response in 4.688714 seconds with response code 200
# 2025-10-18 09:39:46.228591+0000 UTC [INFO] pydataquery: Sending 157/228 API request
# 2025-10-18 09:39:51.387859+0000 UTC [INFO] pydataquery: Received API response in 4.990946 seconds with response code 200
# 2025-10-18 09:39:51.403873+0000 UTC [INFO] pydataquery: Sending 158/228 API request
# 2025-10-18 09:39:53.305791+0000 UTC [INFO] pydataquery: Received API response in 1.734948 seconds with response code 200
# 2025-10-18 09:39:53.305791+0000 UTC [INFO] pydataquery: Sending 159/228 API request
# 2025-10-18 09:39:54.715782+0000 UTC [INFO] pydataquery: Received API response in 1.288446 seconds with response code 200
# 2025-10-18 09:39:54.731183+0000 UTC [INFO] pydataquery: Sending 160/228 API request
# 2025-10-18 09:39:56.477930+0000 UTC [INFO] pydataquery: Received API response in 1.57328 seconds with response code 200
# 2025-10-18 09:39:56.477930+0000 UTC [INFO] pydataquery: Sending 161/228 API request
# 2025-10-18 09:40:01.731322+0000 UTC [INFO] pydataquery: Received API response in 5.058492 seconds with response code 200
# 2025-10-18 09:40:01.736917+0000 UTC [INFO] pydataquery: Sending 162/228 API request
# 2025-10-18 09:40:03.541995+0000 UTC [INFO] pydataquery: Received API response in 1.706242 seconds with response code 200
# 2025-10-18 09:40:03.557615+0000 UTC [INFO] pydataquery: Sending 163/228 API request
# 2025-10-18 09:40:05.439424+0000 UTC [INFO] pydataquery: Received API response in 1.707665 seconds with response code 200
# 2025-10-18 09:40:05.439424+0000 UTC [INFO] pydataquery: Sending 164/228 API request
# 2025-10-18 09:40:10.496437+0000 UTC [INFO] pydataquery: Received API response in 4.885068 seconds with response code 200
# 2025-10-18 09:40:10.512161+0000 UTC [INFO] pydataquery: Sending 165/228 API request
# 2025-10-18 09:40:13.924614+0000 UTC [INFO] pydataquery: Received API response in 3.212426 seconds with response code 200
# 2025-10-18 09:40:13.924614+0000 UTC [INFO] pydataquery: Sending 166/228 API request
# 2025-10-18 09:40:17.405499+0000 UTC [INFO] pydataquery: Received API response in 3.142882 seconds with response code 200
# 2025-10-18 09:40:17.420512+0000 UTC [INFO] pydataquery: Sending 167/228 API request
# 2025-10-18 09:40:19.383861+0000 UTC [INFO] pydataquery: Received API response in 1.633651 seconds with response code 200
# 2025-10-18 09:40:19.383861+0000 UTC [INFO] pydataquery: Sending 168/228 API request
# 2025-10-18 09:40:21.187865+0000 UTC [INFO] pydataquery: Received API response in 1.600888 seconds with response code 200
# 2025-10-18 09:40:21.203541+0000 UTC [INFO] pydataquery: Sending 169/228 API request
# 2025-10-18 09:40:22.460846+0000 UTC [INFO] pydataquery: Received API response in 1.113298 seconds with response code 200
# 2025-10-18 09:40:22.468949+0000 UTC [INFO] pydataquery: Sending 170/228 API request
# 2025-10-18 09:40:23.462445+0000 UTC [INFO] pydataquery: Received API response in 0.862653 seconds with response code 200
# 2025-10-18 09:40:23.462445+0000 UTC [INFO] pydataquery: Sending 171/228 API request
# 2025-10-18 09:40:24.397475+0000 UTC [INFO] pydataquery: Received API response in 0.866934 seconds with response code 200
# 2025-10-18 09:40:24.413765+0000 UTC [INFO] pydataquery: Sending 172/228 API request
# 2025-10-18 09:40:26.630499+0000 UTC [INFO] pydataquery: Received API response in 1.884083 seconds with response code 200
# 2025-10-18 09:40:26.636028+0000 UTC [INFO] pydataquery: Sending 173/228 API request
# 2025-10-18 09:40:28.869516+0000 UTC [INFO] pydataquery: Received API response in 1.911028 seconds with response code 200
# 2025-10-18 09:40:28.885200+0000 UTC [INFO] pydataquery: Sending 174/228 API request
# 2025-10-18 09:40:30.694291+0000 UTC [INFO] pydataquery: Received API response in 1.612114 seconds with response code 200
# 2025-10-18 09:40:30.694291+0000 UTC [INFO] pydataquery: Sending 175/228 API request
# 2025-10-18 09:40:33.101593+0000 UTC [INFO] pydataquery: Received API response in 2.140207 seconds with response code 200
# 2025-10-18 09:40:33.116980+0000 UTC [INFO] pydataquery: Sending 176/228 API request
# 2025-10-18 09:40:35.125192+0000 UTC [INFO] pydataquery: Received API response in 1.711764 seconds with response code 200
# 2025-10-18 09:40:35.140595+0000 UTC [INFO] pydataquery: Sending 177/228 API request
# 2025-10-18 09:40:39.724170+0000 UTC [INFO] pydataquery: Received API response in 4.400397 seconds with response code 200
# 2025-10-18 09:40:39.724170+0000 UTC [INFO] pydataquery: Sending 178/228 API request
# 2025-10-18 09:40:44.669374+0000 UTC [INFO] pydataquery: Received API response in 4.654546 seconds with response code 200
# 2025-10-18 09:40:44.684994+0000 UTC [INFO] pydataquery: Sending 179/228 API request
# 2025-10-18 09:40:47.643960+0000 UTC [INFO] pydataquery: Received API response in 2.667163 seconds with response code 200
# 2025-10-18 09:40:47.659591+0000 UTC [INFO] pydataquery: Sending 180/228 API request
# 2025-10-18 09:40:50.224141+0000 UTC [INFO] pydataquery: Received API response in 2.380437 seconds with response code 200
# 2025-10-18 09:40:50.224141+0000 UTC [INFO] pydataquery: Sending 181/228 API request
# 2025-10-18 09:40:54.660359+0000 UTC [INFO] pydataquery: Received API response in 4.143134 seconds with response code 200
# 2025-10-18 09:40:54.676368+0000 UTC [INFO] pydataquery: Sending 182/228 API request
# 2025-10-18 09:40:56.439688+0000 UTC [INFO] pydataquery: Received API response in 1.424298 seconds with response code 200
# 2025-10-18 09:40:56.449746+0000 UTC [INFO] pydataquery: Sending 183/228 API request
# 2025-10-18 09:41:00.999381+0000 UTC [INFO] pydataquery: Received API response in 4.34723 seconds with response code 200
# 2025-10-18 09:41:01.009398+0000 UTC [INFO] pydataquery: Sending 184/228 API request
# 2025-10-18 09:41:04.611652+0000 UTC [INFO] pydataquery: Received API response in 3.265137 seconds with response code 200
# 2025-10-18 09:41:04.626168+0000 UTC [INFO] pydataquery: Sending 185/228 API request
# 2025-10-18 09:41:08.316456+0000 UTC [INFO] pydataquery: Received API response in 3.421588 seconds with response code 200
# 2025-10-18 09:41:08.316456+0000 UTC [INFO] pydataquery: Sending 186/228 API request
# 2025-10-18 09:41:09.868103+0000 UTC [INFO] pydataquery: Received API response in 1.343233 seconds with response code 200
# 2025-10-18 09:41:09.868103+0000 UTC [INFO] pydataquery: Sending 187/228 API request
# 2025-10-18 09:41:11.880182+0000 UTC [INFO] pydataquery: Received API response in 1.734734 seconds with response code 200
# 2025-10-18 09:41:11.883786+0000 UTC [INFO] pydataquery: Sending 188/228 API request
# 2025-10-18 09:41:14.412357+0000 UTC [INFO] pydataquery: Received API response in 2.209637 seconds with response code 200
# 2025-10-18 09:41:14.422449+0000 UTC [INFO] pydataquery: Sending 189/228 API request
# 2025-10-18 09:41:19.384239+0000 UTC [INFO] pydataquery: Received API response in 4.767831 seconds with response code 200
# 2025-10-18 09:41:19.399594+0000 UTC [INFO] pydataquery: Sending 190/228 API request
# 2025-10-18 09:41:21.030720+0000 UTC [INFO] pydataquery: Received API response in 1.446265 seconds with response code 200
# 2025-10-18 09:41:21.047529+0000 UTC [INFO] pydataquery: Sending 191/228 API request
# 2025-10-18 09:41:23.407789+0000 UTC [INFO] pydataquery: Received API response in 2.192655 seconds with response code 200
# 2025-10-18 09:41:23.419382+0000 UTC [INFO] pydataquery: Sending 192/228 API request
# 2025-10-18 09:41:25.389534+0000 UTC [INFO] pydataquery: Received API response in 1.865438 seconds with response code 200
# 2025-10-18 09:41:25.398047+0000 UTC [INFO] pydataquery: Sending 193/228 API request
# 2025-10-18 09:41:27.666622+0000 UTC [INFO] pydataquery: Received API response in 2.083085 seconds with response code 200
# 2025-10-18 09:41:27.666622+0000 UTC [INFO] pydataquery: Sending 194/228 API request
# 2025-10-18 09:41:32.512383+0000 UTC [INFO] pydataquery: Received API response in 4.665085 seconds with response code 200
# 2025-10-18 09:41:32.512383+0000 UTC [INFO] pydataquery: Sending 195/228 API request
# 2025-10-18 09:41:37.011441+0000 UTC [INFO] pydataquery: Received API response in 4.435138 seconds with response code 200
# 2025-10-18 09:41:37.026186+0000 UTC [INFO] pydataquery: Sending 196/228 API request
# 2025-10-18 09:41:38.797209+0000 UTC [INFO] pydataquery: Received API response in 1.631165 seconds with response code 200
# 2025-10-18 09:41:38.806731+0000 UTC [INFO] pydataquery: Sending 197/228 API request
# 2025-10-18 09:41:40.982598+0000 UTC [INFO] pydataquery: Received API response in 2.042587 seconds with response code 200
# 2025-10-18 09:41:40.982598+0000 UTC [INFO] pydataquery: Sending 198/228 API request
# 2025-10-18 09:41:45.846795+0000 UTC [INFO] pydataquery: Received API response in 4.678598 seconds with response code 200
# 2025-10-18 09:41:45.846795+0000 UTC [INFO] pydataquery: Sending 199/228 API request
# 2025-10-18 09:41:50.550396+0000 UTC [INFO] pydataquery: Received API response in 4.396041 seconds with response code 200
# 2025-10-18 09:41:50.550396+0000 UTC [INFO] pydataquery: Sending 200/228 API request
# 2025-10-18 09:41:52.242256+0000 UTC [INFO] pydataquery: Received API response in 1.449664 seconds with response code 200
# 2025-10-18 09:41:52.242256+0000 UTC [INFO] pydataquery: Sending 201/228 API request
# 2025-10-18 09:41:56.550927+0000 UTC [INFO] pydataquery: Received API response in 4.122252 seconds with response code 200
# 2025-10-18 09:41:56.550927+0000 UTC [INFO] pydataquery: Sending 202/228 API request
# 2025-10-18 09:42:00.950471+0000 UTC [INFO] pydataquery: Received API response in 4.158379 seconds with response code 200
# 2025-10-18 09:42:00.950471+0000 UTC [INFO] pydataquery: Sending 203/228 API request
# 2025-10-18 09:42:05.604586+0000 UTC [INFO] pydataquery: Received API response in 4.40973 seconds with response code 200
# 2025-10-18 09:42:05.604586+0000 UTC [INFO] pydataquery: Sending 204/228 API request
# 2025-10-18 09:42:09.973299+0000 UTC [INFO] pydataquery: Received API response in 4.158559 seconds with response code 200
# 2025-10-18 09:42:09.973299+0000 UTC [INFO] pydataquery: Sending 205/228 API request
# 2025-10-18 09:42:13.669985+0000 UTC [INFO] pydataquery: Received API response in 3.368727 seconds with response code 200
# 2025-10-18 09:42:13.685598+0000 UTC [INFO] pydataquery: Sending 206/228 API request
# 2025-10-18 09:42:15.909999+0000 UTC [INFO] pydataquery: Received API response in 1.89622 seconds with response code 200
# 2025-10-18 09:42:15.909999+0000 UTC [INFO] pydataquery: Sending 207/228 API request
# 2025-10-18 09:42:19.255453+0000 UTC [INFO] pydataquery: Received API response in 3.33988 seconds with response code 200
# 2025-10-18 09:42:19.261457+0000 UTC [CRITICAL] pydataquery: Not a valid DataQuery time-series response: `instruments` object not found
# Response code: 200 - API request: https://api-developer.jpmorgan.com/research/dataquery-authe/api/v2/expressions/time-series?expressions=DB%28CREDIT%2CHY%2CBOND%2CYQ2990469%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CZF3448098%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CZF2342714%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYL8987973%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYL7092825%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYL6371642%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYL6746058%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYM9725784%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYN5035905%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYN2868316%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYO7071450%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYO4254190%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYL6745472%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYO0367764%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYO1191478%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2C46284VAQ4%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2C476556DD4%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2C476556DG7%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2C491386AP3%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2C501797AW4%2CMDUR%29&start-date=20201019&end-date=20211017&data=ALL&calendar=CAL_WEEKDAYS&nan-treatment=NA_NOTHING&frequency=FREQ_DAY
# Response body: {'errors': [{'code': None, 'message': 'Unable to fetch data. Please try after some time', 'description': 'Unable to fetch data. Please try after some time'}]}
# 2025-10-18 09:42:19.261457+0000 UTC [CRITICAL] pydataquery: Not a valid DataQuery time-series response: `instruments` object not found
# Response code: 200 - API request: https://api-developer.jpmorgan.com/research/dataquery-authe/api/v2/expressions/time-series?expressions=DB%28CREDIT%2CHY%2CBOND%2CYQ2990469%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CZF3448098%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CZF2342714%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYL8987973%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYL7092825%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYL6371642%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYL6746058%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYM9725784%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYN5035905%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYN2868316%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYO7071450%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYO4254190%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYL6745472%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYO0367764%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2CYO1191478%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2C46284VAQ4%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2C476556DD4%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2C476556DG7%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2C491386AP3%2CMDUR%29&expressions=DB%28CREDIT%2CHY%2CBOND%2C501797AW4%2CMDUR%29&start-date=20201019&end-date=20211017&data=ALL&calendar=CAL_WEEKDAYS&nan-treatment=NA_NOTHING&frequency=FREQ_DAY
# Response body: {'errors': [{'code': None, 'message': 'Unable to fetch data. Please try after some time', 'description': 'Unable to fetch data. Please try after some time'}]}
# 2025-10-18 09:42:19.261457+0000 UTC [CRITICAL] pydataquery: API process terminated unexpectedly. Trying to save 4,120 entries of data retrieved so far.
# 2025-10-18 09:42:19.261457+0000 UTC [INFO] pydataquery: Processing API responses... This may take a few seconds depending on the size of requests.
# 2025-10-18 09:42:22.123900+0000 UTC [CRITICAL] pydataquery: Missing data: 40 expressions. Run `.show_value_isna()` for the job to see the list.
# 2025-10-18 09:42:22.123900+0000 UTC [INFO] pydataquery: Execution completed
# 2025-10-18 09:42:22.123900+0000 UTC [CRITICAL] pydataquery: API process terminated because the recent API returned invalid response. Please look into the log for details. To retry, please rerun `.execute()`
# 2025-10-18 09:42:22.123900+0000 UTC [CRITICAL] pydataquery: API process terminated because the recent API returned invalid response. Please look into the log for details. To retry, please rerun `.execute()`

# %%
df5a = pd.merge(left = par, right = uf, on="ISIN", how="outer")
df5a[[col for col in df5a.columns if "_UF100_" in col or "_UF500_" in col]] = 100-\
df5a[[col for col in df5a.columns if "_UF100_" in col or "_UF500_" in col]]

for item in dt_list:
    if (f"Price_{item}" in df5a.columns) and (f"Mat_Matched_UF100_{item}" in df5a.columns) and\
    (f"Mat_Matched_UF500_{item}" in df5a.columns):
        df5a[f"UF100_Basis_{item}"] = df5a[f"Price_{item}"] - df5a[f"Mat_Matched_UF100_{item}"]
        df5a[f"UF500_Basis_{item}"] = df5a[f"Price_{item}"] - df5a[f"Mat_Matched_UF500_{item}"]

with open('Rating_Dict.json', 'w') as f:
    json.dump(f_dict, f)

df5a.to_parquet("Basis df5a.parquet")
