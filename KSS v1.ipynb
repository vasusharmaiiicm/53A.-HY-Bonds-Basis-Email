# %%
update_live = False
email_both = False

# %%
import pandas as pd
import random
from pydataquery import DataQuery
from matplotlib.colors import LinearSegmentedColormap
from xbbg import blp
import numpy as np
import pytz
import time
from datetime import datetime, timedelta
import statsmodels.api as sm
from ipywidgets import interact, Dropdown, HBox, VBox, Button, Output, Text, widgets
from IPython.display import display, clear_output
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
import re
import scipy.stats as stats
from adjustText import adjust_text
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import sympy as sp
import itertools
import warnings
import openpyxl
import subprocess
import dataframe_image as dfi
import time
import pyautogui
import pygetwindow as gw
import pyodbc
import ast
warnings.filterwarnings("ignore")

# %%
dft = pd.read_excel("DQ_Data_v75.xlsx")
dft.set_index(dft.columns[0],inplace=True)
dft.index.name = None
dft.index = pd.to_datetime(dft.index, format='%Y-%m-%d').date
df_back = dft.copy()

start_date = df_back.index.max()

##################  Change here only

isin_list = ["US105756BX78", "US105756BZ27", "US105756CA66", "US105756CC23", "US105756CG37", "US105756CE88", "US105756CK49", "US105756CF53", "US105756CH10", "US105756BW95", "US105756BY51", "US105756CB40", "US105756CJ75", "US168863DX33", "US168863CF36", "US168863EB04", "US168863DP09", "US168863DN50", "US168863DT21", "US168863DV76", "US168863DZ80", "US168863DS48", "US168863DY16", "US168863CE60", "US168863DL94", "US168863DW59", "XS2327851874", "US168863EA21", "US168863DQ81", "US168863DU93", "US195325CX13", "US195325DL65", "US195325DP79", "US195325DR36", "US195325DS19", "US195325DZ51", "US195325EF88", "US195325EG61", "US195325EL56", "US195325BK01", "US195325BM66", "US195325EA91", "US195325BR53", "US195325CU73", "US195325DQ52", "US195325DT91", "US195325EM30", "US195325DX04", "US91086QBG29", "US91087BAC46", "US91087BAE02", "US91087BAU44", "US91087BAF76", "US91087BAY65", "US91087BAH33", "US91087BAM28", "US91087BAK61", "US91087BAT70", "US91087BAR15", "US91087BAV27", "US91087BAZ31", "US91086QAV05", "US91087BAQ32", "US91086QBB32", "US91086QBE70", "US91086QBF46", "US91087BAB62", "US91087BAD29", "US91087BAG59", "US91087BAL45", "US91087BAS97", "US91087BAX82", "US91087BBA70", "US91087BAN01", "XS2280637039", "US91086QAZ19", "USP90603AN40", "US698299BF03", "US698299BK97", "US698299BX19", "USP90603AP97", "US698299BN37", "US698299BR41", "US698299BT07", "US698299AW45", "US698299BW36", "US698299BY91", "US698299BG85", "US698299BH68", "US698299BB98", "US698299BV52", "US698299BM53", "US698299BL70", "US698299BS24", "US715638DE95", "US715638BU55", "US715638DA73", "US715638DF60", "US715638DP43", "US715638DU38", "US715638EB48", "US715638DS81", "US715638BM30", "US715638DT64", "US715638EC21", "US715638DQ26", "US715638DW93", "US715638DR09", "US836205AT15", "US836205AW44", "US836205AU87", "US836205BA15", "US836205AY00", "US836205BC70", "US836205AS32", "US836205AV60", "US836205AX27", "US836205BB97", "US836205BE37", "US900123DB31", "US900123CJ75", "US900123CK49", "US900123CL22", "USM88269US88", "US900123DF45", "US900123CP36", "US900123CQ19", "US900123DH01", "US900123CT57", "US900123CY43", "US900123DJ66", "US900123DA57", "US900123DC14", "US900123DL13", "US900123DG28", "US900123DD96", "US900123AT75", "US900123DK30", "US900123DN78", "US900123AY60", "US900123BB58", "US900123BG46", "US900123BJ84", "US900123CB40", "US900123CG37", "US900123CM05", "USP3579EBK21", "USP3579EBV85", "USP3579ECB13", "USP3579ECP09", "USP3579ECF27", "USP3579ECR64", "USP3579ECH82", "USP3579ECN50", "USP3579ECU93", "USP3579ECJ49", "USP3579EAY34", "USP3579EBE60", "USP3579EBY25", "USP3579ECE51", "USP3579ECG00", "US71654QDH20", "US71654QBW15", "US71654QCB68", "US71654QDB59", "US71654QCG55", "US71654QCK67", "US71654QCP54", "US71654QDL32", "US71654QDC33", "US71654QDE98", "US71643VAB18", "US71654QDP46", "US706451BG56", "US71654QAZ54", "US71654QBR20", "US71654QCC42", "US71654QCL41", "US71654QDD16", "US71654QDF63", "US71656MAF68", "US71647NAS80", "US71647NAY58", "US71647NBH17", "US71647NBK46", "US71647NBL29", "US71645WAQ42", "US71645WAS08", "US71647NAK54", "US71647NBJ72", "US71647NAN93",
             "XS2214237807", "XS2214239506", "XS2214238441", "XS2214239175", "US040114HX11", "US040114HS26", "US040114HT09", "US040114HU71", "US040114HV54", "US040114HW38", "XS1910826996", "XS1717011982", "XS2384698994", "XS2445169985", "XS1777972511", "XS1910827887", "XS2948511949", "XS1566179039", "XS2384701020", "XS2948512913", "XS1777972941", "XS1717013095", "XS1910828182", "XS2384704800", "XS1843435840", "XS1781710543", "XS2764839945", "XS1843435766", "XS2354781614", "XS1781710626", "XS1318576086", "XS1819680288", "XS2083302419", "XS2446175577", "XS1819680528", "XS2083302500", "XS1790104530", "XS1619155564", "XS2333676133", "XS1790134362", "XS2297220423", "XS1903488572", "XS1558078736", "XS2391394348", "XS1775618439", "XS1504948776", "XS1953057061", "XS1903489463", "XS2297226545", "XS2079842642", "XS2176897754", "XS2391395154", "XS1558078496", "XS1775617464", "XS1953057491", "XS2176899701", "XS2391398174", "USP01012BX31", "USP01012CF16", "XS0146173371", "USP01012AN67", "USP01012AR71", "USP01012CA29", "USP01012CC84", "USP01012CH71", 
             "USP7808BAA54", "USP7808BAB38", "XS0505478684", "XS2079846635", "XS2297221405", 
             "USG2583XAB76", "USL21779AL44", "USL21779AJ97", "USL21779AK60", 
             "XS2322319398", "XS1729875598", "XS2419405274", "XS2322319638", "XS2322321964",
             "USN15516AB83", "USN15516AD40", "USN15516AH53","USN15516AG70","USN15516AJ10","USU1065PAA94",
             "USN15516AE23"
            ]
isin_list += ['XS2965710598','US105756CL22','US105756CM05','US168863EE43','US195325ER27','US195325EQ44','US195325EP60','US195325ES00','US25714PFB94','US25714PFC77','XS2990500766','XS2989586941','XS3010561762','US91087BBB53','US91087BBF67','US91087BBE92','US91087BBC37','US91087BBD10','US715638FD94','US715638FC12','US836205BF02','XS2917537875','US900123DQ00']
isin_list += ["US60367QAC78", "US16955EAC49", "US455780CB07", "US455780BM70", "US455780BY19", "US455780BJ42", "US455780BU96", "US455780BW52", "US455780BR67", "US455780AX45", "US455780AZ92", "US455780AT33", "IT0003805295", "FR0014007L00", "FR0014001NN8", "FR0013515806", "FR0014002JM6", "FR0013516549", "FR0014002WK3", "FR0013480613", "FR0014004J31", "FR0014003N51", "FR0013524014", "FR0014001N38", "FR0013327491", "FR001400AQH0", "FR0013209871", "FR0014008181", "FR001400IKW5", "FR001400JI88", "FR0011982776", "FR001400QCA1", "FR0012993103", "FR0013404969", "FR0013313582", "FR0013154044", "FR0014009O62", "FR0013154028", "FR0013234333", "FR0010447367", "FR0013257524", "FR0011883966", "FR001400CMX2", "FR001400BKZ3", "FR001400PM68", "FR001400Z2L7", "FR001400H7V7", "FR001400FTH3", "FR001400NEF3", "FR001400L834", "FR0014012II5", "FR0011461037", "FR001400OHF4", "FR001400QMF9", "FR001400XJJ3", "FR0000188799", "FR001400X8V5", "FR001400WYO4", "FR0010171975", "FR0010870956", "FR0010773192", "FR0010371401", "FR0010070060", "FR0000187635", "US455780CV60", "US455780CY00", "US455780CQ75", "US455780CR58", "US455780CW44", "US455780DG84", "US455780CX27", "US455780DJ24", "US455780CN45", "US455780CS32", "US455780DX18", "US455780CT15", "US455780DK96", "US455780CE46", "US455780CU87", "US455780DN36", "US455780DU78", "US455780DR40", "US455780DZ65", "US455780DV51", "US455780DW35", "US455780CJ33", "US455780EA06", "US455780DS23", "XS2088745430", "XS1405801041", "XS0280146357", "XS1435990863", "XS1199008670", "XS1180459395", "XS0342993747", "XS3107226006", "XS3016634399", "XS3074411524", "XS2948764563", "XS2994958416", "XS3041419642", "XS0936805612", "XS2624502360", "XS0970703772", "IT0003685093", "XS0181673798", "XS2265524210"]

names_list = ["BRAZIL 6 04/07/26", "BRAZIL 4 5/8 01/13/28", "BRAZIL 4 1/2 05/30/29", "BRAZIL 3 7/8 06/12/30", "BRAZIL 6 1/4 03/18/31", "BRAZIL 3 3/4 09/12/31", "BRAZIL 6 1/8 01/22/32", "BRAZIL 6 10/20/33", "BRAZIL 6 1/8 03/15/34", "BRAZIL 5 01/27/45", "BRAZIL 5 5/8 02/21/47", "BRAZIL 4 3/4 01/14/50", "BRAZIL 7 1/8 05/13/54", "CHILE 2 3/4 01/31/27", "CHILE 3.24 02/06/28", "CHILE 4.85 01/22/29", "CHILE 2.45 01/31/31", "CHILE 2.55 01/27/32", "CHILE 2.55 07/27/33", "CHILE 3 1/2 01/31/34", "CHILE 4.95 01/05/36", "CHILE 3.1 05/07/41", "CHILE 4.34 03/07/42", "CHILE 3.86 06/21/47", "CHILE 3 1/2 01/25/50", "CHILE 4 01/31/52", "CHILE 3 1/2 04/15/53", "CHILE 5.33 01/05/54", "CHILE 3.1 01/22/61", "CHILE 3 1/4 09/21/2071", "COLOM 4 1/2 01/28/26", "COLOM 3 7/8 04/25/27", "COLOM 4 1/2 03/15/29", "COLOM 3 01/30/30", "COLOM 3 1/8 04/15/31", "COLOM 3 1/4 04/22/32", "COLOM 8 04/20/33", "COLOM 7 1/2 02/02/34", "COLOM 8 11/14/35", "COLOM 7 3/8 09/18/37", "COLOM 6 1/8 01/18/41", "COLOM 4 1/8 02/22/42", "COLOM 5 5/8 02/26/44", "COLOM 5 06/15/45", "COLOM 5.2 05/15/49", "COLOM 4 1/8 05/15/51", "COLOM 8 3/4 11/14/53", "COLOM 3 7/8 02/15/61", "MEX 4 1/8 01/21/26", "MEX 4.15 03/28/27", "MEX 3 3/4 01/11/28", "MEX 5.4 02/09/28", "MEX 4 1/2 04/22/29", "MEX 5 05/07/29", "MEX 3 1/4 04/16/30", "MEX 2.659 05/24/31", "MEX 4 3/4 04/27/32", "MEX 4 7/8 05/19/33", "MEX 3 1/2 02/12/34", "MEX 6.35 02/09/35", "MEX 6 05/07/36", "MEX 6.05 01/11/40", "MEX 4.28 08/14/41", "MEX 4 3/4 03/08/44", "MEX 5.55 01/21/45", "MEX 4.6 01/23/46", "MEX 4.35 01/15/47", "MEX 4.6 02/10/48", "MEX 4 1/2 01/31/50", "MEX 5 04/27/51", "MEX 4.4 02/12/52", "MEX 6.338 05/04/53", "MEX 6.4 05/07/54", "MEX 3.771 05/24/61", "MEX 3 3/4 04/19/2071", "MEX 5 3/4 10/12/2110", "PANAMA 3 3/4 04/17/26", "PANAMA 3 7/8 03/17/28", "PANAMA 3.16 01/23/30", "PANAMA 7 1/2 03/01/31", "PANAMA 3.362 06/30/31", "PANAMA 2.252 09/29/32", "PANAMA 3.298 01/19/33", "PANAMA 6.4 02/14/35", "PANAMA 6.7 01/26/36", "PANAMA 6 7/8 01/31/36", "PANAMA 8 03/01/38", "PANAMA 4 1/2 05/15/47", "PANAMA 4 1/2 04/16/50", "PANAMA 4.3 04/29/53", "PANAMA 6.853 03/28/54", "PANAMA 4 1/2 04/01/56", "PANAMA 3.87 07/23/60", "PANAMA 4 1/2 01/19/63", "PERU 2.392 01/23/26", "PERU 4 1/8 08/25/27", "PERU 2.844 06/20/30", "PERU 2.783 01/23/31", "PERU 1.862 12/01/32", "PERU 3 01/15/34", "PERU 5 3/8 02/08/35", "PERU 3.3 03/11/41", "PERU 5 5/8 11/18/50", "PERU 3.55 03/10/51", "PERU 5 7/8 08/08/54", "PERU 2.78 12/01/60", "PERU 3.6 01/15/2072", "PERU 3.23 07/28/2121", "SOAF 4 7/8 04/14/26", "SOAF 4.85 09/27/27", "SOAF 4.3 10/12/28", "SOAF 4.85 09/30/29", "SOAF 5 7/8 06/22/30", "SOAF 5 7/8 04/20/32", "SOAF 5 3/8 07/24/44", "SOAF 5 10/12/46", "SOAF 5.65 09/27/47", "SOAF 5 3/4 09/30/49", "SOAF 7.3 04/20/52", "TURKEY 4 3/4 01/26/26", "TURKEY 4 1/4 04/14/26", "TURKEY 4 7/8 10/09/26", "TURKEY 6 03/25/27", "TURKEY 8.6 09/24/27", "TURKEY 9 7/8 01/15/28", "TURKEY 5 1/8 02/17/28", "TURKEY 6 1/8 10/24/28", "TURKEY 9 3/8 03/14/29", "TURKEY 7 5/8 04/26/29", "TURKEY 5 1/4 03/13/30", "TURKEY 9 1/8 07/13/30", "TURKEY 5.95 01/15/31", "TURKEY 5 7/8 06/26/31", "TURKEY 7 1/8 07/17/32", "TURKEY 9 3/8 01/19/33", "TURKEY 6 1/2 09/20/33", "TURKEY 8 02/14/34", "TURKEY 7 5/8 05/15/34", "TURKEY 6 1/2 01/03/35", "TURKEY 6 7/8 03/17/36", "TURKEY 7 1/4 03/05/38", "TURKEY 6 3/4 05/30/40", "TURKEY 6 01/14/41", "TURKEY 4 7/8 04/16/43", "TURKEY 6 5/8 02/17/45", "TURKEY 5 3/4 05/11/47", "DOMREP 6 7/8 01/29/26", "DOMREP 5.95 01/25/27", "DOMREP 6 07/19/28", "DOMREP 5 1/2 02/22/29", "DOMREP 4 1/2 01/30/30", "DOMREP 7.05 02/03/31", "DOMREP 4 7/8 09/23/32", "DOMREP 6 02/22/33", "DOMREP 6.6 06/01/36", "DOMREP 5.3 01/21/41", "DOMREP 7.45 04/30/44", "DOMREP 6.85 01/27/45", "DOMREP 6 1/2 02/15/48", "DOMREP 6.4 06/05/49", "DOMREP 5 7/8 01/30/60", "PEMEX 6 7/8 10/16/25", "PEMEX 4 1/2 01/23/26", "PEMEX 6 7/8 08/04/26", "PEMEX 6.49 01/23/27", "PEMEX 6 1/2 03/13/27", "PEMEX 5.35 02/12/28", "PEMEX 6 1/2 01/23/29", "PEMEX 8 3/4 06/02/29", "PEMEX 6.84 01/23/30", "PEMEX 5.95 01/28/31", "PEMEX 6.7 02/16/32", "PEMEX 10 02/07/33", "PEMEX 6 5/8 06/15/35", "PEMEX 6 1/2 06/02/41", "PEMEX 6 3/8 01/23/45", "PEMEX 6 3/4 09/21/47", "PEMEX 6.35 02/12/48", "PEMEX 7.69 01/23/50", "PEMEX 6.95 01/28/60", "PEMEX 6 5/8 PERP", "PETBRA 7 3/8 01/17/27", "PETBRA 5.999 01/27/28", "PETBRA 5.6 01/03/31", "PETBRA 6 1/2 07/03/33", "PETBRA 6 01/13/35", "PETBRA 6 7/8 01/20/40", "PETBRA 6 3/4 01/27/41", "PETBRA 7 1/4 03/17/44", "PETBRA 5 1/2 06/10/51", "PETBRA 6.85 06/05/2115",
             "ECUA 6.9 07/31/30", "ECUA 0 07/31/30", "ECUA 5 1/2 07/31/35", "ECUA 5 07/31/40", "ARGENT 1 07/09/29", "ARGENT 0 3/4 07/09/30", "ARGENT 4 1/8 07/09/35", "ARGENT 5 01/09/38", "ARGENT 3 1/2 07/09/41", "ARGENT 4 1/8 07/09/46", "NGERIA 7 5/8 11/21/25", "NGERIA 6 1/2 11/28/27", "NGERIA 6 1/8 09/28/28", "NGERIA 8 3/8 03/24/29", "NGERIA 7.143 02/23/30", "NGERIA 8.747 01/21/31", "NGERIA 9 5/8 06/09/31", "NGERIA 7 7/8 02/16/32", "NGERIA 7 3/8 09/28/33", "NGERIA 10 3/8 12/09/34", "NGERIA 7.696 02/23/38", "NGERIA 7 5/8 11/28/47", "NGERIA 9.248 01/21/49", "NGERIA 8 1/4 09/28/51", "KENINT 7 05/22/27", "KENINT 7 1/4 02/28/28", "KENINT 9 3/4 02/16/31", "KENINT 8 05/22/32", "KENINT 6.3 01/23/34", "KENINT 8 1/4 02/28/48", "ANGOL 9 1/2 11/12/25", "ANGOL 8 1/4 05/09/28", "ANGOL 8 11/26/29", "ANGOL 8 3/4 04/14/32", "ANGOL 9 3/8 05/08/48", "ANGOL 9 1/8 11/26/49", "SENEGL 4 3/4 03/13/28", "SENEGL 6 1/4 05/23/33", "SENEGL 5 3/8 06/08/37", "SENEGL 6 3/4 03/13/48", "EGYPT 3 7/8 02/16/26", "EGYPT 7 1/8 11/10/26", "EGYPT 7 1/2 01/31/27", "EGYPT 5.8 09/30/27", "EGYPT 6.588 02/21/28", "EGYPT 7 11/10/28", "EGYPT 7.6003 03/01/29", "EGYPT 7 5/8 11/10/30", "EGYPT 5 7/8 02/16/31", "EGYPT 7.0529 01/15/32", "EGYPT 7 5/8 05/29/32", "EGYPT 7.3 09/30/33", "EGYPT 8 1/2 01/31/47", "EGYPT 7.903 02/21/48", "EGYPT 8.7002 03/01/49", "EGYPT 8 7/8 05/29/50", "EGYPT 8 3/4 09/30/51", "ELSALV 8 5/8 02/28/29", "ELSALV 9 1/4 04/17/30", "ELSALV 8 1/4 04/10/32", "ELSALV 7.65 06/15/35", "ELSALV 7 5/8 02/01/41", "ELSALV 7.1246 01/20/50", "ELSALV 9 1/2 07/15/52", "ELSALV 9.65 11/21/54", 
             "PETRPE 4 3/4 06/19/32", "PETRPE 5 5/8 06/19/47", "EGYPT 6 7/8 04/30/40", "EGYPT 8.15 11/20/59", "EGYPT 7 1/2 02/16/61", 
             "CSNABZ 6 3/4 01/28/28", "CSNABZ 8 7/8 12/05/30", "CSNABZ 4 5/8 06/10/31", "CSNABZ 5 7/8 04/08/32",
             "PKSTAN 6 04/08/26", "PKSTAN 6 7/8 12/05/27", "PKSTAN 7.95 01/31/29", "PKSTAN 7 3/8 04/08/31", "PKSTAN 8 7/8 04/08/51",
             "BRASKM 4.5 01/10/28", "BRASKM 4.5 01/31/30","BRASKM 8.5 01/12/31","BRASKM 7.25 02/13/33","BRASKM 8 10/15/34","BRASKM 7.125 07/22/41", "BRASKM 5.875 01/31/50",
             ]
names_list += ['ANGOL 10.95 12/27/30', 'BRAZIL 6 5/8 03/15/35', 'BRAZIL 5 1/2 11/06/30', 'CHILE 5.65 01/13/37', 'COLOM 7 3/8 04/25/30', 'COLOM 8 3/8 11/07/54', 'COLOM 7 3/4 11/07/36', 'COLOM 8 1/2 04/25/35', 'DOMREP 6.95 03/15/37', 'DOMREP 7.15 02/24/55', 'EGYPT 9.45 02/04/33', 'EGYPT 8 5/8 02/04/30', 'KENINT 9 1/2 03/05/36', 'MEX 6 05/13/30', 'MEX 6 5/8 01/29/38', 'MEX 5.85 07/02/32', 'MEX 6 7/8 05/13/37', 'MEX 7 3/8 05/13/55', 'PERU 6.2 06/30/55', 'PERU 5 1/2 03/30/36', 'SOAF 7.1 11/19/36', 'SOAF 7.95 11/19/54', 'TURKEY 7 1/4 05/29/32']
names_list += ["CHINA 1 3/4 10/26/31", "CHINA 1.2 10/21/30", "INDON 4 3/4 07/18/47", "INDON 4 5/8 04/15/43", "INDON 5 1/4 01/08/47", "INDON 5 1/4 01/17/42", "INDON 5 1/8 01/15/45", "INDON 5.95 01/08/46", "INDON 6 3/4 01/15/44", "INDON 6 5/8 02/17/37", "INDON 7 3/4 01/17/38", "INDON 8 1/2 10/12/35", "ITALY Float 07/31/45", "FRTR 0 05/25/32", "FRTR 0 1/2 05/25/2072", "FRTR 0 1/2 05/25/40", "FRTR 0 1/2 06/25/44", "FRTR 0 11/25/30", "FRTR 0 11/25/31", "FRTR 0 3/4 05/25/52", "FRTR 0 3/4 05/25/53", "FRTR 0.1 03/01/32", "FRTR 0.1 03/01/36", "FRTR 0.1 07/25/31", "FRTR 0.1 07/25/36", "FRTR 0.1 07/25/38", "FRTR 0.1 07/25/47", "FRTR 0.1 07/25/53", "FRTR 0.55 03/01/39", "FRTR 0.6 07/25/34", "FRTR 0.7 07/25/30", "FRTR 0.95 07/25/43", "FRTR 1 1/2 05/25/31", "FRTR 1 1/2 05/25/50", "FRTR 1 1/4 05/25/34", "FRTR 1 1/4 05/25/36", "FRTR 1 1/4 05/25/38", "FRTR 1 3/4 05/25/66", "FRTR 1 3/4 06/25/39", "FRTR 1.8 07/25/40", "FRTR 2 05/25/48", "FRTR 2 1/2 05/25/30", "FRTR 2 1/2 05/25/43", "FRTR 2 11/25/32", "FRTR 2 3/4 02/25/30", "FRTR 2.7 02/25/31", "FRTR 3 05/25/33", "FRTR 3 05/25/54", "FRTR 3 06/25/49", "FRTR 3 1/2 11/25/33", "FRTR 3 1/2 11/25/35", "FRTR 3 1/4 05/25/45", "FRTR 3 1/4 05/25/55", "FRTR 3 11/25/34", "FRTR 3 3/4 05/25/56", "FRTR 3.15 07/25/32", "FRTR 3.2 05/25/35", "FRTR 3.6 05/25/42", "FRTR 4 04/25/55", "FRTR 4 04/25/60", "FRTR 4 1/2 04/25/41", "FRTR 4 10/25/38", "FRTR 4 3/4 04/25/35", "FRTR 5 3/4 10/25/32", "INDON 1.85 03/12/31", "INDON 2.15 07/28/31", "INDON 2.85 02/14/30", "INDON 3 1/2 02/14/50", "INDON 3.05 03/12/51", "INDON 3.2 09/23/61", "INDON 3.35 03/12/2071", "INDON 3.55 03/31/32", "INDON 3.7 10/30/49", "INDON 3.85 10/15/30", "INDON 4 3/4 09/10/34", "INDON 4.2 10/15/50", "INDON 4.3 03/31/52", "INDON 4.35 01/11/48", "INDON 4.45 04/15/70", "INDON 4.65 09/20/32", "INDON 4.7 02/10/34", "INDON 4.85 01/11/33", "INDON 5 1/4 01/15/30", "INDON 5.1 02/10/54", "INDON 5.15 09/10/54", "INDON 5.35 02/11/49", "INDON 5.6 01/15/35", "INDON 5.65 01/11/53", "ITALY 0.913 09/01/39", "ITALY 1.483 05/04/46", "ITALY 1.85 09/15/57", "ITALY 1.901 06/22/31", "ITALY 2 09/05/32", "ITALY 2.192 02/02/32", "ITALY 2.2 09/15/58", "ITALY 3 07/02/35", "ITALY 3 1/2 09/04/35", "ITALY 3 1/2 11/15/35", "ITALY 3.55 10/29/36", "ITALY 4 08/05/35", "ITALY 4 10/02/35", "ITALY 4 3/4 05/28/63", "ITALY 5 05/17/33", "ITALY 5.05 09/11/53", "ITALY 5.2 07/31/34", "ITALY 5.345 01/27/48", "ITALY Float 12/02/40"]

#Making Manual Adj. for Perp Bond of PEMEX
names_list[names_list.index("PEMEX 6 5/8 PERP")] = "PEMEX 6 5/8 01/01/9999"
##################  Change here only

names_list = [item.split(' ',1)[0] + ' ' + item.rsplit(' ',1)[0].split(' ',1)[1] + '% due ' + item.rsplit('/',1)[-1] for item in names_list]

fields = [          
          ["DB(SAGE,INSTRUMENT,id_isin,", ",StatCdsPESpreadAsk)"],
          ["DB(SAGE,INSTRUMENT,id_isin,", ",StatCdsPESpreadBid)"],
          ["DB(SAGE,INSTRUMENT,id_isin,", ",StatCdsBasis)"],
         ]

field_names = ['PECS Ask', 'PECS Bid','Basis',]

dq_list = []
full_names = []

for i in range(len(isin_list)):
    for j in range(len(fields)):
        dq_list = dq_list + [fields[j][0] + isin_list[i] + fields[j][1]]
        full_names = full_names + [names_list[i] + ' ' + field_names[j]]

labels = dict(zip(full_names, dq_list))

######################################################### Hash this for non-live
try:
    if update_live:
        cl = 'jbAIMF2Tkp0JO3sc'
        # cl = '0'
    dq = DataQuery(
    client_id=cl,
    client_secret='d7qfzgt55pddjs352sgxosFyI4t2eja07k7opbi6wg9oqjc1OjkdAksn1btmnugeMjchcx2vwTsJupw',
    )
    job = dq.create_job(expressions = list(labels.values()))
    dq.start_date = 'TODAY-5Y'
    job.execute(alert_long_requests='ignore')
    df = job.to_pivot_table()
    df = df.T
    df.index.name = 'Date'
    df.index = pd.to_datetime(df.index, format='%Y%m%d').date
    df.columns.name = None
    
    df1 = pd.DataFrame()
    for key in labels:
        df1[key] = df[labels[key]]
    
    df1 = df1[list(labels.keys())].copy()
    clear_output(wait=False)
    df1.dropna(axis=1, how='all', inplace=True)
    
    df1.columns = df1.columns.str.replace("DQ PECS", "DQ PECS Rich/Cheap")
    df1.columns = df1.columns.str.replace("DQ Z_SPREAD", "DQ Z_SPREAD Rich/Cheap")
    df_back = df1.copy()
    df_back.to_excel("DQ_Data_v75.xlsx")
    
    # else:
    #     df_back = pd.concat([df_back[~df_back.index.isin(df.index)], df])
    #     df_back.to_excel("DQ_Data_v75.xlsx")

except Exception as e:
    print(f"JPM DQ error, continuing with old data: {e}")
# Out:
# JPM DQ error, continuing with old data: name 'cl' is not defined

# %%
try:
    if not update_live:
        df_original = pd.read_parquet("Markit CDS.parquet/")
    else:
        df_original = pd.read_parquet("Markit CDS.parquet")
    
    to_date = datetime.today().date()
    from_date = df_original["close_date"].iloc[-1].date()
    
    from_date_str = from_date.strftime('%m/%d/%Y')
    to_date_str = to_date.strftime('%m/%d/%Y')
    
    conn_str = (
        f'DRIVER={{SQL Server}};'
        f'SERVER=BC-ODS-P1;'
        f'DATABASE=MarkitDB;'
        f'ApplicationIntent=ReadOnly;'
        f'Trusted_Connection=Yes;'
        f'Authentication=ActiveDirectoryIntegrated;'
    )
    
    conn = pyodbc.connect(conn_str)
    
    query1 = f"""
        DECLARE @FromDate DATE = '{from_date_str}';
        DECLARE @ToDate DATE = '{to_date_str}';
        
        SELECT sc.close_date, r.ticker, c.red, c.tier, c.docclause, c.ccy, sc.tenor, sc.spread
        FROM dbo.RedEntities r
        INNER JOIN dbo.MarkitCurves c ON r.red = c.red
        INNER JOIN dbo.MarkitSpreadCurve sc ON c.curve_id = sc.curve_id
        WHERE sc.close_date >= @FromDate AND sc.close_date <= @ToDate;
    """
    
    df_new = pd.read_sql(query1, conn)
    conn.close()

    df_old = df_original[df_original["close_date"]<pd.to_datetime(df_original["close_date"].iloc[-1])]

    df1 = pd.concat([df_old, df_new])
    df1 = df1.drop_duplicates()
    df1.to_parquet("Markit CDS.parquet")
except:
    df1 = pd.read_parquet("Markit CDS.parquet")
    hello = 1

# %%
# dfx = df1[["ticker","red","prev_red"]].drop_duplicates().copy()
# dfx1 = dfx[~pd.isna(dfx["prev_red"])].reset_index(drop=True).copy()
# red_dict = dict(zip(dfx1["prev_red"], dfx1["red"]))
# name_dict = dict(zip(dfx1["red"], dfx1["ticker"]))

# df1["red"] = df1["red"].apply(lambda x: red_dict[x] if x in red_dict.keys() else x)
# df1["ticker"] = df1["red"].apply(lambda x: name_dict[x] if x in name_dict.keys() else x)
# df1 = df1.drop(["prev_red","next_red"], axis=1).reset_index(drop=True).copy()
# df1 = df1.drop_duplicates(keep="last").copy()

# %%
markit_cds = list(set(df1["red"]))
markit_df1 = df1.copy()

res_codes = { "Full Restructuring": "CR14", "Modified Restructuring": "MR14",
          "Modified-Modified Restructurin": "MM14", "No Restructuring": "XR14"}

excel_df = None
all_dq = None
all_temp_cds = None

for rating_col in["IG","HY","EUR_IG","EUR_HY","SNRFIN","SUBFIN","Extras"]:
    dq = pd.read_excel("New CDX Members.xlsx", sheet_name=rating_col)
    # dq = pd.read_excel("CDX Members.xlsx", sheet_name=rating_col)
    dq["Restructuring"] = dq["Restructuring"].apply(lambda x: res_codes[x])
    dq = dq[dq["Actual RED Code"].isin(markit_cds)].reset_index(drop=True).copy()
    dq.rename(columns={"Actual RED Code": "red"}, inplace=True)
    
    if not "Family" in dq.columns:
        dq["Family"] = [rating_col]*len(dq)
        
    if not "tier" in dq.columns:
        dq["tier"] = "SNRFOR" if rating_col != "SUBFIN" else "SUBLT2"
    
    dq["ccy"] = dq["Family"].apply(lambda x: "USD" if x in ["IG","HY"] else "EUR")
    dq = dq.drop(["5Y CDS Ticker","ISIN","RED Code","Company Name","Corp Ticker"],axis=1)
    
    all_dq = pd.concat([all_dq, dq]).drop_duplicates(keep="first").reset_index(drop=True).copy()

unique_all_dq = all_dq.drop("Family",axis=1).drop_duplicates().reset_index(drop=True).copy()
unique_all_dq.columns = unique_all_dq.columns.str.replace("Restructuring","docclause")

cds_df = pd.merge(left=markit_df1, right = unique_all_dq, on=["red","docclause","tier","ccy"], how="inner")
cds_df["close_date"] = pd.to_datetime(cds_df["close_date"])
cds_df = cds_df[cds_df["tenor"]!="Spot"]
cds_df["tenor"] = cds_df["tenor"].apply(lambda x: eval(x.replace("y","*1").replace("m","*(1/12)")))

cds_df["ticker_red_tier_ccy_docclause"] = (cds_df["ticker"].astype(str) + "_" + cds_df["red"].astype(str) +\
     "_" + cds_df["tier"].astype(str) + "_" + cds_df["ccy"].astype(str) + "_" + cds_df["docclause"].astype(str))
cds_df = cds_df.drop(["ticker","red","tier","ccy","docclause"],axis=1)

########################### Creating map for family
f = all_dq.drop_duplicates().reset_index(drop=True).copy()
f1 = f["Issuer Equity"].astype(str) + "_" + f["red"].astype(str) + "_" +\
f["tier"].astype(str) + "_" + f["ccy"].astype(str)  + "_" + f["Restructuring"].astype(str)
f2 = f["Family"]
f_dict = dict(zip(f1,f2))

# %%
##############################################################################################################

issuers = list(sorted(set(cds_df["ticker_red_tier_ccy_docclause"])))
last_dt = max(cds_df["close_date"])

all_curves = None

try:
    if not update_live:
        all_curves = pd.read_excel("All CDS Curves.xlsx/") ############## made to fail
    for issuer in issuers:
        df = cds_df[cds_df["ticker_red_tier_ccy_docclause"]==issuer]
        df = pd.pivot_table(df, values="spread", index="close_date", columns ="tenor")
        
        if not last_dt in df.index:
            df.loc[last_dt] = [np.nan] * len(df.columns)
        df = df.sort_index().ffill().copy()
        df[f"{issuer}_curve"] = [np.nan] * len(df)
    
        for idx in df.index:
            curve = df.loc[[idx],:].dropna(axis=1)
            curve = curve.iloc[:,:-1].copy()
            x = list((curve.columns))
            x2 = [item**2 for item in x]
            X = np.column_stack([x, x2])
            Y = list(curve.iloc[0])
    
            if len(X) > 2:
                model = sm.OLS(Y, sm.add_constant(X)).fit()
                df.loc[idx,f"{issuer}_curve"] = str([model.params[0], model.params[1], model.params[2]])
                
                # x_pred = list(np.linspace(min(x), max(x),100))
                # x_pred2 = [item**2 for item in x_pred]
                # X_pred = np.column_stack([x_pred, x_pred2])
                # y_pred = model.predict(sm.add_constant(X_pred))
                # plt.plot(x, Y)
                # plt.plot(x_pred, y_pred)
                # title = f"{issuer} on {str(idx.date())}"
                # plt.title(title)
                # # plt.savefig(f"Curve Plots v2/{title}.png")
                # plt.show()
                # plt.close()
                
            else:
                df.loc[idx,f"{issuer}_curve"] = str([np.nan, np.nan, np.nan])
    
        all_curves = pd.concat([all_curves,df.iloc[:,[-1]]],axis=1)
    all_curves.to_excel("All CDS Curves.xlsx")
except:
    all_curves = pd.read_excel("All CDS Curves.xlsx",index_col=0, parse_dates=True)
    hello=1

all_curves1 = all_curves.copy()
all_curves = all_curves.T.copy()
all_curves.index.name = "ticker_red_tier_ccy_docclause"
all_curves.columns = [f'CDS_{item.date()}' for item in all_curves.columns]
all_curves = all_curves.reset_index(drop=False).copy()
all_temp_cds = all_curves.copy()
all_temp_cds["Temp"] = (all_temp_cds["ticker_red_tier_ccy_docclause"].astype(str).\
    str.split("_", n=1).str[1].str.replace("_curve", "", regex=False))

# %%
unique_all_dq["Issuer Equity_red_tier_ccy_docclause"] = (unique_all_dq["Issuer Equity"].astype(str) + "_" + unique_all_dq["red"].astype(str) +\
     "_" + unique_all_dq["tier"].astype(str) + "_" + unique_all_dq["ccy"].astype(str) + "_" + unique_all_dq["docclause"].astype(str))
unique_all_dq = unique_all_dq.drop(["Issuer Equity","red","tier","ccy","docclause"],axis=1)
unique_all_dq["Temp"] = unique_all_dq["Issuer Equity_red_tier_ccy_docclause"].astype(str).str.split("_", n=1).str[1]

df2 = pd.merge(left=unique_all_dq, right=all_temp_cds, on="Temp", how="inner").drop(["Temp","ticker_red_tier_ccy_docclause"], axis=1)

# %%
markit_to_bbg_tier_map = {"SNRFOR": "Sr Unsecured", "SUBLT2": "Subordinated"}

l1 = [item.split("_")[0] for item in df2["Issuer Equity_red_tier_ccy_docclause"]]
l2 = [markit_to_bbg_tier_map[item.split("_")[2]] for item in df2["Issuer Equity_red_tier_ccy_docclause"]]
l3 = [item.split("_")[3] for item in df2["Issuer Equity_red_tier_ccy_docclause"]]
l4 = [item.split(" ")[0] for item in df2["Bond Name"]]
bbg_bonds_dict = {}

for i in range(len(l1)):
    bbg_bonds_dict[f"{l1[i]} Equity_{l2[i]}_{l3[i]}"] = l4[i]

# %%
df2
# Out:
#      Primary ISIN            Bond Name Issuer Equity_red_tier_ccy_docclause  \
# 0    US007903BD80   AMD 2 1/8 09/01/26        AMD US_007G93_SNRFOR_USD_XR14
# 1    US02005NBW92  ALLY 5.543 01/17/31       ALLY US_0C205P_SNRFOR_USD_XR14
# 2    US02209SAU78    MO 2 5/8 09/16/26         MO US_0C4291_SNRFOR_USD_XR14
# 3    US023135BY17   AMZN 1.65 05/12/28       AMZN US_0C5448_SNRFOR_USD_XR14
# 4    US025537AJ08     AEP 3.2 11/13/27        AEP US_027A8A_SNRFOR_USD_XR14
# ..            ...                  ...                                  ...
# 455  US06051GHQ55   BAC 3.974 02/07/30        BAC US_0G655D_SNRFOR_USD_XR14
# 456  US617446HD43    MS 7 1/4 04/01/32         MS US_678B8A_SNRFOR_USD_XR14
# 457  US172967ME81      C 3.98 03/20/30          C US_189BFD_SNRFOR_USD_XR14
# 458  US037833CR93    AAPL 3.2 05/11/27       AAPL US_03AFCJ_SNRFOR_USD_XR14
# 459  US345397ZR75     F 5.113 05/03/29         F1 US_3H994Q_SNRFOR_USD_XR14
#
#                                         CDS_2020-08-19  \
# 0    [0.8372625856702949, 9.279393523861632, -0.277...
# 1    [30.028124050907792, 19.450190485600302, -0.53...
# 2    [-1.4535430612061404, 9.50948057059177, -0.253...
# 3                                                  NaN
# 4    [-0.20205765446279056, 5.022340156607932, -0.1...
# ..                                                 ...
# 455  [20.08551467570509, 7.444646014507276, -0.1983...
# 456  [26.001941550645, 7.334648778890823, -0.187349...
# 457  [30.28215057099772, 7.402512071999836, -0.1934...
# 458  [3.5608298552050144, 5.916367915905746, -0.141...
# 459  [171.9739748227111, 30.64838899811254, -1.1152...
#
#                                         CDS_2020-08-20  \
# 0    [0.8498427987975115, 9.030594568444887, -0.273...
# 1    [30.40636405188383, 19.53399682750579, -0.5394...
# 2    [-1.8734126098485104, 9.567102605604621, -0.25...
# 3                                                  NaN
# 4    [-0.22520924509148843, 5.0301781260548655, -0....
# ..                                                 ...
# 455  [22.668784840093004, 7.120102234369864, -0.188...
# 456  [26.702583713811954, 7.252012500270558, -0.183...
# 457  [30.76310111970904, 7.3572772676661105, -0.189...
# 458  [3.5582705888251307, 5.917314707481804, -0.141...
# 459  [167.30500769826074, 33.32592534427086, -1.180...
#
#                                         CDS_2020-08-21  \
# 0    [0.9649237974050742, 8.954752265969638, -0.271...
# 1    [30.547143897859264, 19.772555332453813, -0.54...
# 2    [-2.708983497213513, 9.919061229785022, -0.269...
# 3                                                  NaN
# 4    [-0.27949246549036966, 5.050288881972781, -0.1...
# ..                                                 ...
# 455  [20.9407126655196, 7.342772222442738, -0.19216...
# 456  [26.116976434813616, 7.316162883797713, -0.184...
# 457  [31.004153788930473, 7.4399549772258915, -0.19...
# 458  [3.557251388702037, 5.9173086248824855, -0.141...
# 459  [172.30829141059368, 32.09016724488599, -1.145...
#
#                                         CDS_2020-08-24  \
# 0    [-0.9525211181988311, 9.713454546281366, -0.30...
# 1    [30.027581157606903, 19.360572616191952, -0.53...
# 2    [-2.5254567727119177, 9.762836237764123, -0.26...
# 3                                                  NaN
# 4    [-0.11172797125945344, 4.936697365282013, -0.1...
# ..                                                 ...
# 455  [20.13151598560581, 7.278816693217979, -0.1912...
# 456  [25.588860937108898, 7.2389961913029195, -0.18...
# 457  [29.906300916528693, 7.274961684546892, -0.185...
# 458  [4.6810708100900555, 5.653267519875913, -0.133...
# 459  [162.87107096035174, 31.091995242654164, -1.13...
#
#                                         CDS_2020-08-25  \
# 0    [1.8356735227523822, 8.358580523384543, -0.262...
# 1    [28.327094775680237, 19.49739651202156, -0.544...
# 2    [-2.5726612179972017, 9.674093154776413, -0.25...
# 3                                                  NaN
# 4    [-0.05424755703286932, 4.9096369437120675, -0....
# ..                                                 ...
# 455  [19.243980658895772, 7.241988260784442, -0.188...
# 456  [25.13304910245911, 7.252237105604781, -0.1790...
# 457  [27.64043928851018, 7.494704695996744, -0.1930...
# 458  [4.235528694904969, 5.768249585844435, -0.1366...
# 459  [166.88806572073494, 29.330054121503945, -1.07...
#
#                                         CDS_2020-08-26  \
# 0    [2.187292635700892, 8.012246016194469, -0.2524...
# 1    [29.671452345239743, 19.312386566168108, -0.53...
# 2    [-1.867971347201312, 9.565826607069559, -0.256...
# 3                                                  NaN
# 4    [0.006344485549592882, 4.87803459417785, -0.11...
# ..                                                 ...
# 455  [19.265300497216906, 7.162370871801765, -0.186...
# 456  [24.008181394328695, 7.252700347423181, -0.182...
# 457  [28.04162840908954, 7.361335101108869, -0.1886...
# 458  [4.981464263987478, 5.586136807790325, -0.1313...
# 459  [162.66159642696232, 27.5666649361956, -1.0268...
#
#                                         CDS_2020-08-27  ...  \
# 0    [1.0169576299558156, 8.75711685554895, -0.2671...  ...
# 1    [27.758459231162714, 19.606189245303884, -0.54...  ...
# 2    [-1.7736175166601225, 9.564357292899146, -0.25...  ...
# 3                                                  NaN  ...
# 4    [0.08699931414733442, 4.848193895496097, -0.11...  ...
# ..                                                 ...  ...
# 455  [18.85471846970247, 7.15185927115278, -0.18625...  ...
# 456  [24.304557473183884, 7.23559629391625, -0.1809...  ...
# 457  [26.85572591042414, 7.4294906507159455, -0.190...  ...
# 458  [4.361331468060296, 5.740819722764842, -0.1358...  ...
# 459  [154.93441231665517, 29.683456810741966, -1.08...  ...
#
#                                         CDS_2025-08-21  \
# 0    [5.444774394228691, 7.380957967553417, -0.1807...
# 1    [22.527197436019282, 23.79556570788299, -0.772...
# 2    [1.1239071940742829, 8.80970041940753, -0.2480...
# 3    [6.048594549730638, 4.03868181171535, -0.11584...
# 4    [2.6304095210141867, 7.198266021423531, -0.200...
# ..                                                 ...
# 455  [19.364231543306836, 7.855052821553414, -0.218...
# 456  [16.897784491380307, 8.109791713084753, -0.228...
# 457  [19.995162954802492, 7.724904087070935, -0.210...
# 458                                                NaN
# 459  [38.72159864973184, 27.296277010692545, -0.927...
#
#                                         CDS_2025-08-22  \
# 0    [5.31455517512442, 7.292360466436823, -0.18292...
# 1    [21.234443385805257, 23.462409772051338, -0.76...
# 2    [0.9921025488965483, 8.607730421621596, -0.238...
# 3    [5.660344586582568, 4.118745857774828, -0.1166...
# 4    [2.5077762294203056, 7.032441383112022, -0.194...
# ..                                                 ...
# 455  [18.539294699711977, 7.773926822512433, -0.217...
# 456  [15.908593674879718, 8.062559920229736, -0.225...
# 457  [19.14834146501463, 7.64253868162046, -0.20777...
# 458                                                NaN
# 459  [37.695558697273924, 26.579870677266143, -0.90...
#
#                                         CDS_2025-08-25  \
# 0    [5.02175542054025, 7.396894059074755, -0.18562...
# 1    [20.896372300352137, 23.62456272276357, -0.764...
# 2    [0.6895190791044499, 8.925520764336397, -0.246...
# 3    [5.7518613019822675, 4.119300298836517, -0.115...
# 4    [2.566741217249719, 7.0092948450717, -0.192516...
# ..                                                 ...
# 455  [18.522768172228144, 7.704103178047565, -0.213...
# 456  [15.64530351679888, 8.121004155617602, -0.2271...
# 457  [18.928311466765894, 7.634992696918907, -0.206...
# 458                                                NaN
# 459  [39.039021929856, 25.962812293864488, -0.88286...
#
#                                         CDS_2025-08-26  \
# 0    [4.634736069133652, 7.4888641980078745, -0.191...
# 1    [20.89089242522398, 23.70374892507358, -0.7732...
# 2    [0.3678837173834917, 9.035180095614612, -0.249...
# 3    [5.724065840177493, 4.1163408192725335, -0.116...
# 4    [2.6676593888065474, 7.047983407314623, -0.196...
# ..                                                 ...
# 455  [19.078823385566736, 7.683517465460343, -0.213...
# 456  [16.004476612591766, 8.073507700149014, -0.225...
# 457  [19.461018025082375, 7.640397690369491, -0.207...
# 458                                                NaN
# 459  [38.347016274388444, 27.104926679063162, -0.90...
#
#                                         CDS_2025-08-27  \
# 0    [6.106484434253472, 7.208000926162832, -0.1815...
# 1    [22.181291455820322, 23.27748845407517, -0.754...
# 2    [1.369045172241301, 8.42667763449008, -0.23343...
# 3    [6.359765273966282, 4.685281558723677, -0.1270...
# 4    [3.0174580904227724, 6.9536045542524345, -0.19...
# ..                                                 ...
# 455  [19.36005860539356, 7.732062993720855, -0.2149...
# 456  [16.3514071212242, 8.143945063476284, -0.22917...
# 457  [19.631167497726196, 7.706809392788688, -0.210...
# 458                                                NaN
# 459  [38.68749749511808, 26.239181073053665, -0.884...
#
#                                         CDS_2025-08-28  \
# 0    [5.894963723550783, 7.259361950861997, -0.1870...
# 1    [22.159510035505328, 23.276597662345296, -0.75...
# 2    [1.0034954940017866, 8.70145268378926, -0.2410...
# 3    [5.656514100773524, 4.648702196166427, -0.1302...
# 4    [2.9742516525806635, 7.022974850860475, -0.195...
# ..                                                 ...
# 455  [19.731272054955177, 7.844720018768036, -0.220...
# 456  [16.515039542379313, 8.264634045692908, -0.232...
# 457  [19.625152124077594, 7.807075617524603, -0.214...
# 458                                                NaN
# 459  [38.50481436356451, 26.09851147409354, -0.8782...
#
#                                         CDS_2025-08-29  \
# 0    [5.767481564264938, 7.6272165108369405, -0.193...
# 1    [22.3223406017298, 23.401477264287326, -0.7525...
# 2    [0.7127466823793482, 8.915283102312461, -0.248...
# 3    [5.659829962749516, 4.7322246139031465, -0.135...
# 4    [2.9508148134877175, 7.055391241354753, -0.197...
# ..                                                 ...
# 455  [20.162420908092855, 7.773994849558209, -0.217...
# 456  [16.094031260807746, 8.419068959941356, -0.237...
# 457  [19.706592853719457, 7.909655152426986, -0.216...
# 458                                                NaN
# 459  [38.55430646345349, 25.946384379207743, -0.876...
#
#                                         CDS_2025-09-01  \
# 0    [5.791168790010509, 7.48899513130021, -0.18808...
# 1    [23.025982917841908, 23.20220896298751, -0.749...
# 2    [0.5783015636297315, 8.975727983419432, -0.248...
# 3    [5.80867868006253, 4.680321314255389, -0.13251...
# 4    [2.728516521396039, 7.124189683029494, -0.1990...
# ..                                                 ...
# 455  [19.848247166518824, 7.813017924231424, -0.219...
# 456  [15.581421022172384, 8.41225400893709, -0.2371...
# 457  [18.745724709831382, 8.022986725236429, -0.222...
# 458                                                NaN
# 459  [38.74230214701855, 25.883757033951184, -0.870...
#
#                                         CDS_2025-09-02  \
# 0    [6.103733842898283, 7.719196540303489, -0.1917...
# 1    [23.537512359283614, 23.52373975573861, -0.769...
# 2    [0.6036270271173119, 9.209255096184584, -0.257...
# 3    [7.201764790718539, 4.253915073757446, -0.1223...
# 4    [3.049784995769527, 7.194594637093553, -0.2012...
# ..                                                 ...
# 455  [20.06426433221634, 7.978156674784562, -0.2227...
# 456  [16.903882946593566, 8.407584983618635, -0.237...
# 457  [20.097256089206464, 7.952366021219345, -0.218...
# 458                                                NaN
# 459  [39.98835755511247, 26.638889051984492, -0.896...
#
#                                         CDS_2025-09-03
# 0    [5.864556417832644, 7.7753243447392055, -0.194...
# 1    [22.954281773993266, 23.62034248366741, -0.774...
# 2    [0.6036270271173119, 9.209255096184584, -0.257...
# 3    [6.046254166179153, 4.8795663731105865, -0.138...
# 4    [3.049784995769527, 7.194594637093553, -0.2012...
# ..                                                 ...
# 455  [19.865949602999294, 8.043870383486144, -0.225...
# 456  [16.409688884652077, 8.482576452396167, -0.240...
# 457  [20.225325130010198, 7.9493631685016535, -0.21...
# 458  [4.812528643699346, 2.1470566207603214, -0.046...
# 459  [38.483612933699774, 26.69948534894465, -0.900...
#
# [460 rows x 1319 columns]

# %%
stock = "KSS"

peers = df2.iloc[:,[1,2]].copy()
peers["Equity"] = peers["Issuer Equity_red_tier_ccy_docclause"].apply(lambda x: x.split("_")[0]+" Equity")
peers["Name"] = peers["Bond Name"].apply(lambda x: x.split(" ")[0])
peers = peers[["Name","Equity"]].copy()
# bg = blp.bdp(tickers=list(set(peers["Equity"])), flds="GICS_SECTOR_NAME")
bg = blp.bdp(tickers=list(set(peers["Equity"])), flds="GICS_INDUSTRY_NAME")
bg1 = bg.reset_index().copy()
bg1.columns=[ "Equity","Sector"]
dfy = pd.merge(left=peers, right=bg1, on="Equity", how="outer")
dfy = dfy[dfy["Sector"]==dfy[dfy["Name"]==stock]["Sector"].iloc[0]].reset_index(drop=True).copy()

country = dfy[dfy["Name"]==stock]["Equity"].iloc[0].split(" ",1)[1]
comp_eq = dfy["Equity"].to_list()
dfy["Country"] = dfy["Equity"].apply(lambda x: x.split(" ",1)[1])
dfy = dfy[dfy["Country"]==country].drop(["Sector","Country"],axis=1)
dfy["CDS Srch"] = dfy["Equity"].str.replace(" Equity","")

# %%
eq = cds_df[cds_df["Issuer Equity"].isin(dfy["CDS Srch"].to_list())].copy()
eq = eq[eq["tenor"]==5].drop(["tenor","Bond Name","ticker_red_tier_ccy_docclause","Primary ISIN"],axis=1).copy()
# for item in set(eq["Issuer Equity"]):
#     cd = eq[eq["Issuer Equity"]==item]
eq = pd.pivot_table(columns="Issuer Equity",index="close_date",values="spread", data=eq).copy()
eq = eq[eq.index>datetime.now()-timedelta(days=365*2)].iloc[:,:10]
eq.plot(figsize=(15,6))
plt.title("5Y CDS spreads for KSS's GICS_SECTOR_NAME (2years)")
plt.show()

# %%
eq1 = eq.copy()
# beq = blp.bdh(tickers=[item+" Equity" for item in eq1.columns],flds="TOT_RETURN_INDEX_GROSS_DVDS",start_date=datetime.now()-timedelta(days=2*365))
# beq = blp.bdh(tickers=[item+" Equity" for item in eq1.columns],flds="PX_LAST",start_date=datetime.now()-timedelta(days=2*365))
beq1 = beq.copy()
beq1.columns = [item[0] for item in beq1.columns]
# beq1 = beq1/beq1.iloc[0]
ax=beq1[["JWN US Equity","KSS US Equity"]].plot(figsize=(15,6))
beq1["AMZN US Equity"].plot(ax=ax,secondary_y=True)
plt.title("Equity for KSS's GICS_SECTOR_NAME (2years)\nJWN was acquired in May-2025")
plt.show()
beq1.index = pd.to_datetime(beq1.index)

# %%
col = "JWN US Equity"
t = pd.concat([beq1[col],eq1[col.rsplit(" ",1)[0]]],axis=1)
t.columns = ["Equity","5Y CDS"]
plt.figure(figsize=(15,6))
plt.scatter(t["Equity"].iloc[:-252],t["5Y CDS"].iloc[:-252], color="gray", label=">1Y")
plt.scatter(t["Equity"].iloc[-252:-63],t["5Y CDS"].iloc[-252:-63], color="blue", label=">3M & 1Y")
plt.scatter(t["Equity"].iloc[-63:-2],t["5Y CDS"].iloc[-63:-2], color="green", label="<3M")
plt.scatter(t["Equity"].iloc[-2:],t["5Y CDS"].iloc[-2:], color="red", label="Latest Value")
plt.xlabel("Eq. Level")
plt.ylabel("CDS")
plt.title(col)
# plt.legend()
plt.show()

# %%
# ##########################################################################This Data was copied to All Bonds sheet
# bql_list = []

# fl = [f"""=BQL("filter(bonds(['""",
#       f"""']), payment_rank=='""",
#       f"""' AND crncy=='""",
#       f"""')", "id_isin, id_cusip, name, maturity, amt_outstanding")"""]

# for item, key in bbg_bonds_dict.items():
#     bql_list += [fl[0] + item.split("_")[0] + fl[1] + item.split("_")[1] + fl[2] + item.split("_")[2] + fl[3]]

    
# bql_list = [item.replace("\\", "") for item in bql_list]

# workbook = openpyxl.load_workbook(r"J:\\HY Basis Data.xlsx")
# sheet = workbook.active

# for row in sheet.iter_rows():
#     for cell in row:
#         cell.value = None

# start_col = 1
# for item in bql_list:
#     cell = sheet.cell(row=2, column=start_col)
#     cell.value = item
#     start_col += 6
# workbook.save(r"J:\\HY Basis Data.xlsx")

# file_path = r"J:\\HY Basis Data.xlsx"
# window_title = "HY Basis Data - Excel"

# subprocess.Popen(['start', 'excel', file_path], shell=True)
# time.sleep(5)

# excel_windows = [window for window in gw.getWindowsWithTitle('Excel')]

# for window in excel_windows:
#     if window_title in window.title:
#         # time.sleep(0.5)
#         window.activate()
#         break

# time.sleep(45)
# pyautogui.hotkey('ctrl', 's')
# time.sleep(1)
# # pyautogui.hotkey('alt', 'f4')

# time.sleep(1.5)

# %%
bonds_map = []
markit_to_bbg_tier_map_reverse = dict(zip(list(markit_to_bbg_tier_map.values()), list(markit_to_bbg_tier_map.keys())))

for i in range(len(l1)):
    bonds_map += [f"{l1[i]}_{markit_to_bbg_tier_map_reverse[l2[i]]}_{l3[i]}"]

# %%
# df = pd.read_excel("All Bonds.xlsx", sheet_name="All Bonds")
df = pd.read_excel("All Bonds.xlsx", sheet_name="New All Bonds")
l5 = [item.split("_")[0].replace(" Equity","") + "_" + markit_to_bbg_tier_map_reverse[item.split("_")[1]] +\
      "_" + item.split("_")[2] for item in list(bbg_bonds_dict.keys())]
l6 = list(bbg_bonds_dict.values())

all_df = None

for i in range(len(df.columns))[::6]:
    x = df.iloc[:,i:i+6].dropna().copy()
    # try:
    if len(x) > 0:
        x.columns = ['ID','ISIN', "CUSIP", 'Name', 'Maturity','Amt']
        x["Issuer Equity_tier_ccy"] = [l5[int(i/6)]] * len(x)
        x["Bond Name"] = [l6[int(i/6)]] * len(x)
        x["Check Col"] = x.apply(lambda row: row["Name"].split(" ")[0]==row["Bond Name"],axis=1)
        x = x[x["Check Col"]].drop(["Check Col","Bond Name"],axis=1)
        all_df = pd.concat([all_df, x])
    # except:
    #     hello = 1

all_df['Time'] = round(((pd.to_datetime(all_df['Maturity'])-datetime.now()).dt.days/365),2)
all_df = all_df[all_df["Time"]>=0]
all_df = all_df[(all_df['Time']>=4) & (all_df['Time']<=10)]
all_df = all_df[all_df['Amt']>=300*10**6]
all_df = all_df.reset_index(drop=True)
excel_df = pd.concat([excel_df, all_df])
all_df = excel_df.copy()

all_df = all_df.drop_duplicates(keep="first").reset_index(drop=True).copy()

########################################################################################### 144A and REGS

blist = [f'/isin/{item}@BGN' for item in list(all_df["ISIN"])]
if update_live:
    blist = blp.bdp(tickers=blist, flds=["144A_FLAG","IS_REG_S"])
    blist.to_parquet("144A.parquet")
blist = pd.read_parquet("144A.parquet")
blist.index = [item.rsplit("/",1)[1].split("@")[0] for item in blist.index]

blist.columns = ["144A","REGS"]
blist.index.name = "ISIN"
blist = blist.reset_index()
blist["REGS_144A"] = blist.apply(lambda row: f'{row["REGS"]}_{row["144A"]}',axis=1)
order = ["N_N", "Y_N", "Y_Y", "N_Y"]

all_df = pd.merge(left=all_df, right=blist, on="ISIN", how="outer")
all_df = all_df[[item for item in all_df.columns if not item in ["144A","REGS"]]]

all_df["REGS_144A"] = pd.Categorical(all_df["REGS_144A"], categories=order, ordered=True)
all_df = all_df.sort_values(by="REGS_144A")
all_df = all_df[~all_df["Name"].duplicated(keep='first')].drop(["REGS_144A","Time"],axis=1).reset_index(drop=True).copy()

# %%
t = [f"/isin/{item}@BGN" for item in list(all_df["ISIN"])]
if update_live:
    bbg = blp.bdh(tickers=t, flds="BLOOMBERG_MID_G_SPREAD", start_date=datetime.now()-timedelta(days=365*5))
    bbg.to_parquet("Test1.parquet")
bbg = pd.read_parquet("Test1.parquet")

bbg1 = bbg.copy()
new = []
for item in bbg1.columns:
    new += ["BBG_" + item[0].replace("/isin/","").replace("@BGN","")]
bbg1.columns = new
bbg1.index = pd.to_datetime(bbg1.index)

############################################################ choose bbg or dq sprds

bbg1.columns = [item.split("_")[1] for item in bbg1.columns]
bbg1.index = [f"Sprd_{str(item.date())}" for item in bbg1.index]
bbg1 = bbg1.T.copy()
bbg1.index.name = "ISIN"
bbg1 = bbg1.reset_index(drop=False).copy()

# %%
df2a = df2.drop(["Primary ISIN","Bond Name"],axis=1).copy()
df2a["Issuer Equity_tier_ccy"] = [item.split("_")[0] + "_" + item.split("_")[2] +\
               "_" + item.split("_")[3] for item in df2a["Issuer Equity_red_tier_ccy_docclause"]]
# df2a = df2a.replace(np.nan,"[np.nan, np.nan, np.nan]")
df3 = pd.merge(left=all_df, right=df2a, on="Issuer Equity_tier_ccy",\
               how="inner").drop(["ID","Amt","Issuer Equity_tier_ccy"],axis=1).copy()

for dt in pd.to_datetime(bbg.index):
    df3[f'Mat_Time_{dt.date()}'] = [((pd.to_datetime(item) - dt).days/365) for item in df3["Maturity"]]

df4A = df3.copy()
dt_list = [item.replace("CDS_","") for item in df4A.columns if item.startswith("CDS_")]

def safe_literal_eval(x):
    try:
        return ast.literal_eval(x) if isinstance(x, str) else [np.nan, np.nan, np.nan]
    except (ValueError, SyntaxError):
        return [np.nan, np.nan, np.nan]

for dt in dt_list:
    if f"Mat_Time_{dt}" in df4A.columns and f"CDS_{dt}" in df4A.columns:
        cds_values = df4A[f'CDS_{dt}'].apply(safe_literal_eval)
        mat_time = df4A[f'Mat_Time_{dt}']

        df4A[f'Mat_Matched_CDS_{dt}'] = (
            cds_values.apply(lambda x: x[0]) +
            mat_time * cds_values.apply(lambda x: x[1]) +
            mat_time**2 * cds_values.apply(lambda x: x[2]))

df4 = df4A[["ISIN","CUSIP","Name","Maturity","Issuer Equity_red_tier_ccy_docclause"] +\
    [col for col in df4A.columns if col.startswith("Mat_Matched_CDS")]].copy()

# %%
#################################################### Duration Data

dq_bonds = ['US50077LBF22','US49456BAG68','US49456BAR24','US49456BAV36','US49456BAX91','US500255AX28','US50077LAL09','US50077LAV80','US50077LBN55','US526057CY87','US530715AJ01','US501044DV05','US48666KAY55','US48666KAZ21','US48666KBA60','US620076BT59','US626717AP72','US63938CAN83','US63938CAP32','US63938CAQ15','US651229BD74','US549271AF19','US55262CAJ99','US552676AT59','US552676AU23','US552953CJ87','US552953CK50','US55342UAM62','US55616XAM92','US58013MFQ24','US382550BJ95','US382550BK68','US382550BR12','US382550BS94','US404119CA57','US404119CC14','US404119CK30','US404119CQ00','US404119CT49','US337932AL12','US337932AP26','US345370CA64','US345370CX67','US345370DA55','US345370DB39','US35671DBJ37','US35671DCD57','US35671DCF06','US35671DCH61','US36186CBY84','US36962GXZ26','US370334CL64','US370334CT90','US37045VAH33','US37045VAY65','US37045VAZ31','US404119DB22','US404121AK12','US458140BR09','US651229BE57','US44107TBC99','US40434LAN55','US42307TAG31','US432833AF84','US437076CB65','US44106MAY84','US44106MBB72','US44107TAY29','US44107TAZ93','US651229BF23','US89352HBA68','US893830AF64','US902494AZ66','US911363AM11','US911365BL76','US911365BP80','US91324PEJ75','US911365BN33','US88947EAU47','US85172FAR01','US87264ABF12','US87264ABT16','US87264ABW45','US87264ABX28','US87264ACB98','US87264ACQ67','US87264ACV52','US87264ADT97','US87901JAH86','US88033GAV23','US88167AAR23','US88167AAS06','US88167AAT88','US962166BR41','US963320AY28','US963320AZ92','US963320BA33','US963320BC98','US963320BD71','US963320BE54','US969457BB59','US969457BM15','US969457BZ28','US969457CJ76','US988498AN16','US988498AP63','US988498AR20','XS0161100515','US931142FC22','US92343VEU44','US92343VFX73','US92343VGN82','US92343VGY48','US92343VGZ13','US925524AH30','US925524AV24','US92556HAB33','US92556HAD98','US680665AK27','US682691AA80','US682691AE03','US682691AF77','US682691AG50','US682691AJ99','US682691AK62','US682691AL46','US68389XBV64','US68389XCE31','US68389XCH61','US68389XCJ28','US69047QAC69','US674599EL59','US674599EK76','US65339KCU25','US65339KDJ60','US65339KDK34','US65339KDL17',
'US674599DD43','US674599DE26','US674599EA94','US674599ED34','US674599EF81','US698900AG20','US75513ECR09','US78355HLC15','US78442FAZ18','US81761LAE20','US828807DT11','US716973AD41','US716973AE24','US717081EW90','US745867AM30','US745867AP60','US745867AT82','US74834LBC37','US30212PBH73','US1248EPCN14','US012873AK13','US012873AH83','US11135FAS02','US11135FBD24','US136385AE19','US134429BJ73','US126650DJ69','US00206RMM15','US126650DU15','US126650ED80','US031162DQ06','US026874DC84','US02406PBB58','US023551AM66','US023551AJ38','US097023CN34','US097023CP81','US097023CY98','US097023DC69','US097023DR39','US097023CJ22','US097023DS12','US023135AP19','US097023AU94','US023551AF16','US058498AW66','US058498AX40','US058498BA38','US07556QBT13','US08652BAB53','US071813BY49','US254709AS70','US244199BJ37','US247361ZT81','US251799AA02','US25179MBF95','US25179SAD27','US247361A329','US23331ABT51','US29273VAU44','US29273VBA70','US29278NAQ60','US30161NAX93','US30212PAR64','US29273VAT70','US29273RBE80','US28368EAD85','US28368EAE68','US292480AM22','US29273VAQ32','US292505AD65','US20030NEE76','US20030NDG34','US20030NBH35','US15089QAZ72','US15089QBA13','US15089QAY08','US00206RCP55','US15089QAP90','US00130HCG83','US15089QAX25','US205887AX04','XS2774392638','XS2655993033','XS3037720227','XS3023963534','XS3126635039','XS3106096178','XS3105513769','XS3091660194','XS2872799734','XS2870878456','XS2864439158','XS2811097075','XS2802883731','XS2826718087','XS2929387996','XS2922654418','XS2914769299','XS2904791774','XS2385393587','XS2116386132','XS2432162654','XS2247549731','XS2189766970','XS2300293003','XS2290544068','XS2056491587','XS2488809612','XS2010039894','FR001400WJR8','FR001400PAJ8','DE000A383HC1','CH0494734418','CH0591979627','DE000A4DFLQ6','US46284VAQ41','US501797AW48','US513272AD65','US513272AE49','US53219LAX73','US46284VAN10','US55617LAR33','US55617LAS16','US62482BAB80','US46284VAL53','US44332PAJ03','US46284VAF85','US37441QAA94','US428040DB25','US431318AV64','US431318AY04','US431318AZ78','US431318BC74','US431318BE31','US431318BG88','US432833AL52','US432833AN19','US432833AQ40','US432833AR23','US432833AS06','US44332PAG63','US62886HBP55','US46284VAJ08','US62886HBR12','US629377CS98','US629377CR16','US780153BV38','US780153BW11','US81211KAK60','US812127AB45','US812127AC28','US82967NBG25','US82967NBM92','US853496AG21','US853496AH04','US893830BZ10','US911365BR47','US92840VAP76','US92840VAR33','US947075AU14','US988498AL59','US780153BU54','US75606DAQ43','US737446AV69','US629377CW01','US629377CX83','US62957HAP01','US62957HAQ83','US63861CAF68','US64110LAU08','US64110LAV80','US677347CH71','US680665AN65','US68622FAB76','US68622TAB70','US737446AP91','US737446AQ74','US737446AR57','US737446AX26','US364760AQ18','US11135FBF71','US11135FBH38','US11135FBK66''US11135FBL40','US11135FBT75','US1248EPCD32','US1248EPCE15','US1248EPCK74','US1248EPCL57','US1248EPCP61','US1248EPCQ45''US1248EPCS01','US1248EPCT83','US126307BA42','US126307BB25','US103304BV23','US126307BD80','US097751CD18','US097751CB51','US00130HCC79','US01883LAD55','US01883LAH69','US03743QAQ10','US04433LAA08','US05368VAA44','US05368VAB27','US053773BH95','US053773BJ51','US053773BK25','US071734AJ60','US071734AL17','US097751AL51','US097751CA78','US097751CC35','US126307BF39','US126307BH94','US126307BK24','US224044CS42','US226373AT56','US23918KAS78','US23918KAT51','US23918KAW80','US23918KAY47','US185899AS01','US185899AR28','US12769GAA85','US12769GAD25','US131347CQ78','US143658BX94','US143658BY77','US364760AP35','US143658BZ43','US17888HAB96','US17888HAC79','US17888HAD52','US185899AL57','US185899AN14','US185899AP61','US185899AQ45','US143658CA82']

dq_bonds = list(df4["ISIN"])
all_labels = dict(zip(df4["ISIN"],[f"DB(CREDIT,HY,BOND,{item},MDUR)" for item in df4["CUSIP"]]))

labels = {}
for item in dq_bonds:
    labels[f"{item}_Dur"] = all_labels[item]

try:
    if not update_live:
        df1 = pd.read_excel("DQ HY Duration Data.xlsx/",index_col=0, parse_dates=True)
    dq = DataQuery(
        client_id='jbAIMF2Tkp0JO3sc',
        client_secret='d7qfzgt55pddjs352sgxosFyI4t2eja07k7opbi6wg9oqjc1OjkdAksn1btmnugeMjchcx2vwTsJupw',
        # calendar = 'CAL_USBANK',
    )
    
    job = dq.create_job(expressions = list(labels.values()))
    dq.start_date = str((datetime.now()-timedelta(days=5*365)).date())
    job.execute(alert_long_requests='ignore')
    df = job.to_pivot_table()
    df = df.T
    df.index.name = 'Date'
    df.index = pd.to_datetime(df.index, format='%Y%m%d').date
    df.columns.name = None
    
    df1 = pd.DataFrame()
    for key in labels:
        df1[key] = df[labels[key]]
    
    df1 = df1[list(labels.keys())].copy()
    clear_output(wait=False)
    df1.dropna(axis=1, how='all', inplace=True)
    df1.to_excel("DQ HY Duration Data.xlsx")
except:
    df1 = pd.read_excel("DQ HY Duration Data.xlsx",index_col=0, parse_dates=True)
# Out:
# 2025-09-04 20:48:50.475846+0000 UTC [INFO] pydataquery: DataQuery initialized with client_id='jbAIMF2Tkp0JO3sc'
# 2025-09-04 20:48:50.477847+0000 UTC [INFO] pydataquery: Set preferred_timezone='UTC'. current_time='2025-09-04 20:48:50.477846+0000 UTC'
# 2025-09-04 20:48:50.538521+0000 UTC [INFO] pydataquery: DataQuery default attribute `start_date` set to '2020-09-05'
# 2025-09-04 20:48:50.543540+0000 UTC [WARNING] pydataquery: Potential long process time due to date range exceeding two years: 5.0 years.
# 2025-09-04 20:48:50.544536+0000 UTC [INFO] pydataquery: DataQuery default attribute `start_date` set to '2020-09-05' (client_id='jbAIMF2Tkp0JO3sc')
# 2025-09-04 20:48:50.545927+0000 UTC [INFO] pydataquery: Execution started
# 2025-09-04 20:48:50.550938+0000 UTC [INFO] pydataquery: Prepared 234 API requests for 1,549 expressions of 4 year(s) 364 day(s): start_date=20200905, end_date=20250903
# 2025-09-04 20:48:50.552368+0000 UTC [INFO] pydataquery: Sending 1/234 API request
# 2025-09-04 20:48:50.553368+0000 UTC [INFO] pydataquery: Generating a new OAuth access token for client_id=jbAIMF2Tkp0JO3sc
# 2025-09-04 20:48:51.057986+0000 UTC [INFO] pydataquery: Generated an OAuth access token for client_id=jbAIMF2Tkp0JO3sc in 0.50 seconds. The token expires_at=2025-09-04 22:48:50+0000 UTC
# 2025-09-04 20:48:57.053492+0000 UTC [INFO] pydataquery: Received API response in 5.606231 seconds with response code 200
# 2025-09-04 20:48:57.059402+0000 UTC [INFO] pydataquery: Sending 2/234 API request
# 2025-09-04 20:49:00.694723+0000 UTC [INFO] pydataquery: Received API response in 3.257101 seconds with response code 200
# 2025-09-04 20:49:00.701820+0000 UTC [INFO] pydataquery: Sending 3/234 API request
# 2025-09-04 20:49:03.302946+0000 UTC [INFO] pydataquery: Received API response in 2.342785 seconds with response code 200
# 2025-09-04 20:49:03.306569+0000 UTC [INFO] pydataquery: Sending 4/234 API request
# 2025-09-04 20:49:08.248586+0000 UTC [INFO] pydataquery: Received API response in 4.625403 seconds with response code 200
# 2025-09-04 20:49:08.253610+0000 UTC [INFO] pydataquery: Sending 5/234 API request
# 2025-09-04 20:49:13.431182+0000 UTC [INFO] pydataquery: Received API response in 4.85653 seconds with response code 200
# 2025-09-04 20:49:13.435006+0000 UTC [INFO] pydataquery: Sending 6/234 API request
# 2025-09-04 20:49:16.975441+0000 UTC [INFO] pydataquery: Received API response in 3.423254 seconds with response code 200
# 2025-09-04 20:49:16.979486+0000 UTC [INFO] pydataquery: Sending 7/234 API request
# 2025-09-04 20:49:18.305294+0000 UTC [INFO] pydataquery: Received API response in 1.189403 seconds with response code 200
# 2025-09-04 20:49:18.308476+0000 UTC [INFO] pydataquery: Sending 8/234 API request
# 2025-09-04 20:49:21.684854+0000 UTC [INFO] pydataquery: Received API response in 3.221102 seconds with response code 200
# 2025-09-04 20:49:21.686854+0000 UTC [INFO] pydataquery: Sending 9/234 API request
# 2025-09-04 20:49:24.231374+0000 UTC [INFO] pydataquery: Received API response in 2.430567 seconds with response code 200
# 2025-09-04 20:49:24.237371+0000 UTC [INFO] pydataquery: Sending 10/234 API request
# 2025-09-04 20:49:25.740980+0000 UTC [INFO] pydataquery: Received API response in 1.314846 seconds with response code 200
# 2025-09-04 20:49:25.750026+0000 UTC [INFO] pydataquery: Sending 11/234 API request
# 2025-09-04 20:49:26.884059+0000 UTC [INFO] pydataquery: Received API response in 1.029484 seconds with response code 200
# 2025-09-04 20:49:26.891728+0000 UTC [INFO] pydataquery: Sending 12/234 API request
# 2025-09-04 20:49:29.286015+0000 UTC [INFO] pydataquery: Received API response in 2.281355 seconds with response code 200
# 2025-09-04 20:49:29.289392+0000 UTC [INFO] pydataquery: Sending 13/234 API request
# 2025-09-04 20:49:31.021292+0000 UTC [INFO] pydataquery: Received API response in 1.543629 seconds with response code 200
# 2025-09-04 20:49:31.023793+0000 UTC [INFO] pydataquery: Sending 14/234 API request
# 2025-09-04 20:49:32.964550+0000 UTC [INFO] pydataquery: Received API response in 1.789951 seconds with response code 200
# 2025-09-04 20:49:32.969563+0000 UTC [INFO] pydataquery: Sending 15/234 API request
# 2025-09-04 20:49:36.574974+0000 UTC [INFO] pydataquery: Received API response in 3.505439 seconds with response code 200
# 2025-09-04 20:49:36.587995+0000 UTC [INFO] pydataquery: Sending 16/234 API request
# 2025-09-04 20:49:40.590190+0000 UTC [INFO] pydataquery: Received API response in 3.808893 seconds with response code 200
# 2025-09-04 20:49:40.733257+0000 UTC [INFO] pydataquery: Sending 17/234 API request
# 2025-09-04 20:49:42.474875+0000 UTC [INFO] pydataquery: Received API response in 1.547237 seconds with response code 200
# 2025-09-04 20:49:42.478899+0000 UTC [INFO] pydataquery: Sending 18/234 API request
# 2025-09-04 20:49:45.118650+0000 UTC [INFO] pydataquery: Received API response in 2.519537 seconds with response code 200
# 2025-09-04 20:49:45.121853+0000 UTC [INFO] pydataquery: Sending 19/234 API request
# 2025-09-04 20:49:50.121733+0000 UTC [INFO] pydataquery: Received API response in 4.796101 seconds with response code 200
# 2025-09-04 20:49:50.126745+0000 UTC [INFO] pydataquery: Sending 20/234 API request
# 2025-09-04 20:49:54.579603+0000 UTC [INFO] pydataquery: Received API response in 4.246849 seconds with response code 200
# 2025-09-04 20:49:54.586126+0000 UTC [INFO] pydataquery: Sending 21/234 API request
# 2025-09-04 20:49:58.874087+0000 UTC [INFO] pydataquery: Received API response in 4.151379 seconds with response code 200
# 2025-09-04 20:49:58.877085+0000 UTC [INFO] pydataquery: Sending 22/234 API request
# 2025-09-04 20:50:03.301814+0000 UTC [INFO] pydataquery: Received API response in 4.087802 seconds with response code 200
# 2025-09-04 20:50:03.309917+0000 UTC [INFO] pydataquery: Sending 23/234 API request
# 2025-09-04 20:50:07.633106+0000 UTC [INFO] pydataquery: Received API response in 3.983861 seconds with response code 200
# 2025-09-04 20:50:07.637242+0000 UTC [INFO] pydataquery: Sending 24/234 API request
# 2025-09-04 20:50:11.250927+0000 UTC [INFO] pydataquery: Received API response in 3.378398 seconds with response code 200
# 2025-09-04 20:50:11.252926+0000 UTC [INFO] pydataquery: Sending 25/234 API request
# 2025-09-04 20:50:16.385349+0000 UTC [INFO] pydataquery: Received API response in 4.834399 seconds with response code 200
# 2025-09-04 20:50:16.391344+0000 UTC [INFO] pydataquery: Sending 26/234 API request
# 2025-09-04 20:50:18.434284+0000 UTC [INFO] pydataquery: Received API response in 1.692611 seconds with response code 200
# 2025-09-04 20:50:18.437665+0000 UTC [INFO] pydataquery: Sending 27/234 API request
# 2025-09-04 20:50:23.092020+0000 UTC [INFO] pydataquery: Received API response in 4.418353 seconds with response code 200
# 2025-09-04 20:50:23.094020+0000 UTC [INFO] pydataquery: Sending 28/234 API request
# 2025-09-04 20:50:27.923041+0000 UTC [INFO] pydataquery: Received API response in 4.587631 seconds with response code 200
# 2025-09-04 20:50:27.938382+0000 UTC [INFO] pydataquery: Sending 29/234 API request
# 2025-09-04 20:50:30.929623+0000 UTC [INFO] pydataquery: Received API response in 2.784461 seconds with response code 200
# 2025-09-04 20:50:30.936261+0000 UTC [INFO] pydataquery: Sending 30/234 API request
# 2025-09-04 20:50:33.316340+0000 UTC [INFO] pydataquery: Received API response in 2.238035 seconds with response code 200
# 2025-09-04 20:50:33.319340+0000 UTC [INFO] pydataquery: Sending 31/234 API request
# 2025-09-04 20:50:36.573148+0000 UTC [INFO] pydataquery: Received API response in 3.015741 seconds with response code 200
# 2025-09-04 20:50:36.576655+0000 UTC [INFO] pydataquery: Sending 32/234 API request
# 2025-09-04 20:50:39.327110+0000 UTC [INFO] pydataquery: Received API response in 2.525773 seconds with response code 200
# 2025-09-04 20:50:39.331109+0000 UTC [INFO] pydataquery: Sending 33/234 API request
# 2025-09-04 20:50:43.740805+0000 UTC [INFO] pydataquery: Received API response in 4.27475 seconds with response code 200
# 2025-09-04 20:50:43.747346+0000 UTC [INFO] pydataquery: Sending 34/234 API request
# 2025-09-04 20:50:45.743906+0000 UTC [INFO] pydataquery: Received API response in 1.824341 seconds with response code 200
# 2025-09-04 20:50:45.748888+0000 UTC [INFO] pydataquery: Sending 35/234 API request
# 2025-09-04 20:50:48.015445+0000 UTC [INFO] pydataquery: Received API response in 1.977797 seconds with response code 200
# 2025-09-04 20:50:48.020953+0000 UTC [INFO] pydataquery: Sending 36/234 API request
# 2025-09-04 20:50:50.378066+0000 UTC [INFO] pydataquery: Received API response in 2.179024 seconds with response code 200
# 2025-09-04 20:50:50.380066+0000 UTC [INFO] pydataquery: Sending 37/234 API request
# 2025-09-04 20:50:55.156423+0000 UTC [INFO] pydataquery: Received API response in 4.426803 seconds with response code 200
# 2025-09-04 20:50:55.159423+0000 UTC [INFO] pydataquery: Sending 38/234 API request
# 2025-09-04 20:50:58.154818+0000 UTC [INFO] pydataquery: Received API response in 2.634827 seconds with response code 200
# 2025-09-04 20:50:58.157822+0000 UTC [INFO] pydataquery: Sending 39/234 API request
# 2025-09-04 20:51:00.593457+0000 UTC [INFO] pydataquery: Received API response in 2.202389 seconds with response code 200
# 2025-09-04 20:51:00.596390+0000 UTC [INFO] pydataquery: Sending 40/234 API request
# 2025-09-04 20:51:05.824765+0000 UTC [INFO] pydataquery: Received API response in 4.931131 seconds with response code 200
# 2025-09-04 20:51:05.835863+0000 UTC [INFO] pydataquery: Sending 41/234 API request
# 2025-09-04 20:51:08.864593+0000 UTC [INFO] pydataquery: Received API response in 2.67906 seconds with response code 200
# 2025-09-04 20:51:08.869464+0000 UTC [INFO] pydataquery: Sending 42/234 API request
# 2025-09-04 20:51:11.245191+0000 UTC [INFO] pydataquery: Received API response in 2.130909 seconds with response code 200
# 2025-09-04 20:51:11.249243+0000 UTC [INFO] pydataquery: Sending 43/234 API request
# 2025-09-04 20:51:15.021794+0000 UTC [INFO] pydataquery: Received API response in 3.371343 seconds with response code 200
# 2025-09-04 20:51:15.026448+0000 UTC [INFO] pydataquery: Sending 44/234 API request
# 2025-09-04 20:51:18.042295+0000 UTC [INFO] pydataquery: Received API response in 2.678355 seconds with response code 200
# 2025-09-04 20:51:18.049294+0000 UTC [INFO] pydataquery: Sending 45/234 API request
# 2025-09-04 20:51:20.158552+0000 UTC [INFO] pydataquery: Received API response in 1.839334 seconds with response code 200
# 2025-09-04 20:51:20.161061+0000 UTC [INFO] pydataquery: Sending 46/234 API request
# 2025-09-04 20:51:23.354858+0000 UTC [INFO] pydataquery: Received API response in 2.865259 seconds with response code 200
# 2025-09-04 20:51:23.359854+0000 UTC [INFO] pydataquery: Sending 47/234 API request
# 2025-09-04 20:51:27.886298+0000 UTC [INFO] pydataquery: Received API response in 4.127561 seconds with response code 200
# 2025-09-04 20:51:27.891295+0000 UTC [INFO] pydataquery: Sending 48/234 API request
# 2025-09-04 20:51:29.483514+0000 UTC [INFO] pydataquery: Received API response in 1.346117 seconds with response code 200
# 2025-09-04 20:51:29.485519+0000 UTC [INFO] pydataquery: Sending 49/234 API request
# 2025-09-04 20:51:31.544153+0000 UTC [INFO] pydataquery: Received API response in 1.828795 seconds with response code 200
# 2025-09-04 20:51:31.546655+0000 UTC [INFO] pydataquery: Sending 50/234 API request
# 2025-09-04 20:51:34.290731+0000 UTC [INFO] pydataquery: Received API response in 2.535272 seconds with response code 200
# 2025-09-04 20:51:34.293727+0000 UTC [INFO] pydataquery: Sending 51/234 API request
# 2025-09-04 20:51:35.699702+0000 UTC [INFO] pydataquery: Received API response in 1.303977 seconds with response code 200
# 2025-09-04 20:51:35.701702+0000 UTC [INFO] pydataquery: Sending 52/234 API request
# 2025-09-04 20:51:40.908351+0000 UTC [INFO] pydataquery: Received API response in 5.040657 seconds with response code 200
# 2025-09-04 20:51:40.918363+0000 UTC [INFO] pydataquery: Sending 53/234 API request
# 2025-09-04 20:51:44.881053+0000 UTC [INFO] pydataquery: Received API response in 3.798063 seconds with response code 200
# 2025-09-04 20:51:44.883044+0000 UTC [INFO] pydataquery: Sending 54/234 API request
# 2025-09-04 20:51:47.055466+0000 UTC [INFO] pydataquery: Received API response in 2.057972 seconds with response code 200
# 2025-09-04 20:51:47.056470+0000 UTC [INFO] pydataquery: Sending 55/234 API request
# 2025-09-04 20:51:51.529290+0000 UTC [INFO] pydataquery: Received API response in 4.308116 seconds with response code 200
# 2025-09-04 20:51:51.532280+0000 UTC [INFO] pydataquery: Sending 56/234 API request
# 2025-09-04 20:51:55.074903+0000 UTC [INFO] pydataquery: Received API response in 3.247619 seconds with response code 200
# 2025-09-04 20:51:55.076853+0000 UTC [INFO] pydataquery: Sending 57/234 API request
# 2025-09-04 20:51:57.424477+0000 UTC [INFO] pydataquery: Received API response in 2.168333 seconds with response code 200
# 2025-09-04 20:51:57.426476+0000 UTC [INFO] pydataquery: Sending 58/234 API request
# 2025-09-04 20:51:59.940030+0000 UTC [INFO] pydataquery: Received API response in 2.159495 seconds with response code 200
# 2025-09-04 20:51:59.947047+0000 UTC [INFO] pydataquery: Sending 59/234 API request
# 2025-09-04 20:52:02.264501+0000 UTC [INFO] pydataquery: Received API response in 2.02327 seconds with response code 200
# 2025-09-04 20:52:02.268502+0000 UTC [INFO] pydataquery: Sending 60/234 API request
# 2025-09-04 20:52:06.737330+0000 UTC [INFO] pydataquery: Received API response in 4.231114 seconds with response code 200
# 2025-09-04 20:52:06.739331+0000 UTC [INFO] pydataquery: Sending 61/234 API request
# 2025-09-04 20:52:10.799769+0000 UTC [INFO] pydataquery: Received API response in 3.769136 seconds with response code 200
# 2025-09-04 20:52:10.801800+0000 UTC [INFO] pydataquery: Sending 62/234 API request
# 2025-09-04 20:52:13.360053+0000 UTC [INFO] pydataquery: Received API response in 2.267631 seconds with response code 200
# 2025-09-04 20:52:13.366738+0000 UTC [INFO] pydataquery: Sending 63/234 API request
# 2025-09-04 20:52:17.337650+0000 UTC [INFO] pydataquery: Received API response in 3.814734 seconds with response code 200
# 2025-09-04 20:52:17.342546+0000 UTC [INFO] pydataquery: Sending 64/234 API request
# 2025-09-04 20:52:19.588276+0000 UTC [INFO] pydataquery: Received API response in 2.041356 seconds with response code 200
# 2025-09-04 20:52:19.602274+0000 UTC [INFO] pydataquery: Sending 65/234 API request
# 2025-09-04 20:52:24.091619+0000 UTC [INFO] pydataquery: Received API response in 4.297916 seconds with response code 200
# 2025-09-04 20:52:24.096630+0000 UTC [INFO] pydataquery: Sending 66/234 API request
# 2025-09-04 20:52:25.519206+0000 UTC [INFO] pydataquery: Received API response in 1.275099 seconds with response code 200
# 2025-09-04 20:52:25.521206+0000 UTC [INFO] pydataquery: Sending 67/234 API request
# 2025-09-04 20:52:28.488707+0000 UTC [INFO] pydataquery: Received API response in 2.769712 seconds with response code 200
# 2025-09-04 20:52:28.492215+0000 UTC [INFO] pydataquery: Sending 68/234 API request
# 2025-09-04 20:52:31.943842+0000 UTC [INFO] pydataquery: Received API response in 3.282371 seconds with response code 200
# 2025-09-04 20:52:31.947850+0000 UTC [INFO] pydataquery: Sending 69/234 API request
# 2025-09-04 20:52:33.836878+0000 UTC [INFO] pydataquery: Received API response in 1.770911 seconds with response code 200
# 2025-09-04 20:52:33.838927+0000 UTC [INFO] pydataquery: Sending 70/234 API request
# 2025-09-04 20:52:36.337780+0000 UTC [INFO] pydataquery: Received API response in 2.306172 seconds with response code 200
# 2025-09-04 20:52:36.340286+0000 UTC [INFO] pydataquery: Sending 71/234 API request
# 2025-09-04 20:52:39.448960+0000 UTC [INFO] pydataquery: Received API response in 2.897061 seconds with response code 200
# 2025-09-04 20:52:39.451960+0000 UTC [INFO] pydataquery: Sending 72/234 API request
# 2025-09-04 20:52:42.117202+0000 UTC [INFO] pydataquery: Received API response in 2.465912 seconds with response code 200
# 2025-09-04 20:52:42.122102+0000 UTC [INFO] pydataquery: Sending 73/234 API request
# 2025-09-04 20:52:47.717627+0000 UTC [INFO] pydataquery: Received API response in 5.263655 seconds with response code 200
# 2025-09-04 20:52:47.721628+0000 UTC [INFO] pydataquery: Sending 74/234 API request
# 2025-09-04 20:52:53.369218+0000 UTC [INFO] pydataquery: Received API response in 5.380756 seconds with response code 200
# 2025-09-04 20:52:53.373260+0000 UTC [INFO] pydataquery: Sending 75/234 API request
# 2025-09-04 20:52:55.296148+0000 UTC [INFO] pydataquery: Received API response in 1.720012 seconds with response code 200
# 2025-09-04 20:52:55.298149+0000 UTC [INFO] pydataquery: Sending 76/234 API request
# 2025-09-04 20:52:58.212035+0000 UTC [INFO] pydataquery: Received API response in 2.51646 seconds with response code 200
# 2025-09-04 20:52:58.221941+0000 UTC [INFO] pydataquery: Sending 77/234 API request
# 2025-09-04 20:53:00.745223+0000 UTC [INFO] pydataquery: Received API response in 2.170732 seconds with response code 200
# 2025-09-04 20:53:00.750223+0000 UTC [INFO] pydataquery: Sending 78/234 API request
# 2025-09-04 20:53:02.872872+0000 UTC [INFO] pydataquery: Received API response in 1.888256 seconds with response code 200
# 2025-09-04 20:53:02.875874+0000 UTC [INFO] pydataquery: Sending 79/234 API request
# 2025-09-04 20:53:07.134700+0000 UTC [INFO] pydataquery: Received API response in 3.966973 seconds with response code 200
# 2025-09-04 20:53:07.137706+0000 UTC [INFO] pydataquery: Sending 80/234 API request
# 2025-09-04 20:53:11.950387+0000 UTC [INFO] pydataquery: Received API response in 4.528546 seconds with response code 200
# 2025-09-04 20:53:11.953380+0000 UTC [INFO] pydataquery: Sending 81/234 API request
# 2025-09-04 20:53:13.738874+0000 UTC [INFO] pydataquery: Received API response in 1.605695 seconds with response code 200
# 2025-09-04 20:53:13.741383+0000 UTC [INFO] pydataquery: Sending 82/234 API request
# 2025-09-04 20:53:16.363421+0000 UTC [INFO] pydataquery: Received API response in 2.329018 seconds with response code 200
# 2025-09-04 20:53:16.372133+0000 UTC [INFO] pydataquery: Sending 83/234 API request
# 2025-09-04 20:53:21.596495+0000 UTC [INFO] pydataquery: Received API response in 4.924643 seconds with response code 200
# 2025-09-04 20:53:21.603513+0000 UTC [INFO] pydataquery: Sending 84/234 API request
# 2025-09-04 20:53:25.778591+0000 UTC [INFO] pydataquery: Received API response in 4.070887 seconds with response code 200
# 2025-09-04 20:53:25.780584+0000 UTC [INFO] pydataquery: Sending 85/234 API request
# 2025-09-04 20:53:30.493793+0000 UTC [INFO] pydataquery: Received API response in 4.540525 seconds with response code 200
# 2025-09-04 20:53:30.497794+0000 UTC [INFO] pydataquery: Sending 86/234 API request
# 2025-09-04 20:53:32.996850+0000 UTC [INFO] pydataquery: Received API response in 2.301743 seconds with response code 200
# 2025-09-04 20:53:33.001737+0000 UTC [INFO] pydataquery: Sending 87/234 API request
# 2025-09-04 20:53:34.638928+0000 UTC [INFO] pydataquery: Received API response in 1.521082 seconds with response code 200
# 2025-09-04 20:53:34.643498+0000 UTC [INFO] pydataquery: Sending 88/234 API request
# 2025-09-04 20:53:36.100445+0000 UTC [INFO] pydataquery: Received API response in 1.286625 seconds with response code 200
# 2025-09-04 20:53:36.113968+0000 UTC [INFO] pydataquery: Sending 89/234 API request
# 2025-09-04 20:53:39.107469+0000 UTC [INFO] pydataquery: Received API response in 2.796044 seconds with response code 200
# 2025-09-04 20:53:39.113469+0000 UTC [INFO] pydataquery: Sending 90/234 API request
# 2025-09-04 20:53:40.484707+0000 UTC [INFO] pydataquery: Received API response in 1.26827 seconds with response code 200
# 2025-09-04 20:53:40.489708+0000 UTC [INFO] pydataquery: Sending 91/234 API request
# 2025-09-04 20:53:45.004668+0000 UTC [INFO] pydataquery: Received API response in 4.284815 seconds with response code 200
# 2025-09-04 20:53:45.010686+0000 UTC [INFO] pydataquery: Sending 92/234 API request
# 2025-09-04 20:53:47.778815+0000 UTC [INFO] pydataquery: Received API response in 2.436314 seconds with response code 200
# 2025-09-04 20:53:47.781807+0000 UTC [INFO] pydataquery: Sending 93/234 API request
# 2025-09-04 20:53:52.328173+0000 UTC [INFO] pydataquery: Received API response in 4.345703 seconds with response code 200
# 2025-09-04 20:53:52.331173+0000 UTC [INFO] pydataquery: Sending 94/234 API request
# 2025-09-04 20:53:57.358754+0000 UTC [INFO] pydataquery: Received API response in 4.625152 seconds with response code 200
# 2025-09-04 20:53:57.367275+0000 UTC [INFO] pydataquery: Sending 95/234 API request
# 2025-09-04 20:53:59.564996+0000 UTC [INFO] pydataquery: Received API response in 1.864202 seconds with response code 200
# 2025-09-04 20:53:59.567988+0000 UTC [INFO] pydataquery: Sending 96/234 API request
# 2025-09-04 20:54:03.690047+0000 UTC [INFO] pydataquery: Received API response in 3.851001 seconds with response code 200
# 2025-09-04 20:54:03.693040+0000 UTC [INFO] pydataquery: Sending 97/234 API request
# 2025-09-04 20:54:06.953916+0000 UTC [INFO] pydataquery: Received API response in 2.861493 seconds with response code 200
# 2025-09-04 20:54:06.957916+0000 UTC [INFO] pydataquery: Sending 98/234 API request
# 2025-09-04 20:54:11.045499+0000 UTC [INFO] pydataquery: Received API response in 3.73156 seconds with response code 200
# 2025-09-04 20:54:11.052027+0000 UTC [INFO] pydataquery: Sending 99/234 API request
# 2025-09-04 20:54:15.732388+0000 UTC [INFO] pydataquery: Received API response in 4.445015 seconds with response code 200
# 2025-09-04 20:54:15.736388+0000 UTC [INFO] pydataquery: Sending 100/234 API request
# 2025-09-04 20:54:20.043239+0000 UTC [INFO] pydataquery: Received API response in 4.014025 seconds with response code 200
# 2025-09-04 20:54:20.055078+0000 UTC [INFO] pydataquery: Sending 101/234 API request
# 2025-09-04 20:54:21.865967+0000 UTC [INFO] pydataquery: Received API response in 1.517412 seconds with response code 200
# 2025-09-04 20:54:21.868947+0000 UTC [INFO] pydataquery: Sending 102/234 API request
# 2025-09-04 20:54:24.410218+0000 UTC [INFO] pydataquery: Received API response in 2.364077 seconds with response code 200
# 2025-09-04 20:54:24.412842+0000 UTC [INFO] pydataquery: Sending 103/234 API request
# 2025-09-04 20:54:26.352744+0000 UTC [INFO] pydataquery: Received API response in 1.65682 seconds with response code 200
# 2025-09-04 20:54:26.355744+0000 UTC [INFO] pydataquery: Sending 104/234 API request
# 2025-09-04 20:54:28.339922+0000 UTC [INFO] pydataquery: Received API response in 1.683108 seconds with response code 200
# 2025-09-04 20:54:28.344944+0000 UTC [INFO] pydataquery: Sending 105/234 API request
# 2025-09-04 20:54:30.487171+0000 UTC [INFO] pydataquery: Received API response in 2.039877 seconds with response code 200
# 2025-09-04 20:54:30.490166+0000 UTC [INFO] pydataquery: Sending 106/234 API request
# 2025-09-04 20:54:32.253655+0000 UTC [INFO] pydataquery: Received API response in 1.573226 seconds with response code 200
# 2025-09-04 20:54:32.258665+0000 UTC [INFO] pydataquery: Sending 107/234 API request
# 2025-09-04 20:54:34.412637+0000 UTC [INFO] pydataquery: Received API response in 2.019641 seconds with response code 200
# 2025-09-04 20:54:34.415641+0000 UTC [INFO] pydataquery: Sending 108/234 API request
# 2025-09-04 20:54:35.456515+0000 UTC [INFO] pydataquery: Received API response in 1.00469 seconds with response code 200
# 2025-09-04 20:54:35.462925+0000 UTC [INFO] pydataquery: Sending 109/234 API request
# 2025-09-04 20:54:37.218960+0000 UTC [INFO] pydataquery: Received API response in 1.566337 seconds with response code 200
# 2025-09-04 20:54:37.222960+0000 UTC [INFO] pydataquery: Sending 110/234 API request
# 2025-09-04 20:54:38.944357+0000 UTC [INFO] pydataquery: Received API response in 1.552936 seconds with response code 200
# 2025-09-04 20:54:38.947415+0000 UTC [INFO] pydataquery: Sending 111/234 API request
# 2025-09-04 20:54:40.533531+0000 UTC [INFO] pydataquery: Received API response in 1.487234 seconds with response code 200
# 2025-09-04 20:54:40.535866+0000 UTC [INFO] pydataquery: Sending 112/234 API request
# 2025-09-04 20:54:43.280599+0000 UTC [INFO] pydataquery: Received API response in 2.522609 seconds with response code 200
# 2025-09-04 20:54:43.288115+0000 UTC [INFO] pydataquery: Sending 113/234 API request
# 2025-09-04 20:54:45.771547+0000 UTC [INFO] pydataquery: Received API response in 2.28154 seconds with response code 200
# 2025-09-04 20:54:45.778658+0000 UTC [INFO] pydataquery: Sending 114/234 API request
# 2025-09-04 20:54:49.885786+0000 UTC [INFO] pydataquery: Received API response in 3.996069 seconds with response code 200
# 2025-09-04 20:54:49.887786+0000 UTC [INFO] pydataquery: Sending 115/234 API request
# 2025-09-04 20:54:54.375541+0000 UTC [INFO] pydataquery: Received API response in 4.153773 seconds with response code 200
# 2025-09-04 20:54:54.380557+0000 UTC [INFO] pydataquery: Sending 116/234 API request
# 2025-09-04 20:55:00.237968+0000 UTC [INFO] pydataquery: Received API response in 5.460105 seconds with response code 200
# 2025-09-04 20:55:00.241893+0000 UTC [INFO] pydataquery: Sending 117/234 API request
# 2025-09-04 20:55:02.690382+0000 UTC [INFO] pydataquery: Received API response in 2.206847 seconds with response code 200
# 2025-09-04 20:55:02.692384+0000 UTC [INFO] pydataquery: Sending 118/234 API request
# 2025-09-04 20:55:08.157423+0000 UTC [INFO] pydataquery: Received API response in 5.128649 seconds with response code 200
# 2025-09-04 20:55:08.160424+0000 UTC [INFO] pydataquery: Sending 119/234 API request
# 2025-09-04 20:55:13.578903+0000 UTC [INFO] pydataquery: Received API response in 5.150723 seconds with response code 200
# 2025-09-04 20:55:13.581904+0000 UTC [INFO] pydataquery: Sending 120/234 API request
# 2025-09-04 20:55:18.232381+0000 UTC [INFO] pydataquery: Received API response in 4.448795 seconds with response code 200
# 2025-09-04 20:55:18.236368+0000 UTC [INFO] pydataquery: Sending 121/234 API request
# 2025-09-04 20:55:21.269130+0000 UTC [INFO] pydataquery: Received API response in 2.634659 seconds with response code 200
# 2025-09-04 20:55:21.276108+0000 UTC [INFO] pydataquery: Sending 122/234 API request
# 2025-09-04 20:55:24.724308+0000 UTC [INFO] pydataquery: Received API response in 3.116062 seconds with response code 200
# 2025-09-04 20:55:24.731360+0000 UTC [INFO] pydataquery: Sending 123/234 API request
# 2025-09-04 20:55:27.376283+0000 UTC [INFO] pydataquery: Received API response in 2.377122 seconds with response code 200
# 2025-09-04 20:55:27.379287+0000 UTC [INFO] pydataquery: Sending 124/234 API request
# 2025-09-04 20:55:29.085835+0000 UTC [INFO] pydataquery: Received API response in 1.371691 seconds with response code 200
# 2025-09-04 20:55:29.093781+0000 UTC [INFO] pydataquery: Sending 125/234 API request
# 2025-09-04 20:55:33.547483+0000 UTC [INFO] pydataquery: Received API response in 4.123559 seconds with response code 200
# 2025-09-04 20:55:33.550493+0000 UTC [INFO] pydataquery: Sending 126/234 API request
# 2025-09-04 20:55:34.706634+0000 UTC [INFO] pydataquery: Received API response in 1.152851 seconds with response code 200
# 2025-09-04 20:55:34.708637+0000 UTC [INFO] pydataquery: Sending 127/234 API request
# 2025-09-04 20:55:36.965035+0000 UTC [INFO] pydataquery: Received API response in 2.062411 seconds with response code 200
# 2025-09-04 20:55:36.970037+0000 UTC [INFO] pydataquery: Sending 128/234 API request
# 2025-09-04 20:55:39.140667+0000 UTC [INFO] pydataquery: Received API response in 2.029627 seconds with response code 200
# 2025-09-04 20:55:39.147938+0000 UTC [INFO] pydataquery: Sending 129/234 API request
# 2025-09-04 20:55:41.552984+0000 UTC [INFO] pydataquery: Received API response in 2.285576 seconds with response code 200
# 2025-09-04 20:55:41.555131+0000 UTC [INFO] pydataquery: Sending 130/234 API request
# 2025-09-04 20:55:43.584384+0000 UTC [INFO] pydataquery: Received API response in 1.836976 seconds with response code 200
# 2025-09-04 20:55:43.586891+0000 UTC [INFO] pydataquery: Sending 131/234 API request
# 2025-09-04 20:55:45.042895+0000 UTC [INFO] pydataquery: Received API response in 1.322314 seconds with response code 200
# 2025-09-04 20:55:45.045408+0000 UTC [INFO] pydataquery: Sending 132/234 API request
# 2025-09-04 20:55:49.181931+0000 UTC [INFO] pydataquery: Received API response in 4.009355 seconds with response code 200
# 2025-09-04 20:55:49.183939+0000 UTC [INFO] pydataquery: Sending 133/234 API request
# 2025-09-04 20:55:51.430096+0000 UTC [INFO] pydataquery: Received API response in 2.068999 seconds with response code 200
# 2025-09-04 20:55:51.436111+0000 UTC [INFO] pydataquery: Sending 134/234 API request
# 2025-09-04 20:55:53.702189+0000 UTC [INFO] pydataquery: Received API response in 2.067847 seconds with response code 200
# 2025-09-04 20:55:53.705183+0000 UTC [INFO] pydataquery: Sending 135/234 API request
# 2025-09-04 20:55:57.840307+0000 UTC [INFO] pydataquery: Received API response in 4.03124 seconds with response code 200
# 2025-09-04 20:55:57.842307+0000 UTC [INFO] pydataquery: Sending 136/234 API request
# 2025-09-04 20:56:01.448318+0000 UTC [INFO] pydataquery: Received API response in 3.309527 seconds with response code 200
# 2025-09-04 20:56:01.455317+0000 UTC [INFO] pydataquery: Sending 137/234 API request
# 2025-09-04 20:56:03.550758+0000 UTC [INFO] pydataquery: Received API response in 1.798551 seconds with response code 200
# 2025-09-04 20:56:03.553260+0000 UTC [INFO] pydataquery: Sending 138/234 API request
# 2025-09-04 20:56:05.363662+0000 UTC [INFO] pydataquery: Received API response in 1.634678 seconds with response code 200
# 2025-09-04 20:56:05.370774+0000 UTC [INFO] pydataquery: Sending 139/234 API request
# 2025-09-04 20:56:07.530064+0000 UTC [INFO] pydataquery: Received API response in 1.866082 seconds with response code 200
# 2025-09-04 20:56:07.532063+0000 UTC [INFO] pydataquery: Sending 140/234 API request
# 2025-09-04 20:56:09.093518+0000 UTC [INFO] pydataquery: Received API response in 1.262722 seconds with response code 200
# 2025-09-04 20:56:09.095518+0000 UTC [INFO] pydataquery: Sending 141/234 API request
# 2025-09-04 20:56:10.757088+0000 UTC [INFO] pydataquery: Received API response in 1.481179 seconds with response code 200
# 2025-09-04 20:56:10.759082+0000 UTC [INFO] pydataquery: Sending 142/234 API request
# 2025-09-04 20:56:13.020848+0000 UTC [INFO] pydataquery: Received API response in 1.968373 seconds with response code 200
# 2025-09-04 20:56:13.024353+0000 UTC [INFO] pydataquery: Sending 143/234 API request
# 2025-09-04 20:56:16.536454+0000 UTC [INFO] pydataquery: Received API response in 3.275285 seconds with response code 200
# 2025-09-04 20:56:16.543465+0000 UTC [INFO] pydataquery: Sending 144/234 API request
# 2025-09-04 20:56:18.348883+0000 UTC [INFO] pydataquery: Received API response in 1.622625 seconds with response code 200
# 2025-09-04 20:56:18.352887+0000 UTC [INFO] pydataquery: Sending 145/234 API request
# 2025-09-04 20:56:21.057218+0000 UTC [INFO] pydataquery: Received API response in 2.433291 seconds with response code 200
# 2025-09-04 20:56:21.061222+0000 UTC [INFO] pydataquery: Sending 146/234 API request
# 2025-09-04 20:56:24.703738+0000 UTC [INFO] pydataquery: Received API response in 3.377026 seconds with response code 200
# 2025-09-04 20:56:24.706738+0000 UTC [INFO] pydataquery: Sending 147/234 API request
# 2025-09-04 20:56:25.871644+0000 UTC [INFO] pydataquery: Received API response in 1.160582 seconds with response code 200
# 2025-09-04 20:56:25.874649+0000 UTC [INFO] pydataquery: Sending 148/234 API request
# 2025-09-04 20:56:28.265719+0000 UTC [INFO] pydataquery: Received API response in 2.123054 seconds with response code 200
# 2025-09-04 20:56:28.272802+0000 UTC [INFO] pydataquery: Sending 149/234 API request
# 2025-09-04 20:56:30.426681+0000 UTC [INFO] pydataquery: Received API response in 1.88829 seconds with response code 200
# 2025-09-04 20:56:30.712151+0000 UTC [INFO] pydataquery: Sending 150/234 API request
# 2025-09-04 20:56:32.244904+0000 UTC [INFO] pydataquery: Received API response in 1.399898 seconds with response code 200
# 2025-09-04 20:56:32.248916+0000 UTC [INFO] pydataquery: Sending 151/234 API request
# 2025-09-04 20:56:34.457910+0000 UTC [INFO] pydataquery: Received API response in 1.874879 seconds with response code 200
# 2025-09-04 20:56:34.460149+0000 UTC [INFO] pydataquery: Sending 152/234 API request
# 2025-09-04 20:56:37.837561+0000 UTC [INFO] pydataquery: Received API response in 3.109013 seconds with response code 200
# 2025-09-04 20:56:37.842567+0000 UTC [INFO] pydataquery: Sending 153/234 API request
# 2025-09-04 20:56:39.662559+0000 UTC [INFO] pydataquery: Received API response in 1.617239 seconds with response code 200
# 2025-09-04 20:56:39.666569+0000 UTC [INFO] pydataquery: Sending 154/234 API request
# 2025-09-04 20:56:42.589087+0000 UTC [INFO] pydataquery: Received API response in 2.653494 seconds with response code 200
# 2025-09-04 20:56:42.591087+0000 UTC [INFO] pydataquery: Sending 155/234 API request
# 2025-09-04 20:56:47.231657+0000 UTC [INFO] pydataquery: Received API response in 4.375888 seconds with response code 200
# 2025-09-04 20:56:47.235679+0000 UTC [INFO] pydataquery: Sending 156/234 API request
# 2025-09-04 20:56:48.772567+0000 UTC [INFO] pydataquery: Received API response in 1.336856 seconds with response code 200
# 2025-09-04 20:56:48.775146+0000 UTC [INFO] pydataquery: Sending 157/234 API request
# 2025-09-04 20:56:50.031025+0000 UTC [INFO] pydataquery: Received API response in 1.121043 seconds with response code 200
# 2025-09-04 20:56:50.034546+0000 UTC [INFO] pydataquery: Sending 158/234 API request
# 2025-09-04 20:56:54.413754+0000 UTC [INFO] pydataquery: Received API response in 4.111167 seconds with response code 200
# 2025-09-04 20:56:54.417262+0000 UTC [INFO] pydataquery: Sending 159/234 API request
# 2025-09-04 20:56:58.480065+0000 UTC [INFO] pydataquery: Received API response in 3.863428 seconds with response code 200
# 2025-09-04 20:56:58.485070+0000 UTC [INFO] pydataquery: Sending 160/234 API request
# 2025-09-04 20:57:03.200782+0000 UTC [INFO] pydataquery: Received API response in 4.378446 seconds with response code 200
# 2025-09-04 20:57:03.204790+0000 UTC [INFO] pydataquery: Sending 161/234 API request
# 2025-09-04 20:57:07.705248+0000 UTC [INFO] pydataquery: Received API response in 4.329782 seconds with response code 200
# 2025-09-04 20:57:07.713932+0000 UTC [INFO] pydataquery: Sending 162/234 API request
# 2025-09-04 20:57:09.354969+0000 UTC [INFO] pydataquery: Received API response in 1.500627 seconds with response code 200
# 2025-09-04 20:57:09.359954+0000 UTC [INFO] pydataquery: Sending 163/234 API request
# 2025-09-04 20:57:10.441709+0000 UTC [INFO] pydataquery: Received API response in 1.011037 seconds with response code 200
# 2025-09-04 20:57:10.447718+0000 UTC [INFO] pydataquery: Sending 164/234 API request
# 2025-09-04 20:57:11.923471+0000 UTC [INFO] pydataquery: Received API response in 1.289749 seconds with response code 200
# 2025-09-04 20:57:11.926420+0000 UTC [INFO] pydataquery: Sending 165/234 API request
# 2025-09-04 20:57:13.272816+0000 UTC [INFO] pydataquery: Received API response in 1.240898 seconds with response code 200
# 2025-09-04 20:57:13.277719+0000 UTC [INFO] pydataquery: Sending 166/234 API request
# 2025-09-04 20:57:17.492579+0000 UTC [INFO] pydataquery: Received API response in 4.035388 seconds with response code 200
# 2025-09-04 20:57:17.499578+0000 UTC [INFO] pydataquery: Sending 167/234 API request
# 2025-09-04 20:57:19.464869+0000 UTC [INFO] pydataquery: Received API response in 1.79268 seconds with response code 200
# 2025-09-04 20:57:19.467875+0000 UTC [INFO] pydataquery: Sending 168/234 API request
# 2025-09-04 20:57:20.912085+0000 UTC [INFO] pydataquery: Received API response in 1.340712 seconds with response code 200
# 2025-09-04 20:57:20.918057+0000 UTC [INFO] pydataquery: Sending 169/234 API request
# 2025-09-04 20:57:24.144822+0000 UTC [INFO] pydataquery: Received API response in 3.064165 seconds with response code 200
# 2025-09-04 20:57:24.151090+0000 UTC [INFO] pydataquery: Sending 170/234 API request
# 2025-09-04 20:57:25.793707+0000 UTC [INFO] pydataquery: Received API response in 1.399514 seconds with response code 200
# 2025-09-04 20:57:25.796711+0000 UTC [INFO] pydataquery: Sending 171/234 API request
# 2025-09-04 20:57:27.205500+0000 UTC [INFO] pydataquery: Received API response in 1.231714 seconds with response code 200
# 2025-09-04 20:57:27.207500+0000 UTC [INFO] pydataquery: Sending 172/234 API request
# 2025-09-04 20:57:28.787973+0000 UTC [INFO] pydataquery: Received API response in 1.281367 seconds with response code 200
# 2025-09-04 20:57:28.793977+0000 UTC [INFO] pydataquery: Sending 173/234 API request
# 2025-09-04 20:57:32.690801+0000 UTC [INFO] pydataquery: Received API response in 3.658698 seconds with response code 200
# 2025-09-04 20:57:32.699815+0000 UTC [INFO] pydataquery: Sending 174/234 API request
# 2025-09-04 20:57:36.364801+0000 UTC [INFO] pydataquery: Received API response in 3.484804 seconds with response code 200
# 2025-09-04 20:57:36.367218+0000 UTC [INFO] pydataquery: Sending 175/234 API request
# 2025-09-04 20:57:40.801548+0000 UTC [INFO] pydataquery: Received API response in 4.136079 seconds with response code 200
# 2025-09-04 20:57:40.803852+0000 UTC [INFO] pydataquery: Sending 176/234 API request
# 2025-09-04 20:57:41.881317+0000 UTC [INFO] pydataquery: Received API response in 1.016775 seconds with response code 200
# 2025-09-04 20:57:41.886315+0000 UTC [INFO] pydataquery: Sending 177/234 API request
# 2025-09-04 20:57:42.808634+0000 UTC [INFO] pydataquery: Received API response in 0.917981 seconds with response code 200
# 2025-09-04 20:57:42.811633+0000 UTC [INFO] pydataquery: Sending 178/234 API request
# 2025-09-04 20:57:44.364778+0000 UTC [INFO] pydataquery: Received API response in 1.258067 seconds with response code 200
# 2025-09-04 20:57:44.371378+0000 UTC [INFO] pydataquery: Sending 179/234 API request
# 2025-09-04 20:57:46.398068+0000 UTC [INFO] pydataquery: Received API response in 1.72774 seconds with response code 200
# 2025-09-04 20:57:46.403126+0000 UTC [INFO] pydataquery: Sending 180/234 API request
# 2025-09-04 20:57:48.006527+0000 UTC [INFO] pydataquery: Received API response in 1.468951 seconds with response code 200
# 2025-09-04 20:57:48.011529+0000 UTC [INFO] pydataquery: Sending 181/234 API request
# 2025-09-04 20:57:50.248207+0000 UTC [INFO] pydataquery: Received API response in 1.901277 seconds with response code 200
# 2025-09-04 20:57:50.251206+0000 UTC [INFO] pydataquery: Sending 182/234 API request
# 2025-09-04 20:57:51.958744+0000 UTC [INFO] pydataquery: Received API response in 1.374715 seconds with response code 200
# 2025-09-04 20:57:51.965411+0000 UTC [INFO] pydataquery: Sending 183/234 API request
# 2025-09-04 20:57:54.273393+0000 UTC [INFO] pydataquery: Received API response in 2.107558 seconds with response code 200
# 2025-09-04 20:57:54.276829+0000 UTC [INFO] pydataquery: Sending 184/234 API request
# 2025-09-04 20:57:55.547201+0000 UTC [INFO] pydataquery: Received API response in 1.134788 seconds with response code 200
# 2025-09-04 20:57:55.553918+0000 UTC [INFO] pydataquery: Sending 185/234 API request
# 2025-09-04 20:57:57.245231+0000 UTC [INFO] pydataquery: Received API response in 1.359454 seconds with response code 200
# 2025-09-04 20:57:57.252239+0000 UTC [INFO] pydataquery: Sending 186/234 API request
# 2025-09-04 20:57:59.296039+0000 UTC [INFO] pydataquery: Received API response in 1.841534 seconds with response code 200
# 2025-09-04 20:57:59.301036+0000 UTC [INFO] pydataquery: Sending 187/234 API request
# 2025-09-04 20:58:00.571780+0000 UTC [INFO] pydataquery: Received API response in 1.131395 seconds with response code 200
# 2025-09-04 20:58:00.574781+0000 UTC [INFO] pydataquery: Sending 188/234 API request
# 2025-09-04 20:58:03.223103+0000 UTC [INFO] pydataquery: Received API response in 2.380881 seconds with response code 200
# 2025-09-04 20:58:03.227112+0000 UTC [INFO] pydataquery: Sending 189/234 API request
# 2025-09-04 20:58:05.544614+0000 UTC [INFO] pydataquery: Received API response in 2.115459 seconds with response code 200
# 2025-09-04 20:58:05.546607+0000 UTC [INFO] pydataquery: Sending 190/234 API request
# 2025-09-04 20:58:09.743097+0000 UTC [INFO] pydataquery: Received API response in 3.865839 seconds with response code 200
# 2025-09-04 20:58:09.749275+0000 UTC [INFO] pydataquery: Sending 191/234 API request
# 2025-09-04 20:58:11.432955+0000 UTC [INFO] pydataquery: Received API response in 1.531403 seconds with response code 200
# 2025-09-04 20:58:11.439955+0000 UTC [INFO] pydataquery: Sending 192/234 API request
# 2025-09-04 20:58:13.609756+0000 UTC [INFO] pydataquery: Received API response in 2.065365 seconds with response code 200
# 2025-09-04 20:58:13.611748+0000 UTC [INFO] pydataquery: Sending 193/234 API request
# 2025-09-04 20:58:17.186153+0000 UTC [INFO] pydataquery: Received API response in 3.409928 seconds with response code 200
# 2025-09-04 20:58:17.189152+0000 UTC [INFO] pydataquery: Sending 194/234 API request
# 2025-09-04 20:58:20.428861+0000 UTC [INFO] pydataquery: Received API response in 3.104425 seconds with response code 200
# 2025-09-04 20:58:20.434280+0000 UTC [INFO] pydataquery: Sending 195/234 API request
# 2025-09-04 20:58:22.693609+0000 UTC [INFO] pydataquery: Received API response in 2.159241 seconds with response code 200
# 2025-09-04 20:58:22.695617+0000 UTC [INFO] pydataquery: Sending 196/234 API request
# 2025-09-04 20:58:24.211839+0000 UTC [INFO] pydataquery: Received API response in 1.345849 seconds with response code 200
# 2025-09-04 20:58:24.214627+0000 UTC [INFO] pydataquery: Sending 197/234 API request
# 2025-09-04 20:58:28.441677+0000 UTC [INFO] pydataquery: Received API response in 4.088477 seconds with response code 200
# 2025-09-04 20:58:28.455690+0000 UTC [INFO] pydataquery: Sending 198/234 API request
# 2025-09-04 20:58:29.870206+0000 UTC [INFO] pydataquery: Received API response in 1.306302 seconds with response code 200
# 2025-09-04 20:58:29.874212+0000 UTC [INFO] pydataquery: Sending 199/234 API request
# 2025-09-04 20:58:34.677461+0000 UTC [INFO] pydataquery: Received API response in 4.629037 seconds with response code 200
# 2025-09-04 20:58:34.680455+0000 UTC [INFO] pydataquery: Sending 200/234 API request
# 2025-09-04 20:58:39.297945+0000 UTC [INFO] pydataquery: Received API response in 4.297051 seconds with response code 200
# 2025-09-04 20:58:39.306099+0000 UTC [INFO] pydataquery: Sending 201/234 API request

# %%
df1 = pd.read_excel("DQ HY Duration Data.xlsx",index_col=0, parse_dates=True)
df1a = df1.copy()
df1a = df1a.T
df1a.index = df1a.index.str.replace("_Dur","")
df1a.columns = ["Dur_" + str(item.date()) for item in df1a.columns]
df1a.index.name="ISIN"
df1a = df1a.reset_index()

df4B = pd.merge(left=df4, right=df1a, on="ISIN", how="outer")

####################################################################

t = [f"/isin/{item}@BGN" for item in list(all_df["ISIN"])]
if update_live:
    px = blp.bdh(tickers=t, flds="PX_LAST", start_date=datetime.now()-timedelta(days=365*5))
    px.to_parquet("Test2.parquet")
px = pd.read_parquet("Test2.parquet")

new = []
for item in px.columns:
    new += [item[0].replace("/isin/","").replace("@BGN","")]
px.columns = new
px = px.T
px.columns = ["Price_" + str(item) for item in px.columns]
px.index.name= "ISIN"
px = px.reset_index()

####################################################
df5a = pd.merge(left=df4B, right=bbg1, on="ISIN", how="inner")
last_update = max(dt_list)
for dt in dt_list:
    try:
        df5a[f"Basis_{dt}"] = df5a[f"Mat_Matched_CDS_{dt}"] - df5a[f"Sprd_{dt}"]
    except:
        hello = 1

df5a = pd.merge(left=df5a, right=px, on="ISIN", how="inner")

# %%
df5 = df5a.copy()
df5 = df5[["ISIN","CUSIP","Name","Maturity","Issuer Equity_red_tier_ccy_docclause"] +\
    [col for col in df5.columns if last_update in col or "Basis_" in col]].copy()

####################################### Zscore and 1Y High/Low Calc

dfz = df5[["ISIN"] + [item for item in df5.columns if "Basis" in item]]
dfz = dfz.set_index("ISIN").T
dfz.index = [pd.to_datetime(item.split("_")[1]).date() for item in dfz.index]
dfz = dfz.sort_index()

all_z_df = None
for period in [3*22, 6*22, 12*22]:
    x = ((dfz-dfz.rolling(period, min_periods = int(0.6*period)).mean())/dfz.rolling(period,\
                  min_periods = int(0.6*period)).std()).iloc[[-1],:].copy()
    x.index = [f'ZScore_{int(period/22)}M']
    all_z_df = pd.concat([all_z_df , x])

max_1y = pd.DataFrame(dfz.iloc[-12*22:,:].max()).T
max_1y.index = [f'Basis 1Y High']
min_1y = pd.DataFrame(dfz.iloc[-12*22:,:].min()).T
min_1y.index = [f'Basis 1Y Low']

all_z_df = pd.concat([all_z_df , max_1y, min_1y])
all_z_df = all_z_df.T
all_z_df = all_z_df.reset_index()

df6 = pd.merge(left=df5.drop([col for col in df5.columns if col.\
    startswith("Basis_") and not last_update in col],axis=1),\
               right=all_z_df, on="ISIN", how="inner").drop(["CUSIP","Maturity"],axis=1).copy()

# %%
df7 = df6.drop(f"Dur_{last_update}",axis=1).copy()
df7["Family"] = df7["Issuer Equity_red_tier_ccy_docclause"].apply(lambda x: f_dict[x])
df7["CDS RED Code"] =  df7["Issuer Equity_red_tier_ccy_docclause"].apply(lambda x: x.split("_")[1])
df7.columns = df7.columns.str.replace(f"_{last_update}","").str.replace("Mat_Matched_CDS","Mat. Matched CDS")
df7["First Sort"] = df7["Name"].apply(lambda x: x.split(" ")[0])
df7["Second Sort"] = df7["Name"].apply(lambda x: x.rsplit("/")[-1])

df7 = df7.sort_values(by=["First Sort","Second Sort"],ascending=[True, True])
df7 = df7.drop(["ISIN","Issuer Equity_red_tier_ccy_docclause","First Sort","Second Sort"], axis=1).set_index("Name").copy()

df7 = df7[["Family","CDS RED Code","Price","Sprd","Mat. Matched CDS","Basis","Basis 1Y Low","Basis 1Y High",\
           "ZScore_3M","ZScore_6M","ZScore_12M"]].copy()
df7 = round(df7,2)

# %%
for family in ["HY","IG","EUR_HY", 'EUR_IG', 'SNRFIN', 'SUBFIN']:
    df8 = df7[df7["Family"]==family].copy()
    df8["Issuer"] = [item.split(" ")[0] for item in df8.index]
    issuers = df8["Issuer"].to_list()
    all_corp_z = pd.DataFrame(columns={"Family":[],"Basis 3M ZScore":[],"Basis 6M ZScore":[],"Basis 12M ZScore":[]})
    for issuer in issuers:
        all_corp_z.loc[issuer] = list(set(df8[df8["Issuer"] == issuer]["Family"])) +\
        list(df8[df8["Issuer"] == issuer][["ZScore_3M","ZScore_6M","ZScore_12M"]].median(axis=0))
    all_corp_z = round(all_corp_z.drop("Family",axis=1),1)
    globals()[f'df_{family}'] = all_corp_z.copy()

# %%
df7[df7["Family"]=="EUR_IG"]

# %%
def color_negative_red_positive_green_basis(col: pd.Series):
    if col.empty:
        return ['' for _ in col]
    float_col = col[col.apply(lambda x: isinstance(x, float))]
    min_val, max_val = float_col.min(), float_col.max()
    def value_to_color(val):
        if not isinstance(val, float):
            return ''
        if val < 0 and min_val < 0:
            frac = val/ min_val
            frac = max(min(frac,1),0)
            r = int(255 - (255 - 87) * frac)
            g = int(255 - (255 - 187) * frac)
            b = int(255 - (255 - 138) * frac)
            a = 0.75
            return f'background-color: rgb({r},{g},{b},{a})'
        elif val > 0 and max_val > 0:
            frac = val/ max_val
            frac = max(min(frac,1),0)
            r = int(255 - (255 - 230) * frac)
            g = int(255 - (255 - 135) * frac)
            b = int(255 - (255 - 115) * frac)
            a = 0.75
            return f'background-color: rgb({r},{g},{b},{a})'
        return ''
    return [value_to_color(v) for v in col]

def add_vertical_lines(df):
    styles = pd.DataFrame('', index=df.index, columns=df.columns)
    for i in range(1, len(df.columns), 2):
        styles.iloc[:, i] = 'border-right: 8px solid black;'
    return styles
    
def style_rich_cheap_basis(df):
    styled_df = df.style.apply(color_negative_red_positive_green_basis, subset=df.columns[-3:], axis=0)
    styled_df = styled_df.format(precision=2)
    styled_df = styled_df.format(precision=0, subset=df.columns[2:7])
    styled_df = styled_df.format(precision=1, subset=df.columns[-3:])
    styled_df = styled_df.set_properties(**{'text-align': 'center'})
    styled_df = styled_df.applymap(lambda val: 'font-weight: bold', subset=pd.IndexSlice[:, df.columns[4]])
    return styled_df
    
for rating_col in ["IG","HY","EUR_IG","EUR_HY","SNRFIN","SUBFIN"]:
    df1 = df7[df7["Family"]==rating_col].drop("Family",axis=1)
    df1["Issuer"] = [item.split(" ")[0] for item in df1.index]
    
    num_issuers = len(set([item.split(" ")[0] for item in df1.index]))
    
    issuers_per_table = 4
    # issuers_list = list(sorted(set([item.split(" ")[0] for item in df1.index])))
    issuers_list = list(sorted(set(df1["Issuer"])))
    
    for i in range(int(num_issuers/issuers_per_table)+1):
        globals()[f'df_{i}'] = df1[df1["Issuer"].isin(issuers_list[issuers_per_table*i:issuers_per_table*i+issuers_per_table])].copy()
    
    modified_dfs = []
    
    for i in range(int(num_issuers / issuers_per_table) + 1):
        df = globals()[f'df_{i}'].reset_index().copy()
        new_df = pd.DataFrame(columns=df.columns)
        
        for issuer in df['Issuer'].unique():
            issuer_rows = df[df['Issuer'] == issuer]
            new_df = pd.concat([new_df, issuer_rows], ignore_index=True)
            empty_row = pd.Series([''] * len(df.columns), index=df.columns)
            new_df = pd.concat([new_df, pd.DataFrame([empty_row])], ignore_index=True)
        globals()[f'df_{i}'] = new_df.set_index(new_df.columns[0]).drop("Issuer",axis=1).copy()                
    
        
    for i in range(int(num_issuers / issuers_per_table) + 1):
        df = globals()[f'df_{i}'].copy()
        index_counts = {}
        new_index = []
        
        for idx in df.index:
            if idx in index_counts:
                index_counts[idx] += 1
                # new_index.append(f"{idx}_{index_counts[idx]}")
                new_index.append(f"{idx}{'_' * index_counts[idx]}{pd.to_datetime(last_update).strftime("%d-%b")}")
    
            else:
                count = df.index.tolist().count(idx)
                if count > 1:
                    index_counts[idx] = 1
                    new_index.append(f"{idx}_{pd.to_datetime(last_update).strftime("%d-%b")}")
                else:
                    new_index.append(idx)
        df.index = new_index
        df.index.name = f'{pd.to_datetime(last_update).strftime("%d-%b")}'
        globals()[f'display_df_{i}'] = style_rich_cheap_basis(df.iloc[:-1,:])
        globals()[f'display_df_{i}'] = globals()[f'display_df_{i}'].set_table_styles(
            [
                {'selector': 'tr', 'props': [('width', '8px')]},
                {'selector': 'th, td', 'props': [('line-height', '8px')]}
            ],)
    
        dfi.export(globals()[f'display_df_{i}'] , f'Plots/{rating_col}/{rating_col}_{i}.png', table_conversion='chrome', dpi=100)
    
    import os
    import win32com.client
    import glob
    import pandas as pd
    import dataframe_image as dfi
    from io import BytesIO
    import tempfile
    
    html_body = "<html><body>"
    
    outlook = win32com.client.Dispatch("Outlook.Application")
    mail = outlook.CreateItem(0)
    
    folder_path = f'J:\\53A. HY Bonds Basis Email\\Plots\\{rating_col}'
    png_files = glob.glob(os.path.join(folder_path, '*.png'))
    png_files = [item for item in png_files if f"{rating_col}_" in item]
    png_files.sort(key=lambda x: int(os.path.splitext(os.path.basename(x))[0].rsplit("_")[-1]))
    
    for png_file in png_files:
        raw_name = os.path.splitext(os.path.basename(png_file))[0]
        image_cid = raw_name.replace(" ", "_")
        attachment = mail.Attachments.Add(Source=png_file)
        attachment.PropertyAccessor.SetProperty("http://schemas.microsoft.com/mapi/proptag/0x3712001F", image_cid)
        html_body += f'<img src="cid:{image_cid}"><br><br><br>'
    
    html_body += '</body></html>'
    
    mail.HTMLBody = html_body
    mail.Subject = f'{rating_col.replace("_"," ")} Basis (auto)'
    mail.CC = 'vasu.sharma@iiicm.com'
    if email_both:
        mail.To = 'spyros.michas@iiicm.com'
    mail.Send()
    
print("Sent")

# %%
def style_rich_cheap_basis(df):
    # styled_df = df.style.applymap(color_negative_red_positive_green_basis, subset=df.columns[-3:])
    styled_df = df.style.apply(color_negative_red_positive_green_basis, subset=df.columns[:], axis=0)
    # styled_df = styled_df.format(precision=2)
    # styled_df = styled_df.format(precision=0, subset=df.columns[1:6])
    styled_df = styled_df.format(precision=1, subset=df.columns[:])
    styled_df = styled_df.set_properties(**{'text-align': 'center'})
    # styled_df = styled_df.applymap(lambda val: 'font-weight: bold', subset=pd.IndexSlice[:, df.columns[3]])
    return styled_df
    
    
# em = pd.read_excel(
#     r"J:\\8A. Automating EM & EMB vs IEF SR+PnL Optimization\\DQ_Data_v75.xlsx",\
#                    index_col=0, parse_dates=True)

em = pd.read_excel("DQ_Data_v75.xlsx",index_col=0, parse_dates=True)

dfz = em[[col for col in em.columns if col.endswith("Basis")]].dropna(how="all").copy()
all_z_df = None

for period in [63, 126, 252]:
    nan_limit = 0.95 if period==252 else 0.9
    x = ((dfz-dfz.rolling(period, min_periods = int(nan_limit*period)).mean())/dfz.rolling(period,\
                  min_periods = int(nan_limit*period)).std()).iloc[[-1],:].copy()
    x.index = [f'ZScore_{int(period/21)}M']
    all_z_df = pd.concat([all_z_df , x])

all_z_df = all_z_df.T
all_z_df["Country"] = [item.split(" ")[0] for item in all_z_df.index]

all_z_df["Year"] = [item.rsplit(" ",2)[-2] for item in all_z_df.index]
all_z_df = round(all_z_df.sort_values(by=["Country","Year"],ascending=True),1)

em_scores = pd.DataFrame(columns={"Basis 3M ZScore":[],"Basis 6M ZScore":[],"Basis 12M ZScore":[]})
for issuer in sorted(list(set(all_z_df["Country"]))):
    # issuer = list(set(all_z_df["Country"]))[0]
    em_scores.loc[issuer] =\
    list(all_z_df[all_z_df["Country"]==issuer][["ZScore_3M","ZScore_6M","ZScore_12M"]].median(axis=0))
df_EM = round(em_scores,1).copy()

# %%
for family in ["EM","HY","IG","EUR_HY", 'EUR_IG', 'SNRFIN', 'SUBFIN']:
    num = int(len(globals()[f'df_{family}'])/32)+1
    
    for i in range(num):
        display_df1 = globals()[f'df_{family}'].iloc[30*i:30*i+30].copy()
        display_df1 = style_rich_cheap_basis(display_df1)
        display_df1.index.name = f'{em.index[-1].strftime("%d-%b") if family=="EM" else pd.\
            to_datetime(last_update).strftime("%d-%b")}'
        
        display_df1 = display_df1.set_table_styles(
            [{'selector': 'tr', 'props': [('width', '8px')]},
                {'selector': 'th, td', 'props': [('line-height', '8px')]}],)
        dfi.export(display_df1, f'Email Plots/{family.replace("_","")}_{i+1}.png', table_conversion='chrome', dpi=100)

# %%
plot_names = None
for family in ["EM","HY","IG","EUR_HY", 'EUR_IG', 'SNRFIN', 'SUBFIN']:
    df = globals()[f'df_{family}'].copy()
    df = df[(abs(df["Basis 3M ZScore"])>=1.5) & (abs(df["Basis 6M ZScore"])>=1.5) & (abs(df["Basis 12M ZScore"])>=1.5)]
    df["Family"] = [family] * len(df)
    plot_names = pd.concat([plot_names,df])

# %%
# ############## Setting Default Bonds
# isin_list = [
#              "US105756BZ27", "US105756CA66", "US105756CC23", "US105756CG37", "US105756CE88", "US105756CK49", "US105756CF53", "US105756CH10", "US105756BW95", "US105756BY51", "US105756CB40", "US105756CJ75", "US168863DX33", "US168863CF36", "US168863EB04", "US168863DP09", "US168863DN50", "US168863DT21", "US168863DV76", "US168863DZ80", "US168863DS48", "US168863DY16", "US168863CE60", "US168863DL94", "US168863DW59", "XS2327851874", "US168863EA21", "US168863DQ81", "US168863DU93", "US195325DL65", "US195325DP79", "US195325DR36", "US195325DS19", "US195325DZ51", "US195325EF88", "US195325EG61", "US195325EL56", "US195325BK01", "US195325BM66", "US195325EA91", "US195325BR53", "US195325CU73", "US195325DQ52", "US195325DT91", "US195325EM30", "US195325DX04", "US91087BAC46", "US91087BAE02", "US91087BAU44", "US91087BAF76", "US91087BAY65", "US91087BAH33", "US91087BAM28", "US91087BAK61", "US91087BAT70", "US91087BAR15", "US91087BAV27", "US91087BAZ31", "US91086QAV05", "US91087BAQ32", "US91086QBB32", "US91086QBE70", "US91086QBF46", "US91087BAB62", "US91087BAD29", "US91087BAG59", "US91087BAL45", "US91087BAS97", "US91087BAX82", "US91087BBA70", "US91087BAN01", "XS2280637039", "US91086QAZ19", "US698299BF03", "US698299BK97", "US698299BX19", "USP90603AP97", "US698299BN37", "US698299BR41", "US698299BT07", "US698299AW45", "US698299BW36", "US698299BY91", "US698299BG85", "US698299BH68", "US698299BB98", "US698299BV52", "US698299BM53", "US698299BL70", "US698299BS24", "US715638BU55", "US715638DA73", "US715638DF60", "US715638DP43", "US715638DU38", "US715638EB48", "US715638DS81", "US715638BM30", "US715638DT64", "US715638EC21", "US715638DQ26", "US715638DW93", "US715638DR09", "US836205AW44", "US836205AU87", "US836205BA15", "US836205AY00", "US836205BC70", "US836205AS32", "US836205AV60", "US836205AX27", "US836205BB97", "US836205BE37", "US900123CL22", "USM88269US88", "US900123DF45", "US900123CP36", "US900123CQ19", "US900123DH01", "US900123CT57", "US900123CY43", "US900123DJ66", "US900123DA57", "US900123DC14", "US900123DL13", "US900123DG28", "US900123DD96", "US900123AT75", "US900123DK30", "US900123DN78", "US900123AY60", "US900123BB58", "US900123BG46", "US900123BJ84", "US900123CB40", "US900123CG37", "US900123CM05", "USP3579EBV85", "USP3579ECB13", "USP3579ECP09", "USP3579ECF27", "USP3579ECR64", "USP3579ECH82", "USP3579ECN50", "USP3579ECU93", "USP3579ECJ49", "USP3579EAY34", "USP3579EBE60", "USP3579EBY25", "USP3579ECE51", "USP3579ECG00", "US71654QDB59", "US71654QCG55", "US71654QCK67", "US71654QCP54", "US71654QDL32", "US71654QDC33", "US71654QDE98", "US71643VAB18", "US71654QDP46", "US706451BG56", "US71654QAZ54", "US71654QBR20", "US71654QCC42", "US71654QCL41", "US71654QDD16", "US71654QDF63", "US71656MAF68", "US71647NAS80", "US71647NAY58", "US71647NBH17", "US71647NBK46", "US71647NBL29", "US71645WAQ42", "US71645WAS08", "US71647NAK54", "US71647NBJ72", "US71647NAN93",
#              "XS2214237807", "XS2214239506", "XS2214238441", "XS2214239175", "US040114HX11", "US040114HS26", "US040114HT09", "US040114HU71", "US040114HV54", "US040114HW38", "XS1910826996", "XS1717011982", "XS2384698994", "XS2445169985", "XS1777972511", "XS1910827887", "XS2948511949", "XS1566179039", "XS2384701020", "XS2948512913", "XS1777972941", "XS1717013095", "XS1910828182", "XS2384704800", "XS1843435840", "XS1781710543", "XS2764839945", "XS1843435766", "XS2354781614", "XS1781710626", "XS1318576086", "XS1819680288", "XS2083302419", "XS2446175577", "XS1819680528", "XS2083302500", "XS1790104530", "XS1619155564", "XS2333676133", "XS1790134362", "XS2297220423", "XS1903488572", "XS1558078736", "XS2391394348", "XS1775618439", "XS1504948776", "XS1953057061", "XS1903489463", "XS2297226545", "XS2079842642", "XS2176897754", "XS2391395154", "XS1558078496", "XS1775617464", "XS1953057491", "XS2176899701", "XS2391398174", "USP01012BX31", "USP01012CF16", "XS0146173371", "USP01012AN67", "USP01012AR71", "USP01012CA29", "USP01012CC84", "USP01012CH71", 
#              "USP7808BAA54", "USP7808BAB38", "XS0505478684", "XS2079846635", "XS2297221405",
#              "USG2583XAB76", "USL21779AL44", "USL21779AJ97", "USL21779AK60", 
#             ]

# isin_list += ['XS2965710598','US105756CM05','US105756CL22','US168863EE43','US195325EQ44','US195325ER27','US195325ES00','US195325EP60','USP3579ECW59','USP3579ECX33','US03846JAH32','US03846JAG58','XS3010561762','US91087BBB53','US91087BBD10','US91087BBF67','US91087BBE92','US91087BBC37','US715638FD94','US715638FC12','XS2908172260','US836205BG84','US900123DQ00','USN15516AJ10']

# names_list = [
#              "BRAZIL 4 5/8 01/13/28", "BRAZIL 4 1/2 05/30/29", "BRAZIL 3 7/8 06/12/30", "BRAZIL 6 1/4 03/18/31", "BRAZIL 3 3/4 09/12/31", "BRAZIL 6 1/8 01/22/32", "BRAZIL 6 10/20/33", "BRAZIL 6 1/8 03/15/34", "BRAZIL 5 01/27/45", "BRAZIL 5 5/8 02/21/47", "BRAZIL 4 3/4 01/14/50", "BRAZIL 7 1/8 05/13/54", "CHILE 2 3/4 01/31/27", "CHILE 3.24 02/06/28", "CHILE 4.85 01/22/29", "CHILE 2.45 01/31/31", "CHILE 2.55 01/27/32", "CHILE 2.55 07/27/33", "CHILE 3 1/2 01/31/34", "CHILE 4.95 01/05/36", "CHILE 3.1 05/07/41", "CHILE 4.34 03/07/42", "CHILE 3.86 06/21/47", "CHILE 3 1/2 01/25/50", "CHILE 4 01/31/52", "CHILE 3 1/2 04/15/53", "CHILE 5.33 01/05/54", "CHILE 3.1 01/22/61", "CHILE 3 1/4 09/21/2071", "COLOM 3 7/8 04/25/27", "COLOM 4 1/2 03/15/29", "COLOM 3 01/30/30", "COLOM 3 1/8 04/15/31", "COLOM 3 1/4 04/22/32", "COLOM 8 04/20/33", "COLOM 7 1/2 02/02/34", "COLOM 8 11/14/35", "COLOM 7 3/8 09/18/37", "COLOM 6 1/8 01/18/41", "COLOM 4 1/8 02/22/42", "COLOM 5 5/8 02/26/44", "COLOM 5 06/15/45", "COLOM 5.2 05/15/49", "COLOM 4 1/8 05/15/51", "COLOM 8 3/4 11/14/53", "COLOM 3 7/8 02/15/61", "MEX 4.15 03/28/27", "MEX 3 3/4 01/11/28", "MEX 5.4 02/09/28", "MEX 4 1/2 04/22/29", "MEX 5 05/07/29", "MEX 3 1/4 04/16/30", "MEX 2.659 05/24/31", "MEX 4 3/4 04/27/32", "MEX 4 7/8 05/19/33", "MEX 3 1/2 02/12/34", "MEX 6.35 02/09/35", "MEX 6 05/07/36", "MEX 6.05 01/11/40", "MEX 4.28 08/14/41", "MEX 4 3/4 03/08/44", "MEX 5.55 01/21/45", "MEX 4.6 01/23/46", "MEX 4.35 01/15/47", "MEX 4.6 02/10/48", "MEX 4 1/2 01/31/50", "MEX 5 04/27/51", "MEX 4.4 02/12/52", "MEX 6.338 05/04/53", "MEX 6.4 05/07/54", "MEX 3.771 05/24/61", "MEX 3 3/4 04/19/2071", "MEX 5 3/4 10/12/2110", "PANAMA 3 7/8 03/17/28", "PANAMA 3.16 01/23/30", "PANAMA 7 1/2 03/01/31", "PANAMA 3.362 06/30/31", "PANAMA 2.252 09/29/32", "PANAMA 3.298 01/19/33", "PANAMA 6.4 02/14/35", "PANAMA 6.7 01/26/36", "PANAMA 6 7/8 01/31/36", "PANAMA 8 03/01/38", "PANAMA 4 1/2 05/15/47", "PANAMA 4 1/2 04/16/50", "PANAMA 4.3 04/29/53", "PANAMA 6.853 03/28/54", "PANAMA 4 1/2 04/01/56", "PANAMA 3.87 07/23/60", "PANAMA 4 1/2 01/19/63", "PERU 4 1/8 08/25/27", "PERU 2.844 06/20/30", "PERU 2.783 01/23/31", "PERU 1.862 12/01/32", "PERU 3 01/15/34", "PERU 5 3/8 02/08/35", "PERU 3.3 03/11/41", "PERU 5 5/8 11/18/50", "PERU 3.55 03/10/51", "PERU 5 7/8 08/08/54", "PERU 2.78 12/01/60", "PERU 3.6 01/15/2072", "PERU 3.23 07/28/2121", "SOAF 4.85 09/27/27", "SOAF 4.3 10/12/28", "SOAF 4.85 09/30/29", "SOAF 5 7/8 06/22/30", "SOAF 5 7/8 04/20/32", "SOAF 5 3/8 07/24/44", "SOAF 5 10/12/46", "SOAF 5.65 09/27/47", "SOAF 5 3/4 09/30/49", "SOAF 7.3 04/20/52", "TURKEY 6 03/25/27", "TURKEY 8.6 09/24/27", "TURKEY 9 7/8 01/15/28", "TURKEY 5 1/8 02/17/28", "TURKEY 6 1/8 10/24/28", "TURKEY 9 3/8 03/14/29", "TURKEY 7 5/8 04/26/29", "TURKEY 5 1/4 03/13/30", "TURKEY 9 1/8 07/13/30", "TURKEY 5.95 01/15/31", "TURKEY 5 7/8 06/26/31", "TURKEY 7 1/8 07/17/32", "TURKEY 9 3/8 01/19/33", "TURKEY 6 1/2 09/20/33", "TURKEY 8 02/14/34", "TURKEY 7 5/8 05/15/34", "TURKEY 6 1/2 01/03/35", "TURKEY 6 7/8 03/17/36", "TURKEY 7 1/4 03/05/38", "TURKEY 6 3/4 05/30/40", "TURKEY 6 01/14/41", "TURKEY 4 7/8 04/16/43", "TURKEY 6 5/8 02/17/45", "TURKEY 5 3/4 05/11/47", "DOMREP 5.95 01/25/27", "DOMREP 6 07/19/28", "DOMREP 5 1/2 02/22/29", "DOMREP 4 1/2 01/30/30", "DOMREP 7.05 02/03/31", "DOMREP 4 7/8 09/23/32", "DOMREP 6 02/22/33", "DOMREP 6.6 06/01/36", "DOMREP 5.3 01/21/41", "DOMREP 7.45 04/30/44", "DOMREP 6.85 01/27/45", "DOMREP 6 1/2 02/15/48", "DOMREP 6.4 06/05/49", "DOMREP 5 7/8 01/30/60", "PEMEX 6.49 01/23/27", "PEMEX 6 1/2 03/13/27", "PEMEX 5.35 02/12/28", "PEMEX 6 1/2 01/23/29", "PEMEX 8 3/4 06/02/29", "PEMEX 6.84 01/23/30", "PEMEX 5.95 01/28/31", "PEMEX 6.7 02/16/32", "PEMEX 10 02/07/33", "PEMEX 6 5/8 06/15/35", "PEMEX 6 1/2 06/02/41", "PEMEX 6 3/8 01/23/45", "PEMEX 6 3/4 09/21/47", "PEMEX 6.35 02/12/48", "PEMEX 7.69 01/23/50", "PEMEX 6.95 01/28/60", "PEMEX 6 5/8 PERP", "PETBRA 7 3/8 01/17/27", "PETBRA 5.999 01/27/28", "PETBRA 5.6 01/03/31", "PETBRA 6 1/2 07/03/33", "PETBRA 6 01/13/35", "PETBRA 6 7/8 01/20/40", "PETBRA 6 3/4 01/27/41", "PETBRA 7 1/4 03/17/44", "PETBRA 5 1/2 06/10/51", "PETBRA 6.85 06/05/2115",
#              "ECUA 6.9 07/31/30", "ECUA 0 07/31/30", "ECUA 5 1/2 07/31/35", "ECUA 5 07/31/40", "ARGENT 1 07/09/29", "ARGENT 0 3/4 07/09/30", "ARGENT 4 1/8 07/09/35", "ARGENT 5 01/09/38", "ARGENT 3 1/2 07/09/41", "ARGENT 4 1/8 07/09/46", "NGERIA 7 5/8 11/21/25", "NGERIA 6 1/2 11/28/27", "NGERIA 6 1/8 09/28/28", "NGERIA 8 3/8 03/24/29", "NGERIA 7.143 02/23/30", "NGERIA 8.747 01/21/31", "NGERIA 9 5/8 06/09/31", "NGERIA 7 7/8 02/16/32", "NGERIA 7 3/8 09/28/33", "NGERIA 10 3/8 12/09/34", "NGERIA 7.696 02/23/38", "NGERIA 7 5/8 11/28/47", "NGERIA 9.248 01/21/49", "NGERIA 8 1/4 09/28/51", "KENINT 7 05/22/27", "KENINT 7 1/4 02/28/28", "KENINT 9 3/4 02/16/31", "KENINT 8 05/22/32", "KENINT 6.3 01/23/34", "KENINT 8 1/4 02/28/48", "ANGOL 9 1/2 11/12/25", "ANGOL 8 1/4 05/09/28", "ANGOL 8 11/26/29", "ANGOL 8 3/4 04/14/32", "ANGOL 9 3/8 05/08/48", "ANGOL 9 1/8 11/26/49", "SENEGL 4 3/4 03/13/28", "SENEGL 6 1/4 05/23/33", "SENEGL 5 3/8 06/08/37", "SENEGL 6 3/4 03/13/48", "EGYPT 3 7/8 02/16/26", "EGYPT 7 1/8 11/10/26", "EGYPT 7 1/2 01/31/27", "EGYPT 5.8 09/30/27", "EGYPT 6.588 02/21/28", "EGYPT 7 11/10/28", "EGYPT 7.6003 03/01/29", "EGYPT 7 5/8 11/10/30", "EGYPT 5 7/8 02/16/31", "EGYPT 7.0529 01/15/32", "EGYPT 7 5/8 05/29/32", "EGYPT 7.3 09/30/33", "EGYPT 8 1/2 01/31/47", "EGYPT 7.903 02/21/48", "EGYPT 8.7002 03/01/49", "EGYPT 8 7/8 05/29/50", "EGYPT 8 3/4 09/30/51", "ELSALV 8 5/8 02/28/29", "ELSALV 9 1/4 04/17/30", "ELSALV 8 1/4 04/10/32", "ELSALV 7.65 06/15/35", "ELSALV 7 5/8 02/01/41", "ELSALV 7.1246 01/20/50", "ELSALV 9 1/2 07/15/52", "ELSALV 9.65 11/21/54", 
#              "PETRPE 4 3/4 06/19/32", "PETRPE 5 5/8 06/19/47", "EGYPT 6 7/8 04/30/40", "EGYPT 8.15 11/20/59", "EGYPT 7 1/2 02/16/61", 
#              "CSNABZ 6 3/4 01/28/28", "CSNABZ 8 7/8 12/05/30", "CSNABZ 4 5/8 06/10/31", "CSNABZ 5 7/8 04/08/32",
#              ]
# names_list += ['ANGOL 10.95 12/27/30', 'BRAZIL 5 1/2 11/06/30', 'BRAZIL 6 5/8 03/15/35', 'CHILE 5.65 01/13/37', 'COLOM 8 3/8 11/07/54', 'COLOM 7 3/8 04/25/30', 'COLOM 8 1/2 04/25/35', 'COLOM 7 3/4 11/07/36', 'DOMREP 6.95 03/15/37', 'DOMREP 7.15 02/24/55', 'EGYPT 8 5/8 02/04/30', 'EGYPT 9.45 02/04/33', 'KENINT 9 1/2 03/05/36', 'MEX 6 05/13/30', 'MEX 7 3/8 05/13/55', 'MEX 6 5/8 01/29/38', 'MEX 5.85 07/02/32', 'MEX 6 7/8 05/13/37', 'PERU 6.2 06/30/55', 'PERU 5 1/2 03/30/36', 'SOAF 7.1 11/19/36', 'SOAF 7.95 11/19/54', 'TURKEY 7 1/4 05/29/32', 'BRASKM 8 10/15/34']
# names_list[names_list.index("PEMEX 6 5/8 PERP")] = "PEMEX 6 5/8 01/01/9999"

# new_dict = dict(zip(names_list, isin_list))

# df = pd.DataFrame({"Name" : list(new_dict.keys()), "ISIN": list(new_dict.values())})
# df = pd.concat([df, df6[["Name","ISIN"]]]).reset_index(drop=True).copy()

# def extract_year(name):
#     try:
#         return name.rsplit(" ", 1)[-1]
#     except Exception:
#         return np.nan

# df["Mat. Time"] = round((pd.to_datetime(df["Name"].apply(extract_year), errors='coerce')-datetime.now()).dt.days / 365,2)

# isins=[f"/isin/{item}@BGN" for item in df["ISIN"]]
# # y = blp.bdp(tickers=isins, flds="ISSUE_DT").copy()
# y1 = y.copy()
# y1.index = [item.replace("/isin/","").replace("@BGN","") for item in y1.index]
# y1 = y1.reset_index().copy()
# y1.columns = ["ISIN","Issue"]
# z = pd.merge(left=df, right=y1, on="ISIN", how="inner")
# z["Issue"] = pd.to_datetime(z["Issue"])
# z["Issue Time"] = round((datetime.now()-z["Issue"]).dt.days/365,2)
# z["Issuer"] = z["Name"].apply(lambda x: x.split(" ")[0])
# z = z.sort_values(by=["Issuer","Issue Time"], ascending=[True, False]).reset_index(drop=True).copy()

# all_k = None

# issuers = set(z["Issuer"])
# for issuer in issuers:
#     x = z[z["Issuer"]==issuer].copy()
#     # display(x)
#     x1 = x[(x["Mat. Time"]>=4) & (x["Mat. Time"]<=8)].copy()
#     if len(x1) > 0:
#         k = x1.iloc[[0]].copy()
#     else:
#         k = x.iloc[[0]].copy()
#     # display(k)
#     all_k = pd.concat([all_k, k]).reset_index(drop=True).copy()

# all_k["Name"] = all_k["Name"].apply(lambda x: x.rsplit(" ",1)[0] + "% due " + x.rsplit("/",1)[1])
# all_k["Name"] = all_k["Name"].apply(lambda x: x.split(" ",1)[1])
# default_bonds = dict(zip(all_k["Issuer"],all_k["Name"]))

default_bonds = {'AVNT': '7 ⅛% due 30',
 'SIEGR': '1 ⅜% due 30',
 'T': '4.3% due 30',
 'PUBFP': '1 ¾% due 31',
 'DGFP': '1 ¾% due 30',
 'CMZB': '4% due 30',
 'LINTA': '4% due 29',
 'ECUA': '6.9% due 30',
 'NOKIA': '4 ⅜% due 31',
 'TITIM': '7 ¾% due 33',
 'KERFP': '1 ⅞% due 30',
 'ET': '4.15% due 29',
 'LEN': '5.2% due 30',
 'STLA': '1 ⅛% due 29',
 'ENGIFP': '0 ½% due 30',
 'MCK': '5.1% due 33',
 'CLF': '4 ⅞% due 31',
 'SOAF': '5 7/8% due 30',
 'LLOYDS': '3 ⅛% due 30',
 'FCX': '5 ¼% due 29',
 'TGT': '6.35% due 32',
 'MGM': '6 ½% due 32',
 'PHM': '7 ⅞% due 32',
 'LNC': '3.05% due 30',
 'SO': '2.65% due 29',
 'AALLN': '4 ¾% due 32',
 'MO': '3.4% due 30',
 'EDF': '5 ⅝% due 33',
 'MCFP': '0 ⅜% due 31',
 'ZFFNGR': '3% due 29',
 'APA': '4 ¼% due 30',
 'RIG': '7 ½% due 31',
 'ITVLN': '4 ¼% due 32',
 'OXY': '7 ½% due 31',
 'TELNO': '0 ⅝% due 31',
 'HD': '2.7% due 30',
 'CHTR': '4 ¾% due 30',
 'SHW': '2.3% due 30',
 'GIS': '2 ⅞% due 30',
 'SESGFP': '4 ⅛% due 30',
 'SOCGEN': '1% due 30',
 'IPGIM': '4 ⅞% due 30',
 'IRM': '4 ⅞% due 29',
 'L': '3.2% due 30',
 'GE': '6 ¾% due 32',
 'COXENT': '1.8% due 30',
 'CAR': '8% due 31',
 'UNH': '2% due 30',
 'MSI': '2.3% due 30',
 'HENKEL': '0 ½% due 32',
 'RGCARE': '10% due 32',
 'ZIGGO': '3 ⅜% due 30',
 'EMN': '5 ¾% due 33',
 'PRU': '5 ¾% due 33',
 'NGGLN': '0.553% due 29',
 'CPIPGR': '1 ½% due 31',
 'EXC': '4.05% due 30',
 'VZ': '7 ¾% due 30',
 'ORAFP': '8 ⅛% due 33',
 'CPGLN': '3 ¼% due 31',
 'AEP': '2.3% due 30',
 'INTC': '4% due 32',
 'PG': '3% due 30',
 'KENINT': '8% due 32',
 'SHAEFF': '4 ½% due 30',
 'FDX': '4 ¼% due 30',
 'BMW': '0 ⅞% due 32',
 'OMC': '2.45% due 30',
 'SWEDA': '3 ⅝% due 32',
 'DIS': '7% due 32',
 'BA': '6 ⅛% due 33',
 'MTNA': '3 ½% due 31',
 'TELEFO': '5 ⅞% due 33',
 'BHCCN': '5 ¼% due 30',
 'BACRED': '6 ½% due 33',
 'BBY': '1.95% due 30',
 'NAVI': '5 ⅝% due 33',
 'MBGGR': '2% due 31',
 'KHC': '6 ¾% due 32',
 'PHIANA': '2% due 30',
 'PKG': '3% due 29',
 'BBDBCN': '8 ¾% due 30',
 'ARGENT': '0 3/4% due 30',
 'TRPCN': '4.1% due 30',
 'WMT': '7.55% due 30',
 'CARLB': '0 ⅝% due 30',
 'AES': '3.95% due 30',
 'HEIANA': '2.02% due 32',
 'HOLNSW': '0 ½% due 31',
 'CSCHLD': '5 ¾% due 30',
 'LMT': '1.85% due 30',
 'EGYPT': '7 5/8% due 30',
 'ACAFP': '2% due 30',
 'BBVASM': '5 ¾% due 33',
 'CMACG': '5% due 31',
 'HES': '7 ⅞% due 29',
 'ELSALV': '8 1/4% due 32',
 'CAG': '8 ¼% due 30',
 'MPW': '3 ½% due 31',
 'UNANA': '1 ⅝% due 33',
 'MEX': '3 1/4% due 30',
 'HLT': '4 ⅞% due 30',
 'ALL': '5.35% due 33',
 'URI': '5 ¼% due 30',
 'ARW': '2.95% due 32',
 'DANBNK': '1 ½% due 30',
 'FRFP': '4 ½% due 30',
 'BERTEL': '1 ½% due 30',
 'CPN': '5% due 31',
 'AVT': '3% due 31',
 'BASGR': '3% due 33',
 'PFE': '2 ⅝% due 30',
 'DUFNSW': '4 ¾% due 31',
 'HOTGR': '4 ¼% due 30',
 'VLO': '7 ½% due 32',
 'PNLNA': '4 ¾% due 31',
 'BYD': '4 ¾% due 31',
 'NEE': '2 ¾% due 29',
 'BRAZIL': '3 7/8% due 30',
 'TGNA': '5% due 29',
 'WMB': '7 ½% due 31',
 'SVC': '4 ⅜% due 30',
 'RCL': '6 ¼% due 32',
 'AIG': '3.4% due 30',
 'FE': '4.55% due 30',
 'BZH': '7 ¼% due 29',
 'RDSALN': '0 ½% due 31',
 'HSBC': '0.77% due 31',
 'LOUDRE': '3 ½% due 31',
 'WHR': '2.4% due 31',
 'SEE': '6 ⅞% due 33',
 'BBWI': '6 ⅝% due 30',
 'SPG': '2.45% due 29',
 'TURKEY': '5 1/4% due 30',
 'JPM': '4.452% due 29',
 'UNP': '2.4% due 30',
 'CCL': '6 ⅛% due 33',
 'GFLCN': '6 ⅝% due 32',
 'CZR': '4 ⅝% due 29',
 'D': '6.3% due 33',
 'CE': '6.629% due 32',
 'HST': '3 ⅜% due 29',
 'HOUS': '5 ¼% due 30',
 'BPLN': '1.231% due 31',
 'DVA': '4 ⅝% due 30',
 'NEXIIM': '3 ⅞% due 31',
 'BSX': '2.65% due 30',
 'ACFP': '3 ⅞% due 31',
 'REPSM': '2 ⅝% due 30',
 'OVV': '8 ⅛% due 30',
 'EOANGR': '5 ¾% due 33',
 'BAX': '3.95% due 30',
 'AMD': '2 ⅜% due 30',
 'GSK': '1 ⅜% due 29',
 'LW': '4 ⅛% due 30',
 'POST': '5 ½% due 29',
 'OLN': '5% due 30',
 'HON': '1.95% due 30',
 'AXP': '4.42% due 33',
 'BWA': '5.4% due 34',
 'PETRPE': '4 3/4% due 32',
 'MDLZ': '2 ¾% due 30',
 'GLENLN': '1 ¼% due 33',
 'BMCAUS': '4 ⅜% due 30',
 'COOP': '7 ⅛% due 32',
 'GM': '5.4% due 29',
 'MET': '6 ½% due 32',
 'AMGN': '2.45% due 30',
 'EDPPL': '1 ⅞% due 29',
 'NEM': '2.6% due 32',
 'RTX': '7 ½% due 29',
 'MBI': '5.7% due 34',
 'GAP': '3 ⅝% due 29',
 'SIRI': '4 ⅛% due 30',
 'TELIAS': '0 ⅛% due 30',
 'CAFP': '2 ⅜% due 29',
 'PARA': '7 ⅞% due 30',
 'BMY': '1.45% due 30',
 'NTGYSM': '1 ⅞% due 29',
 'SENEGL': '6 1/4% due 33',
 'F': '7.45% due 31',
 'BRK': '1.85% due 30',
 'SPMIM': '4 ⅞% due 30',
 'DB': '5 ⅝% due 31',
 'AIFP': '0 ⅝% due 30',
 'BATSLN': '2 ¼% due 30',
 'DOMREP': '4 1/2% due 30',
 'PERU': '2.844% due 30',
 'DHI': '4.85% due 30',
 'TSN': '4 ⅞% due 34',
 'DVN': '7 ⅞% due 31',
 'INTNED': '2 ½% due 30',
 'HCA': '3 ½% due 30',
 'KMI': '7.4% due 31',
 'AMZN': '1 ½% due 30',
 'NCLH': '6 ¼% due 30',
 'VLVY': '3% due 30',
 'YUM': '4 ¾% due 30',
 'URWFP': '1 ⅜% due 30',
 'HBGCN': '5 ⅝% due 29',
 'MEDIND': '5 ¼% due 29',
 'NBR': '9 ⅛% due 30',
 'GT': '5 ¼% due 31',
 'PETBRA': '5.6% due 31',
 'CMCSA': '7.05% due 33',
 'BRITEL': '1 ⅛% due 29',
 'BACR': '1 ⅛% due 31',
 'MUR': '6% due 32',
 'CSCO': '4.95% due 31',
 'SHBASS': '3 ¼% due 33',
 'UBS': '0.65% due 29',
 'BALL': '2 ⅞% due 30',
 'BNFP': '0.52% due 30',
 'ASH': '3 ⅜% due 31',
 'CPB': '2 ⅜% due 30',
 'BAYNGR': '2 ⅛% due 29',
 'KSS': '4 ⅝% due 31',
 'NRUC': '8% due 32',
 'WY': '7 ⅜% due 32',
 'OMF': '5 ⅜% due 29',
 'COF': '2.7% due 30',
 'ENBCN': '3 ⅛% due 29',
 'CAH': '5% due 29',
 'JNJ': '6.95% due 29',
 'VOVCAB': '4 ¾% due 30',
 'M': '6 ⅛% due 32',
 'CNQCN': '7.2% due 32',
 'MCD': '2 ⅝% due 29',
 'PEMEX': '6.84% due 30',
 'HEIGR': '3 ¾% due 32',
 'ALOFP': '0 ½% due 30',
 'AZN': '3 ¾% due 32',
 'DRI': '4.55% due 29',
 'CSNABZ': '4 5/8% due 31',
 'LUV': '2 ⅝% due 30',
 'WFRD': '8 ⅝% due 30',
 'ALLY': '8% due 31',
 'COLOM': '3% due 30',
 'DHR': '2.6% due 29',
 'EQNR': '1 ⅜% due 32',
 'HTZ': '5% due 29',
 'AXASA': '3 ¾% due 30',
 'ALIANT': '5 ⅞% due 29',
 'AXL': '5% due 29',
 'ENFP': '0 ½% due 30',
 'SRE': '5 ½% due 33',
 'PANAMA': '3.16% due 30',
 'TUIGR': '1.95% due 31',
 'IBM': '5 ⅞% due 32',
 'NRG': '3 ⅝% due 31',
 'RXLFP': '5 ¼% due 30',
 'HPQ': '3.4% due 30',
 'MPC': '5.15% due 30',
 'ORCL': '3 ¼% due 30',
 'ABIBB': '3 ¼% due 33',
 'ALVGR': '1 ⅜% due 31',
 'NSC': '2.55% due 29',
 'BRASKM': '8% due 34',
 'DAL': '3 ¾% due 29',
 'KBH': '4.8% due 29',
 'NGERIA': '7 7/8% due 32',
 'VIEFP': '1 ⅝% due 32',
 'ENIIM': '0 ⅝% due 30',
 'R': '4.95% due 29',
 'RABOBK': '3 ⅞% due 32',
 'RIFP': '0 ⅞% due 31',
 'ANGOL': '8% due 29',
 'VOD': '1.6% due 31',
 'VW': '3.3% due 33',
 'CIVI': '8 ¾% due 31',
 'ISPIM': '6.184% due 34',
 'NOC': '4.4% due 30',
 'TMUS': '2 ⅞% due 31',
 'LOW': '4 ½% due 30',
 'VST': '7 ¾% due 31',
 'STERV': '0 ⅝% due 30',
 'PPCGA': '4 ⅝% due 31',
 'DOW': '7 ⅜% due 29',
 'DT': '7 ½% due 33',
 'LXSGR': '0 ⅝% due 29',
 'JCI': '1 ¾% due 30',
 'DE': '7 ⅛% due 31',
 'IMBLN': '3 ⅞% due 34',
 'BNP': '2 ⅜% due 30',
 'MWDP': '1% due 31',
 'AFFP': '3 ¾% due 30',
 'LHAGR': '4% due 30',
 'CSTM': '5 ⅜% due 32',
 'KR': '7 ½% due 31',
 'AVGO': '4.15% due 30',
 'GS': '6 ⅛% due 33',
 'EOFP': '5 ½% due 31',
 'SOLBBB': '4 ¼% due 31',
 'ATLIM': '4 ½% due 30',
 'CHILE': '2.55% due 32',
 'CSX': '2.4% due 30',
 'MDC': '3.85% due 30',
 'THC': '6 ⅞% due 31',
 'HRB': '3 ⅞% due 30',
 'NWL': '6 ⅝% due 29',
 'AKZANA': '1 ⅝% due 30',
 'CCK': '4 ½% due 30',
 'ELTLX': '2 ½% due 30',
 'DGX': '2.95% due 30',
 'SGOFP': '1 ⅞% due 31',
 'FUMVFH': '4 ½% due 33',
 'ASSGEN': '2.124% due 30',
 'NFLX': '5 ⅜% due 29',
 'EXPE': '3 ¼% due 30',
 'VMED': '3 ¾% due 30',
 'STANLN': '1.2% due 31',
 'TSCOLN': '4 ¼% due 31',
 'CLNXSM': '1 ¾% due 30',
 'HILCRP': '6% due 31',
 'AIRFP': '2 ⅛% due 29',
 'CONGR': '3 ½% due 29',
 'TEVA': '8 ⅛% due 31',
 'TOL': '3.8% due 29',
 'HAL': '2.92% due 30',
 'KPN': '0 ⅞% due 32',
 'OGN': '5 ⅛% due 31',
 'UCGIM': '2.731% due 32',
 'AZO': '4% due 30',
 'CVS': '3 ¾% due 30',
 'SZUGR': '4 ⅛% due 32',
 'NWG': '0.78% due 30'}

# %%
# em = pd.read_excel(
#     r"J:\\8A. Automating EM & EMB vs IEF SR+PnL Optimization\\DQ_Data_v75.xlsx",\
                   # index_col=0, parse_dates=True)

em = pd.read_excel("DQ_Data_v75.xlsx",index_col=0, parse_dates=True)

a = [item.replace(" PECS Ask","") for item in em.columns.to_list() if item.endswith("PECS Ask")]
b = [item.replace(" PECS Bid","") for item in em.columns.to_list() if item.endswith("PECS Bid")]
c = [item.replace(" Basis","") for item in em.columns.to_list() if item.endswith("Basis")]

common = []
common2 = []
for item in a:
    if (item in b) and (item in c):
        common += [item]
        common2 += [f"{item} PECS Bid", f"{item} PECS Ask", f"{item} Basis"]
        
em_bonds = em[[col for col in em.columns if col in common2]].copy()
for item in common:
    em_bonds[f"{item} PECS"] = 0.5*(em_bonds[f"{item} PECS Bid"] + em_bonds[f"{item} PECS Ask"])
    em_bonds[f"{item} Mat. Matched CDS"] = em_bonds[f"{item} Basis"] + em_bonds[f"{item} PECS"]

em_bonds = em_bonds[[col for col in em_bonds.columns if col.endswith("CDS") or col.endswith("Basis")]]

#############################################

all_corp = None
corp = df5a[["Name"] + [item for item in df5a.columns if item.startswith("Mat_Matched_CDS_")]].copy()
corp = corp.set_index("Name").T
corp.index = [item.replace("Mat_Matched_CDS_","") for item in corp.index]
l = [item.rsplit(" ",1)[0] + "% due " + item.rsplit("/",1)[1] + " Mat. Matched CDS" for item in corp.columns]
corp.columns = l
all_corp = corp.copy()

corp = df5a[["Name"] + [item for item in df5a.columns if item.startswith("Basis_")]].copy()
corp = corp.set_index("Name").T
corp.index = [item.replace("Basis_","") for item in corp.index]
l = [item.rsplit(" ",1)[0] + "% due " + item.rsplit("/",1)[1] + " Basis" for item in corp.columns]
corp.columns = l
all_corp = pd.concat([all_corp, corp],axis=1)
all_corp.index = pd.to_datetime(all_corp.index)

all_bonds = pd.concat([all_corp, em_bonds],axis=1).dropna(how="all")

# %%
for fam in ["EM","HY","IG","EUR_HY", 'EUR_IG', 'SNRFIN', 'SUBFIN']:
    i=1
    x = plot_names[plot_names["Family"]==fam].copy()
    if len(x)>0:
        for item in x.index:
            bond_name = item + " " + default_bonds[item]
            f = all_bonds[[f"{bond_name} Mat. Matched CDS",f"{bond_name} Basis"]].dropna().copy()
            f = f[f.index>pd.to_datetime("2021-01-01")]
            plt.figure(figsize=(12,6))
            plt.scatter(f[f"{bond_name} Mat. Matched CDS"].iloc[:-252], f[f"{bond_name} Basis"].iloc[:-252], color="gray")
            plt.scatter(f[f"{bond_name} Mat. Matched CDS"].iloc[-252:-63], f[f"{bond_name} Basis"].iloc[-252:-63], color="blue")
            plt.scatter(f[f"{bond_name} Mat. Matched CDS"].iloc[-63:-1], f[f"{bond_name} Basis"].iloc[-63:-1], color="green")
            plt.scatter(f[f"{bond_name} Mat. Matched CDS"].iloc[-1], f[f"{bond_name} Basis"].iloc[-1], color="red")          
            
            x_scatter = f[f"{bond_name} Mat. Matched CDS"]
            y_scatter = f[f"{bond_name} Basis"]

            coeffs = np.polyfit(x_scatter,y_scatter,2)
            polynomial = np.poly1d(coeffs)
            x_poly=np.linspace(min(x_scatter),max(x_scatter),500)
            y_poly=polynomial(x_poly)
            y_pred = polynomial(x_scatter)
            r2=r2_score(y_scatter,y_pred)
            equation_text = f"y = {coeffs[0]:.4f}*x² + {coeffs[1]:.4f}*x + {coeffs[2]:.4f}"

            residuals = y_scatter-y_pred
            res_sum=np.sum(residuals**2)
            dof=len(x_scatter)-len(coeffs)
            res_var = res_sum / dof
            se = np.sqrt(res_var)
            conf_upper = y_poly + 2 * se
            conf_lower = y_poly - 2 * se
            
            plt.scatter(x_poly, y_poly,color="orange",s=2)
            plt.scatter(x_poly, conf_upper,color="orange",s=2)
            plt.scatter(x_poly, conf_lower,color="orange",s=2)
            
            plt.fill_between(x_poly, conf_lower, conf_upper, color="orange", alpha=0.1)

            plt.title(f"{bond_name} from {f.index[0].date()} to {f.index[-1].date()}")
            plt.ylabel(f"{bond_name} Basis")
            plt.xlabel(f"{bond_name} Mat. Matched CDS")
            plt.savefig(f'J:\\53A. HY Bonds Basis Email\\Email Plots\\Scatter Plots\\{datetime.\
                now().date()}_{fam.replace("_","")}_{i}.png')
            i += 1
            plt.show()

# %%
import os
import win32com.client
import glob
import pandas as pd
import dataframe_image as dfi
from io import BytesIO
import tempfile

html_body = "<html><body>"

outlook = win32com.client.Dispatch("Outlook.Application")
mail = outlook.CreateItem(0)

folder_path = f'J:\\53A. HY Bonds Basis Email\\Email Plots'

for family in ["EM","HY","IG","EURHY", 'EURIG', 'SNRFIN', 'SUBFIN']:
    html_body += f'<h2 style="color:red;">{family}</h2>'
    png_files = glob.glob(os.path.join(folder_path, '*.png'))
    png_files = [item for item in png_files if item.rsplit("\\")[-1].split("_")[0]==family]
    png_files.sort(key=lambda x: int(os.path.splitext(os.path.basename(x))[0].rsplit("_")[-1]))
    for png_file in png_files:
        raw_name = os.path.splitext(os.path.basename(png_file))[0]
        image_cid = raw_name.replace(" ", "_")
        attachment = mail.Attachments.Add(Source=png_file)
        attachment.PropertyAccessor.SetProperty("http://schemas.microsoft.com/mapi/proptag/0x3712001F", image_cid)
        html_body += f'<img src="cid:{image_cid}"><br><br><br>'

folder_path = f'J:\\53A. HY Bonds Basis Email\\Email Plots\\Scatter Plots'

for family in ["EM","HY","IG","EURHY", 'EURIG', 'SNRFIN', 'SUBFIN']:
    
    png_files = glob.glob(os.path.join(folder_path, '*.png'))
    png_files = [item for item in png_files if ((item.rsplit("\\")[-1].\
        split("_",1)[1].rsplit("_",1)[0]==family) and (item.rsplit("\\")[-1].split("_")[0]==str(datetime.now().date())))]
    png_files.sort(key=lambda x: int(os.path.splitext(os.path.basename(x))[0].rsplit("_")[-1]))
    if len(png_files) > 0:
        html_body += f'<h2 style="color:red;">{family} Basis Scatter Plots</h2>'
        for png_file in png_files:
            raw_name = os.path.splitext(os.path.basename(png_file))[0]
            image_cid = raw_name.replace(" ", "_")
            attachment = mail.Attachments.Add(Source=png_file)
            attachment.PropertyAccessor.SetProperty("http://schemas.microsoft.com/mapi/proptag/0x3712001F", image_cid)
            html_body += f'<img src="cid:{image_cid}"><br><br><br>'
    
html_body += '</body></html>'

mail.HTMLBody = html_body
mail.Subject = f'Median Basis ZScores (auto)'
mail.CC = 'vasu.sharma@iiicm.com'
if email_both:
    mail.To = 'spyros.michas@iiicm.com'
mail.Send()

print("Sent")
